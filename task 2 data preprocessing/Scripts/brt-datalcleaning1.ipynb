# %%
import pandas as pd
import numpy as np

# %%
# Read the weather dataset 
file_path = r"C:\Users\chimi\Desktop\Python Data Science Projects\Urban Modeling Project\Predictive maintenance Model Data\Weather Dataset\South Africa-Kenya-Nigeria-Tanzania-weather 2017-01-01 to 2023-04-18.csv"

# Read the CSV file into a Pandas DataFrame
weather_df = pd.read_csv(file_path)

# %%
weather_df.head(5)
# Out:
#        name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Tanzania  2017-01-01     32.1     21.0  25.9          31.3          21.0
# 1  Tanzania  2017-01-02     32.0     21.0  25.3          32.0          21.0
# 2  Tanzania  2017-01-03     30.4     20.0  22.9          31.1          20.0
# 3  Tanzania  2017-01-04     32.1     19.0  24.8          34.7          19.0
# 4  Tanzania  2017-01-05     33.0     20.0  26.6          31.4          20.0
#
#    feelslike   dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0       25.7  16.0      57.4  ...          NaN      NaN         NaN
# 1       25.3  17.2      63.5  ...          NaN      NaN         NaN
# 2       23.1  18.6      78.4  ...          NaN      NaN         NaN
# 3       25.5  19.0      73.6  ...          NaN      NaN         NaN
# 4       26.1  14.4      52.3  ...          NaN      NaN         NaN
#
#                sunrise               sunset  moonphase  \
# ...

# %%
weather_df.shape
# Out:
# (9196, 33)

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9196 entries, 0 to 9195
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              9196 non-null   object
#  1   datetime          9196 non-null   object
#  2   tempmax           9050 non-null   float64
#  3   tempmin           9050 non-null   float64
#  4   temp              9050 non-null   float64
#  5   feelslikemax      9050 non-null   float64
#  6   feelslikemin      9050 non-null   float64
#  7   feelslike         9050 non-null   float64
#  8   dew               9050 non-null   float64
#  9   humidity          9050 non-null   float64
#  10  precip            8946 non-null   float64
#  11  precipprob        9050 non-null   float64
#  12  precipcover       9196 non-null   float64
#  13  preciptype        2563 non-null   object
#  14  snow              7355 non-null   float64
#  15  snowdepth         7355 non-null   float64
# ...

# %%
weather_df.columns
# Out:
# Index(['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise',
#        'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations'],
#       dtype='object')

# %%
weather_df.dtypes
# Out:
# name                 object
# datetime             object
# tempmax             float64
# tempmin             float64
# temp                float64
# feelslikemax        float64
# feelslikemin        float64
# feelslike           float64
# dew                 float64
# humidity            float64
# precip              float64
# precipprob          float64
# precipcover         float64
# preciptype           object
# snow                float64
# snowdepth           float64
# windgust            float64
# windspeed           float64
# winddir             float64
# sealevelpressure    float64
# cloudcover          float64
# visibility          float64
# solarradiation      float64
# solarenergy         float64
# uvindex             float64
# severerisk          float64
# sunrise              object
# sunset               object
# moonphase           float64
# conditions           object
# description          object
# icon                 object
# stations             object
# ...

# %%
# Drop some of the columns
weather_df.drop(columns=['precip','preciptype','snow','snowdepth','windgust',
                       'solarradiation','solarenergy','uvindex','severerisk','sunset','sunrise',
                       'moonphase','description','icon','stations'],inplace=True)

# %%
 # Rename the column
weather_df.rename(columns={'name':'countries'},inplace=True)

# %%
weather_df.head(5)
# Out:
#   countries    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Tanzania  2017-01-01     32.1     21.0  25.9          31.3          21.0
# 1  Tanzania  2017-01-02     32.0     21.0  25.3          32.0          21.0
# 2  Tanzania  2017-01-03     30.4     20.0  22.9          31.1          20.0
# 3  Tanzania  2017-01-04     32.1     19.0  24.8          34.7          19.0
# 4  Tanzania  2017-01-05     33.0     20.0  26.6          31.4          20.0
#
#    feelslike   dew  humidity  precipprob  precipcover  windspeed  winddir  \
# 0       25.7  16.0      57.4         0.0         0.00       29.5     90.4
# 1       25.3  17.2      63.5       100.0         4.17       22.3     80.4
# 2       23.1  18.6      78.4       100.0        16.67       37.1    294.0
# 3       25.5  19.0      73.6       100.0         4.17       18.4     79.8
# 4       26.1  14.4      52.3         0.0         0.00       29.5     90.4
#
# ...

# %%
# Read the brt data
file_path = r"C:\Users\chimi\Desktop\Python Data Science Projects\Urban Modeling Project\Predictive maintenance Model Data\Public Transport\brtdata-africa_processed.csv"

# Read the CSV file into a Pandas DataFrame
brt_df = pd.read_csv(file_path)

# %%
brt_df.head(5)
# Out:
#    Unnamed: 0  GDP per capita (US$) Population, city Population, metro area  \
# 0           1                2006.8        2,750,547              5,183,657
# 1           2                2097.1       22,583,305             22,583,305
# 2           3                5655.9          957,441              4,434,827
# 3           4                5655.9          957,441              4,434,827
# 4           5                5655.9        3,740,026              3,740,026
#
#   Population density, metropolitan area  Modal split % public transport  \
# 0                                 4,509                            46.0
# 1                                11,009                            71.5
# 2                                 2,696                            32.0
# 3                                 2,696                            32.0
# 4                                 1,530                            43.7
#
# ...

# %%
brt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 95 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Unnamed: 0                                                        9 non-null      int64
#  1   GDP per capita (US$)                                              9 non-null      float64
#  2   Population, city                                                  9 non-null      object
#  3   Population, metro area                                            9 non-null      object
#  4   Population density, metropolitan area                             9 non-null      object
#  5   Modal split % public transport                                    9 non-null      float64
#  6   Modal split % private transport                                   9 non-null      float64
# ...

# %%
brt_df.columns
# Out:
# Index(['Unnamed: 0', 'GDP per capita (US$)', 'Population, city',
#        'Population, metro area', 'Population density, metropolitan area',
#        'Modal split % public transport', 'Modal split % private transport',
#        'Modal split % non motorized', 'System name', 'Corridors',
#        'Year system commenced', 'Transit agency', 'Standard fare (US$)',
#        'Annual fare revenue (US$ millions)',
#        'Fare integration within the system',
#        'Citywide fare integration (other modes)', 'Integration terminals',
#        'Transfer stations', 'Peak load (passengers per hour per direction)',
#        'Daily demand (passengers per day)',
#        'Annual demand (passengers per year)',
#        'Capital productivity (boardings per bus per day)',
#        'Operational productivity (IPK)', 'Operations control center',
#        'Trunk lines', 'Feeder routes', 'Depots', 'System length (km)',
#        'Position of with-flow lanes', 'Position of bus doors',
# ...

# %%
brt_df.isnull().sum()
# Out:
# Unnamed: 0                                                          0
# GDP per capita (US$)                                                0
# Population, city                                                    0
# Population, metro area                                              0
# Population density, metropolitan area                               0
#                                                                    ..
# Planning cost, corridor (US$ million)                               8
# Infrastructure cost per kilometer, corridor (US$ million per km)    5
# Passengers per Day                                                  0
# Number of Corridors                                                 0
# countries                                                           0
# Length: 95, dtype: int64

# %%
# Drop the unnamed column
brt_df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
# Merge the dfs
final_df = pd.merge(weather_df, brt_df, on='countries', how='left')

# %%
final_df.to_csv('transportation_data.csv',index=False)

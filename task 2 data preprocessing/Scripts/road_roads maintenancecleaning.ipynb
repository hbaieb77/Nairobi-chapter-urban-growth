# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import os
from shapely.geometry import LineString
import gemgis as gg

# %%
file_path = "C:/Users/chimi/Desktop/Python Data Science Projects/Urban Modeling Project/Predictive maintenance Model Data/Weather Dataset/annual_precip.csv"
df = pd.read_csv(file_path, skiprows=4)

# %%
df.head(5)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                  Indicator Name  Indicator Code  1960    1961  \
# 0  Average precipitation in depth (mm per year)  AG.LND.PRCP.MM   NaN     NaN
# 1  Average precipitation in depth (mm per year)  AG.LND.PRCP.MM   NaN     NaN
# 2  Average precipitation in depth (mm per year)  AG.LND.PRCP.MM   NaN  327.00
# 3  Average precipitation in depth (mm per year)  AG.LND.PRCP.MM   NaN     NaN
# 4  Average precipitation in depth (mm per year)  AG.LND.PRCP.MM   NaN 1010.00
#
#      1962    1963    1964    1965  ...    2012    2013    2014    2015  \
# 0     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2  327.00  327.00  327.00  327.00  ...  327.00  327.00  327.00  327.00
# 3     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 4 1010.00 1010.00 1010.00 1010.00  ... 1010.00 1010.00 1010.00 1010.00
#
#      2016    2017    2018    2019  2020  2021
# 0     NaN     NaN     NaN     NaN   NaN   NaN
# 1     NaN     NaN     NaN     NaN   NaN   NaN
# 2  327.00  327.00  327.00  327.00   NaN   NaN
# 3     NaN     NaN     NaN     NaN   NaN   NaN
# 4 1010.00 1010.00 1010.00 1010.00   NaN   NaN
#
# [5 rows x 66 columns]

# %%
# Filter in countries
countries_to_filter = ['Burundi','Angola','Cameroon','Ethiopia','Kenya','South Africa']
annualprecip_bycountries = df[df['Country Name'].isin(countries_to_filter)]

# %%
annualprecip_bycountries.head(5)
# Out:
#     Country Name Country Code                                Indicator Name  \
# 4         Angola          AGO  Average precipitation in depth (mm per year)
# 16       Burundi          BDI  Average precipitation in depth (mm per year)
# 42      Cameroon          CMR  Average precipitation in depth (mm per year)
# 72      Ethiopia          ETH  Average precipitation in depth (mm per year)
# 121        Kenya          KEN  Average precipitation in depth (mm per year)
#
#      Indicator Code  1960    1961    1962    1963    1964    1965  ...  \
# 4    AG.LND.PRCP.MM   NaN 1010.00 1010.00 1010.00 1010.00 1010.00  ...
# 16   AG.LND.PRCP.MM   NaN 1274.00 1274.00 1274.00 1274.00 1274.00  ...
# 42   AG.LND.PRCP.MM   NaN 1604.00 1604.00 1604.00 1604.00 1604.00  ...
# 72   AG.LND.PRCP.MM   NaN     NaN     NaN     NaN     NaN     NaN  ...
# 121  AG.LND.PRCP.MM   NaN  630.00  630.00  630.00  630.00  630.00  ...
#
#        2012    2013    2014    2015    2016    2017    2018    2019  2020  \
# 4   1010.00 1010.00 1010.00 1010.00 1010.00 1010.00 1010.00 1010.00   NaN
# 16  1274.00 1274.00 1274.00 1274.00 1274.00 1274.00 1274.00 1274.00   NaN
# 42  1604.00 1604.00 1604.00 1604.00 1604.00 1604.00 1604.00 1604.00   NaN
# 72   848.00  848.00  848.00  848.00  848.00  848.00  848.00  848.00   NaN
# 121  630.00  630.00  630.00  630.00  630.00  630.00  630.00  630.00   NaN
#
#      2021
# 4     NaN
# 16    NaN
# 42    NaN
# 72    NaN
# 121   NaN
#
# [5 rows x 66 columns]

# %%
# Melt the data
melted_data = annualprecip_bycountries.melt(id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], var_name='Year', value_name='Annual Precipitation')

# %%
melted_data.head(5)
# Out:
#   Country Name Country Code                                Indicator Name  \
# 0       Angola          AGO  Average precipitation in depth (mm per year)
# 1      Burundi          BDI  Average precipitation in depth (mm per year)
# 2     Cameroon          CMR  Average precipitation in depth (mm per year)
# 3     Ethiopia          ETH  Average precipitation in depth (mm per year)
# 4        Kenya          KEN  Average precipitation in depth (mm per year)
#
#    Indicator Code  Year  Annual Precipitation
# 0  AG.LND.PRCP.MM  1960                   NaN
# 1  AG.LND.PRCP.MM  1960                   NaN
# 2  AG.LND.PRCP.MM  1960                   NaN
# 3  AG.LND.PRCP.MM  1960                   NaN
# 4  AG.LND.PRCP.MM  1960                   NaN

# %%
melted_data['Indicator Name'].value_counts()
# Out:
# Average precipitation in depth (mm per year)    372
# Name: Indicator Name, dtype: int64

# %%
# Renaming the column indicator name column to Average precipitation in depth (mm per year) 
melted_data.drop(columns=['Indicator Name','Indicator Code'])
# Out:
#      Country Name Country Code  Year  Annual Precipitation
# 0          Angola          AGO  1960                   NaN
# 1         Burundi          BDI  1960                   NaN
# 2        Cameroon          CMR  1960                   NaN
# 3        Ethiopia          ETH  1960                   NaN
# 4           Kenya          KEN  1960                   NaN
# ..            ...          ...   ...                   ...
# 367       Burundi          BDI  2021                   NaN
# 368      Cameroon          CMR  2021                   NaN
# 369      Ethiopia          ETH  2021                   NaN
# 370         Kenya          KEN  2021                   NaN
# 371  South Africa          ZAF  2021                   NaN
#
# [372 rows x 4 columns]

# %%
melted_data.info
# Out:
# <bound method DataFrame.info of      Country Name Country Code                                Indicator Name  \
# 0          Angola          AGO  Average precipitation in depth (mm per year)
# 1         Burundi          BDI  Average precipitation in depth (mm per year)
# 2        Cameroon          CMR  Average precipitation in depth (mm per year)
# 3        Ethiopia          ETH  Average precipitation in depth (mm per year)
# 4           Kenya          KEN  Average precipitation in depth (mm per year)
# ..            ...          ...                                           ...
# 367       Burundi          BDI  Average precipitation in depth (mm per year)
# 368      Cameroon          CMR  Average precipitation in depth (mm per year)
# 369      Ethiopia          ETH  Average precipitation in depth (mm per year)
# 370         Kenya          KEN  Average precipitation in depth (mm per year)
# 371  South Africa          ZAF  Average precipitation in depth (mm per year)
#
#      Indicator Code  Year  Annual Precipitation
# 0    AG.LND.PRCP.MM  1960                   NaN
# 1    AG.LND.PRCP.MM  1960                   NaN
# 2    AG.LND.PRCP.MM  1960                   NaN
# 3    AG.LND.PRCP.MM  1960                   NaN
# 4    AG.LND.PRCP.MM  1960                   NaN
# ..              ...   ...                   ...
# 367  AG.LND.PRCP.MM  2021                   NaN
# 368  AG.LND.PRCP.MM  2021                   NaN
# 369  AG.LND.PRCP.MM  2021                   NaN
# 370  AG.LND.PRCP.MM  2021                   NaN
# 371  AG.LND.PRCP.MM  2021                   NaN
#
# [372 rows x 6 columns]>

# %%
melted_data.dtypes
# Out:
# Country Name             object
# Country Code             object
# Indicator Name           object
# Indicator Code           object
# Year                     object
# Annual Precipitation    float64
# dtype: object

# %%
# Change the data types
if melted_data['Year'].dtype == 'object' or melted_data['Year'].dtype == 'str':
    melted_data['Year'] = pd.to_numeric(melted_data['Year'], errors='coerce')

# %%
# Filter in from year 2000 to 2021
filtered_data = melted_data[(melted_data['Year'] >= 2000) & (melted_data['Year'] <= 2021)]

# %%
# Check for missing values
filtered_data.isnull().sum()
# Out:
# Country Name             0
# Country Code             0
# Indicator Name           0
# Indicator Code           0
# Year                     0
# Annual Precipitation    12
# dtype: int64

# %%
# Drop the missing values
filtered_data = filtered_data.dropna()

# %%
# Make sure there are no null values
filtered_data.isnull().sum()
# Out:
# Country Name            0
# Country Code            0
# Indicator Name          0
# Indicator Code          0
# Year                    0
# Annual Precipitation    0
# dtype: int64

# %%
# Calculate the average precipitation by country from 2000 to 2021
average_precip = filtered_data.groupby(['Country Name']).mean().reset_index()

# %%
# Total number of hours in a year
hours_per_year = 24 * 365

average_precip['Average Precipitation Rate(mm/h by year)'] = average_precip['Annual Precipitation'] / hours_per_year
average_precip
# Out:
#    Country Name    Year  Annual Precipitation  \
# 0        Angola 2009.50               1010.00
# 1       Burundi 2009.50               1271.20
# 2      Cameroon 2009.50               1604.00
# 3      Ethiopia 2009.50                848.00
# 4         Kenya 2009.50                633.10
# 5  South Africa 2009.50                495.00
#
#    Average Precipitation Rate(mm/h by year)
# 0                                      0.12
# 1                                      0.15
# 2                                      0.18
# 3                                      0.10
# 4                                      0.07
# 5                                      0.06

# %%
average_precip.drop(columns=['Year'],axis=0,inplace=True)

# %%
# Rename the Country Name column to Countru
average_precip.rename(columns={'Country Name':'Country'},inplace=True)

# %%
# Final average_precip
average_precip
# Out:
#         Country  Annual Precipitation  \
# 0        Angola               1010.00
# 1       Burundi               1271.20
# 2      Cameroon               1604.00
# 3      Ethiopia                848.00
# 4         Kenya                633.10
# 5  South Africa                495.00
#
#    Average Precipitation Rate(mm/h by year)
# 0                                      0.12
# 1                                      0.15
# 2                                      0.18
# 3                                      0.10
# 4                                      0.07
# 5                                      0.06

# %%
# Read the road dataset
# Calculating PCI index
file_path = r"C:\Users\chimi\Desktop\Python Data Science Projects\Urban Modeling Project\Predictive maintenance Model Data\Roads\roadmain_data.csv"
roads_data = pd.read_csv(file_path)

# %%
roads_data.shape
# Out:
# (12283, 15)

# %%
roads_data.columns
# Out:
# Index(['REGION', 'ROADNO', 'STARTDESC', 'ENDDESC', 'LENGTHKM', 'WIDTH', 'AADT',
#        'PAVETYPE', 'CONDITION', 'LANES', 'geometry', 'Country', 'SURFTYP',
#        'CLASS', 'slope'],
#       dtype='object')

# %%
roads_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12283 entries, 0 to 12282
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   REGION     12283 non-null  object
#  1   ROADNO     12282 non-null  object
#  2   STARTDESC  12279 non-null  object
#  3   ENDDESC    12277 non-null  object
#  4   LENGTHKM   12283 non-null  float64
#  5   WIDTH      12283 non-null  float64
#  6   AADT       12283 non-null  float64
#  7   PAVETYPE   12283 non-null  object
#  8   CONDITION  12283 non-null  object
#  9   LANES      12283 non-null  float64
#  10  geometry   12283 non-null  object
#  11  Country    12283 non-null  object
#  12  SURFTYP    12236 non-null  object
#  13  CLASS      10562 non-null  object
#  14  slope      12283 non-null  float64
# dtypes: float64(5), object(10)
# memory usage: 1.4+ MB

# %%
merged_data = roads_data.merge(average_precip[['Country', 'Average Precipitation Rate(mm/h by year)']], on='Country', how='left')

# %%
merged_data.head(5)
# Out:
#              REGION ROADNO  STARTDESC    ENDDESC  LENGTHKM  WIDTH   AADT  \
# 0  Bujumbura-Mairie    RN7  Bujumbura  Nyakarara      4.18   6.00 524.00
# 1   Bujumbura-Rural    RN7  Bujumbura  Nyakarara     16.29   6.00 524.00
# 2            Bururi    RN7    Unknown  jct RN 16     21.41   6.00  75.00
# 3            Gitega    RN7    Unknown  jct RN 16      2.33   6.00  75.00
# 4            Bururi    RN7  jct RN 16   jct RN 8     17.08   6.00 136.00
#
#   PAVETYPE CONDITION  LANES  \
# 0  Asphalt       Bad   2.00
# 1  Asphalt       Bad   2.00
# 2  Asphalt      Good   2.00
# 3  Asphalt      Good   2.00
# 4  Asphalt      Good   2.00
#
#                                             geometry  Country SURFTYP CLASS  \
# 0  LINESTRING (12.965945581671459 -7.041666075978...  Burundi  Paved    NaN
# 1  LINESTRING (13.59030560021181 -8.5844107579491...  Burundi  Paved    NaN
# 2  LINESTRING (13.7307457308967 -7.83080970764367...  Burundi  Paved    NaN
# 3  LINESTRING (12.97150629518783 -7.6364261839293...  Burundi  Paved    NaN
# 4  LINESTRING (13.702648452544794 -9.284267848298...  Burundi  Paved    NaN
#
#    slope  Average Precipitation Rate(mm/h by year)
# 0   0.88                                      0.15
# 1   0.68                                      0.15
# 2   0.40                                      0.15
# 3   0.54                                      0.15
# 4   1.88                                      0.15

# %%
merged_data['Average Precipitation Rate(mm/h by year)'].value_counts()
# Out:
# 0.07    8275
# 0.06    1803
# 0.18    1443
# 0.12     408
# 0.15     278
# 0.10      76
# Name: Average Precipitation Rate(mm/h by year), dtype: int64

# %%
merged_data['PAVETYPE'].value_counts()
# Out:
# Earth                  4150
# Gravel                 3098
# FLEX                   1490
# Earth Road             1224
# Surface Dressing        719
# Asphalt                 660
# Premix                  260
# Unknown                 246
# Track                   213
# JPCC                     57
# Gravel Road              47
# Concrete (Jt-Plain)      36
# Gap                      31
# Concrete Block           13
# CRCP                     10
# AC                        8
# Sand                      7
# Paved                     5
# Unpaved                   4
# ST                        3
# Set Stone                 2
# Name: PAVETYPE, dtype: int64

# %%
# Drop the unknown surface type rows
merged_data.drop(merged_data[merged_data['PAVETYPE'].isin(['Unknown', ''])].index, inplace=True)

# %%
# Make sure unknown rows were dropped
merged_data['PAVETYPE'].value_counts()
# Out:
# Earth                  4150
# Gravel                 3098
# FLEX                   1490
# Earth Road             1224
# Surface Dressing        719
# Asphalt                 660
# Premix                  260
# Track                   213
# JPCC                     57
# Gravel Road              47
# Concrete (Jt-Plain)      36
# Gap                      31
# Concrete Block           13
# CRCP                     10
# AC                        8
# Sand                      7
# Paved                     5
# Unpaved                   4
# ST                        3
# Set Stone                 2
# Name: PAVETYPE, dtype: int64

# %%
# # Calculate Runoff Coefficents :https://www.researchgate.net/figure/The-runoff-coefficient-of-different-land-types_tbl1_276044494
#https://www.researchgate.net/figure/Guidelines-for-surface-runoff-coefficients-by-the-Ministry-of-Education-Culture-Sports_tbl1_239789469
# These are standard rational coefficents complied  from those sites
surface_types = {
    'Earth': 0.4,
    'Earth Road': 0.4,
    'Track': 0.3,
    'Gravel': 0.5,
    'Gravel Road': 0.5,
    'Sand': 0.25,
    'ST (Set Stone)': 0.35 ,
    'Asphalt': 0.90,
    'AC':0.9,
    'JPCC': 0.85,
    'Concrete (Jt-Plain)': 0.85,
    'CRCP': 0.85,
    'FLEX': 0.85,
    'Premix': 0.85,
    'Surface Dressing': 0.85,
    'Concrete Block': 0.85,
    'Paved': 0.85,
    'Unpaved' : 0.25,
    'ST' : 0.85,
    'Set Stone': 0.85,
    'Gap':0.85
}

# %%
merged_data['runfoff_coef'] = merged_data['PAVETYPE'].replace(surface_types)

# %%
merged_data['runfoff_coef'].value_counts()
# Out:
# 0.40    5374
# 0.50    3145
# 0.85    2626
# 0.90     668
# 0.30     213
# 0.25      11
# Name: runfoff_coef, dtype: int64

# %%
merged_data.head(5)
# Out:
#              REGION ROADNO  STARTDESC    ENDDESC  LENGTHKM  WIDTH   AADT  \
# 0  Bujumbura-Mairie    RN7  Bujumbura  Nyakarara      4.18   6.00 524.00
# 1   Bujumbura-Rural    RN7  Bujumbura  Nyakarara     16.29   6.00 524.00
# 2            Bururi    RN7    Unknown  jct RN 16     21.41   6.00  75.00
# 3            Gitega    RN7    Unknown  jct RN 16      2.33   6.00  75.00
# 4            Bururi    RN7  jct RN 16   jct RN 8     17.08   6.00 136.00
#
#   PAVETYPE CONDITION  LANES  \
# 0  Asphalt       Bad   2.00
# 1  Asphalt       Bad   2.00
# 2  Asphalt      Good   2.00
# 3  Asphalt      Good   2.00
# 4  Asphalt      Good   2.00
#
#                                             geometry  Country SURFTYP CLASS  \
# 0  LINESTRING (12.965945581671459 -7.041666075978...  Burundi  Paved    NaN
# 1  LINESTRING (13.59030560021181 -8.5844107579491...  Burundi  Paved    NaN
# 2  LINESTRING (13.7307457308967 -7.83080970764367...  Burundi  Paved    NaN
# 3  LINESTRING (12.97150629518783 -7.6364261839293...  Burundi  Paved    NaN
# 4  LINESTRING (13.702648452544794 -9.284267848298...  Burundi  Paved    NaN
#
#    slope  Average Precipitation Rate(mm/h by year)  runfoff_coef
# 0   0.88                                      0.15          0.90
# 1   0.68                                      0.15          0.90
# 2   0.40                                      0.15          0.90
# 3   0.54                                      0.15          0.90
# 4   1.88                                      0.15          0.90

# %%
merged_data.tail(5)
# Out:
#               REGION ROADNO       STARTDESC         ENDDESC  LENGTHKM  WIDTH  \
# 12278  KwaZulu-Natal    R66     Gingindlovu        Nkwalini     48.91  12.80
# 12279  KwaZulu-Natal    R66     Gingindlovu        Nkwalini     48.91  12.80
# 12280  KwaZulu-Natal     N2  Hibberdene I/C    Mtwalume I/C      8.44  20.20
# 12281  KwaZulu-Natal     N2  Hibberdene I/C    Mtwalume I/C      8.42  20.20
# 12282  KwaZulu-Natal     N2         Marburg  Umtentweni I/C      7.47  20.20
#
#           AADT PAVETYPE  CONDITION  LANES  \
# 12278     0.00     FLEX    Unknown   2.00
# 12279     0.00     FLEX    Unknown   2.00
# 12280 11885.00     FLEX  Very Good   2.00
# 12281 11885.00     FLEX  Very Good   2.00
# 12282  5807.00     FLEX  Very Good   2.00
#
#                                                 geometry       Country  \
# 12278  LINESTRING (31.61473812 -29.07737001, 31.61465...  South Africa
# 12279  LINESTRING (31.59042590231682 -29.030550211759...  South Africa
# 12280  LINESTRING (30.57512688 -30.56287698, 30.57521...  South Africa
# 12281  LINESTRING (30.574397159999997 -30.56320602, 3...  South Africa
# 12282  LINESTRING (30.43110492 -30.75247503, 30.43117...  South Africa
#
#       SURFTYP    CLASS  slope  Average Precipitation Rate(mm/h by year)  \
# 12278   Paved  Primary    inf                                      0.06
# 12279   Paved  Primary  -6.50                                      0.06
# 12280   Paved  Primary  -1.09                                      0.06
# 12281   Paved  Primary  -1.33                                      0.06
# 12282   Paved  Primary  -2.45                                      0.06
#
#        runfoff_coef
# 12278          0.85
# 12279          0.85
# 12280          0.85
# 12281          0.85
# 12282          0.85

# %%
# Apply rating scale to road condition
def apply_rating(rating):
    if rating == 'Excellent':
        return 95
    elif rating == 'Very Good':
        return 85
    elif rating == 'Good':
        return 75
    elif rating == 'Fair':
        return 60
    elif rating == 'Poor':
        return 45
    elif rating == 'Very Poor':
        return 30
    else:
        return 0
        
# Assign a lower PCI score to road segments with the same rating as "Poor" or "Fair"
merged_data['PCI'] = merged_data['CONDITION'].apply(apply_rating)
merged_data['MAINTENANCE_SCORE'] = merged_data['CONDITION'].apply(apply_rating)

# %%
merged_data
# Out:
#                  REGION ROADNO       STARTDESC         ENDDESC  LENGTHKM  \
# 0      Bujumbura-Mairie    RN7       Bujumbura       Nyakarara      4.18
# 1       Bujumbura-Rural    RN7       Bujumbura       Nyakarara     16.29
# 2                Bururi    RN7         Unknown       jct RN 16     21.41
# 3                Gitega    RN7         Unknown       jct RN 16      2.33
# 4                Bururi    RN7       jct RN 16        jct RN 8     17.08
# ...                 ...    ...             ...             ...       ...
# 12278     KwaZulu-Natal    R66     Gingindlovu        Nkwalini     48.91
# 12279     KwaZulu-Natal    R66     Gingindlovu        Nkwalini     48.91
# 12280     KwaZulu-Natal     N2  Hibberdene I/C    Mtwalume I/C      8.44
# 12281     KwaZulu-Natal     N2  Hibberdene I/C    Mtwalume I/C      8.42
# 12282     KwaZulu-Natal     N2         Marburg  Umtentweni I/C      7.47
#
#        WIDTH     AADT PAVETYPE  CONDITION  LANES  \
# 0       6.00   524.00  Asphalt        Bad   2.00
# 1       6.00   524.00  Asphalt        Bad   2.00
# 2       6.00    75.00  Asphalt       Good   2.00
# 3       6.00    75.00  Asphalt       Good   2.00
# 4       6.00   136.00  Asphalt       Good   2.00
# ...      ...      ...      ...        ...    ...
# 12278  12.80     0.00     FLEX    Unknown   2.00
# 12279  12.80     0.00     FLEX    Unknown   2.00
# 12280  20.20 11885.00     FLEX  Very Good   2.00
# 12281  20.20 11885.00     FLEX  Very Good   2.00
# 12282  20.20  5807.00     FLEX  Very Good   2.00
#
#                                                 geometry       Country  \
# 0      LINESTRING (12.965945581671459 -7.041666075978...       Burundi
# 1      LINESTRING (13.59030560021181 -8.5844107579491...       Burundi
# 2      LINESTRING (13.7307457308967 -7.83080970764367...       Burundi
# 3      LINESTRING (12.97150629518783 -7.6364261839293...       Burundi
# 4      LINESTRING (13.702648452544794 -9.284267848298...       Burundi
# ...                                                  ...           ...
# 12278  LINESTRING (31.61473812 -29.07737001, 31.61465...  South Africa
# 12279  LINESTRING (31.59042590231682 -29.030550211759...  South Africa
# 12280  LINESTRING (30.57512688 -30.56287698, 30.57521...  South Africa
# 12281  LINESTRING (30.574397159999997 -30.56320602, 3...  South Africa
# 12282  LINESTRING (30.43110492 -30.75247503, 30.43117...  South Africa
#
#       SURFTYP    CLASS  slope  Average Precipitation Rate(mm/h by year)  \
# 0      Paved       NaN   0.88                                      0.15
# 1      Paved       NaN   0.68                                      0.15
# 2      Paved       NaN   0.40                                      0.15
# 3      Paved       NaN   0.54                                      0.15
# 4      Paved       NaN   1.88                                      0.15
# ...       ...      ...    ...                                       ...
# 12278   Paved  Primary    inf                                      0.06
# 12279   Paved  Primary  -6.50                                      0.06
# 12280   Paved  Primary  -1.09                                      0.06
# 12281   Paved  Primary  -1.33                                      0.06
# 12282   Paved  Primary  -2.45                                      0.06
#
#        runfoff_coef  PCI  MAINTENANCE_SCORE
# 0              0.90    0                  0
# 1              0.90    0                  0
# 2              0.90   75                 75
# 3              0.90   75                 75
# 4              0.90   75                 75
# ...             ...  ...                ...
# 12278          0.85    0                  0
# 12279          0.85    0                  0
# 12280          0.85   85                 85
# 12281          0.85   85                 85
# 12282          0.85   85                 85
#
# [12037 rows x 19 columns]

# %%
# Let combine this with the weather data
file_path = r'C:\Users\chimi\Desktop\Python Data Science Projects\Urban Modeling Project\Predictive maintenance Model Data\Weather Dataset\Weather data Jan 2017 to April 18 2023.csv'
weather_df = pd.read_csv(file_path)

# %%
weather_df.head(5)
# Out:
#      name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Angola  2017-01-01    30.00    24.00 26.70         35.10         24.00
# 1  Angola  2017-01-02    31.00    25.80 27.40         36.40         25.80
# 2  Angola  2017-01-03    31.00    24.00 27.50         35.50         24.00
# 3  Angola  2017-01-04    32.00    25.80 27.90         36.80         25.80
# 4  Angola  2017-01-05    29.00    24.00 26.00         33.60         24.00
#
#    feelslike   dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0      28.40 23.20     81.40  ...          NaN      NaN         NaN
# 1      29.50 23.20     78.00  ...          NaN      NaN         NaN
# 2      30.10 23.30     78.60  ...          NaN      NaN         NaN
# 3      30.80 23.70     78.60  ...          NaN      NaN         NaN
# 4      27.00 23.30     85.50  ...          NaN      NaN         NaN
#
#                sunrise               sunset  moonphase        conditions  \
# 0  2017-01-01T05:51:57  2017-01-01T18:29:26       0.11  Partially cloudy
# 1  2017-01-02T05:52:29  2017-01-02T18:29:50       0.15  Partially cloudy
# 2  2017-01-03T05:53:01  2017-01-03T18:30:13       0.18  Partially cloudy
# 3  2017-01-04T05:53:33  2017-01-04T18:30:35       0.22  Partially cloudy
# 4  2017-01-05T05:54:04  2017-01-05T18:30:57       0.25  Partially cloudy
#
#                          description               icon          stations
# 0  Partly cloudy throughout the day.  partly-cloudy-day  FNLU,66160099999
# 1  Partly cloudy throughout the day.  partly-cloudy-day  FNLU,66160099999
# 2  Partly cloudy throughout the day.  partly-cloudy-day  FNLU,66160099999
# 3  Partly cloudy throughout the day.  partly-cloudy-day  FNLU,66160099999
# 4  Partly cloudy throughout the day.  partly-cloudy-day  FNLU,66160099999
#
# [5 rows x 33 columns]

# %%
weather_df['name'].value_counts()
# Out:
# Angola          2299
# South Africa    2299
# Kenya           2299
# Cameroon        2299
# Ethiopia        2299
# Burundi         2299
# Name: name, dtype: int64

# %%
weather_df.columns
# Out:
# Index(['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise',
#        'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations'],
#       dtype='object')

# %%
weather_df.shape
# Out:
# (13794, 33)

# %%
# Rename the name column
weather_df.rename(columns={'name':'Country'},inplace=True)

# %%
weather_df.isnull().sum()
# Out:
# Country                 0
# datetime                0
# tempmax               225
# tempmin               225
# temp                  225
# feelslikemax          225
# feelslikemin          225
# feelslike             225
# dew                   227
# humidity              225
# precip               3925
# precipprob            225
# precipcover             0
# preciptype          10444
# snow                 3767
# snowdepth            3769
# windgust             9008
# windspeed               0
# winddir               591
# sealevelpressure      505
# cloudcover            381
# visibility            252
# solarradiation       9545
# solarenergy          9545
# uvindex              9545
# severerisk          11010
# sunrise                 0
# sunset                  0
# moonphase               0
# conditions            225
# description           225
# icon                  225
# stations              225
# dtype: int64

# %%
# Drop some of the empty columns 
weather_df.drop(columns=['precip','preciptype','snow','snowdepth','windgust',
                       'solarradiation','solarenergy','uvindex','severerisk','sunset','sunrise',
                       'moonphase','conditions','description','icon','stations'],inplace=True)

# %%
# Merge the files
weather_df.columns
# Out:
# Index(['Country', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precipprob',
#        'precipcover', 'windspeed', 'winddir', 'sealevelpressure', 'cloudcover',
#        'visibility'],
#       dtype='object')

# %%
# Filter in 3 year columns / 5 year file is too large
#start_date = '2022-01-01'
#end_date = '2023-04-03'
#filtered_data = weather_df.loc[(weather_df['datetime'] >= start_date) & 
                               (weather_df['datetime'] <= end_date)]

# %%
# filtered_data.head(5)
# Out:
#      Country    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 1826  Angola  2022-01-01    29.00    24.00 26.10         32.70         24.00
# 1827  Angola  2022-01-02    28.00    25.00 25.80         31.90         25.00
# 1828  Angola  2022-01-03    29.00    24.00 26.40         32.00         24.00
# 1829  Angola  2022-01-04    28.00    24.00 25.90         31.20         24.00
# 1830  Angola  2022-01-05    29.00    23.00 25.90         32.00         23.00
#
#       feelslike   dew  humidity  precipprob  precipcover  windspeed  winddir  \
# 1826      27.30 22.90     83.20        0.00         0.00      18.40   228.80
# 1827      26.70 23.20     85.60        0.00         0.00      20.50   198.10
# 1828      27.80 23.30     83.50        0.00         0.00      16.60   238.30
# 1829      26.90 23.10     84.90        0.00         0.00      16.60   199.30
# 1830      26.90 22.00     80.20        0.00         0.00      16.60   214.30
#
#       sealevelpressure  cloudcover  visibility
# 1826           1009.70       57.90        9.60
# 1827           1009.10       71.60        9.60
# 1828           1008.90       64.60        9.90
# 1829           1010.50       87.00        9.90
# 1830           1010.00       52.70        9.30

# %%
#merged_df = pd.merge(merged_data, filtered_data, on='Country')

# %%
#merged_df.to_csv('finalroads_data.csv', index=False)

# %%
# Calculating Annual Data From 5 year
# File too large for labtop  to handle it

# %%
# Calculate average tempmax	tempmin	temp	feelslikemax	feelslikemin	feelslike	dew	humidity	precipprob	precipcover	windspeed
# winddir	sealevelpressure	cloudcover	visibility from Jan 2017 to April 2023

# %%
countries_5yearavg = weather_df.groupby(['Country']).mean()

# %%
countries_5yearavg.head(5)
# Out:
#           tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike   dew  \
# Country
# Angola      28.84    23.39 25.67         31.85         23.46      26.97 21.71
# Burundi     29.07    21.23 25.50         30.47         21.29      26.13 19.06
# Cameroon    29.33    20.34 23.87         31.46         20.34      24.38 20.87
# Ethiopia    22.47    12.45 17.08         22.40         12.28      17.05  8.33
# Kenya       25.19    15.49 19.84         24.98         15.49      19.80 13.18
#
#           humidity  precipprob  precipcover  windspeed  winddir  \
# Country
# Angola       79.39       13.88         2.56      20.36   222.17
# Burundi      69.22       27.10         2.94      26.54   170.29
# Cameroon     85.35       17.95         6.13      10.72   227.62
# Ethiopia     60.75       25.95         1.70      22.73   134.34
# Kenya        68.75       22.32         1.43      26.54    94.18
#
#           sealevelpressure  cloudcover  visibility
# Country
# Angola             1011.00       59.00       10.03
# Burundi            1012.81       64.22       11.48
# Cameroon           1015.49       66.37        8.75
# Ethiopia           1024.78       55.79       15.58
# Kenya              1020.85       70.07       11.27

# %%
# Average of countries for the past 5 years
prefix = 'annualavg'
# Loop through each column and append the appropriate prefix
for i in range(len(countries_5yearavg.columns)):
    if not df.columns[i].startswith(prefix):
        countries_5yearavg.rename(columns={countries_5yearavg.columns[i]: prefix + countries_5yearavg.columns[i]}, inplace=True)

# %%
countries_5yearavg.head(5)
# Out:
#           annualavgtempmax  annualavgtempmin  annualavgtemp  \
# Country
# Angola               28.84             23.39          25.67
# Burundi              29.07             21.23          25.50
# Cameroon             29.33             20.34          23.87
# Ethiopia             22.47             12.45          17.08
# Kenya                25.19             15.49          19.84
#
#           annualavgfeelslikemax  annualavgfeelslikemin  annualavgfeelslike  \
# Country
# Angola                    31.85                  23.46               26.97
# Burundi                   30.47                  21.29               26.13
# Cameroon                  31.46                  20.34               24.38
# Ethiopia                  22.40                  12.28               17.05
# Kenya                     24.98                  15.49               19.80
#
#           annualavgdew  annualavghumidity  annualavgprecipprob  \
# Country
# Angola           21.71              79.39                13.88
# Burundi          19.06              69.22                27.10
# Cameroon         20.87              85.35                17.95
# Ethiopia          8.33              60.75                25.95
# Kenya            13.18              68.75                22.32
#
#           annualavgprecipcover  annualavgwindspeed  annualavgwinddir  \
# Country
# Angola                    2.56               20.36            222.17
# Burundi                   2.94               26.54            170.29
# Cameroon                  6.13               10.72            227.62
# Ethiopia                  1.70               22.73            134.34
# Kenya                     1.43               26.54             94.18
#
#           annualavgsealevelpressure  annualavgcloudcover  annualavgvisibility
# Country
# Angola                      1011.00                59.00                10.03
# Burundi                     1012.81                64.22                11.48
# Cameroon                    1015.49                66.37                 8.75
# Ethiopia                    1024.78                55.79                15.58
# Kenya                       1020.85                70.07                11.27

# %%
# Combine merged_data and countries_5yearavg
final_df = pd.merge(merged_data, countries_5yearavg, on='Country', how='left')

# %%
final_df.to_csv('roads_maintenancefinal.csv',index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv('Algeria_cities_population.csv')

# %%
df
# Out:
#      Unnamed: 0   0                     1           2     3  \
# 0             0 NaN                  Name      Native  Adm.
# 1             1 NaN                 Adrar       أدرار   ADR
# 2             2 NaN                 Aflou        آفلو   LAG
# 3             3 NaN             Aïn Arnat   عين أرنات   SET
# 4             4 NaN              Aïn Azel    عين ازال   SET
# ..          ...  ..                   ...         ...   ...
# 176         176 NaN            Tizi Ouzou     تيزىوزو   TIZ
# 177         177 NaN  Tlemcen ( Tilimsen )      تلمسان   TLE
# 178         178 NaN                 Tolga       طولقة   BIS
# 179         179 NaN             Touggourt       توغرة   OUA
# 180         180 NaN        Zighout Youcef  زيغود يوسف   CON
#
#                                     4                                 5  \
# 0    Population Census (C) 1977-02-12  Population Census (C) 1987-03-20
# 1                              11,956                            28,580
# ...

# %%
df = df.drop(columns=['Unnamed: 0','0','9'])

# %%
df
# Out:
#                         1           2     3                                 4  \
# 0                    Name      Native  Adm.  Population Census (C) 1977-02-12
# 1                   Adrar       أدرار   ADR                            11,956
# 2                   Aflou        آفلو   LAG                            16,320
# 3               Aïn Arnat   عين أرنات   SET                             5,656
# 4                Aïn Azel    عين ازال   SET                             9,261
# ..                    ...         ...   ...                               ...
# 176            Tizi Ouzou     تيزىوزو   TIZ                            38,979
# 177  Tlemcen ( Tilimsen )      تلمسان   TLE                           109,408
# 178                 Tolga       طولقة   BIS                            14,921
# 179             Touggourt       توغرة   OUA                            42,519
# 180        Zighout Youcef  زيغود يوسف   CON                             9,877
#
# ...

# %%
column = df.iloc[0]

# %%
df = df[1:]

# %%
df.columns = column

# %%
df
# Out:
# 0                    Name       Native Adm. Population Census (C) 1977-02-12  \
# 1                   Adrar        أدرار  ADR                           11,956
# 2                   Aflou         آفلو  LAG                           16,320
# 3               Aïn Arnat    عين أرنات  SET                            5,656
# 4                Aïn Azel     عين ازال  SET                            9,261
# 5               Aïn Béïda  عين البيضاء  OEB                           42,578
# ..                    ...          ...  ...                              ...
# 176            Tizi Ouzou      تيزىوزو  TIZ                           38,979
# 177  Tlemcen ( Tilimsen )       تلمسان  TLE                          109,408
# 178                 Tolga        طولقة  BIS                           14,921
# 179             Touggourt        توغرة  OUA                           42,519
# 180        Zighout Youcef   زيغود يوسف  CON                            9,877
#
# ...

# %%
df.Area.unique()
# Out:
# array(['0'], dtype=object)

# %%
df = df.drop(columns=['Area'])

# %%
df
# Out:
# 0                    Name       Native Adm. Population Census (C) 1977-02-12  \
# 1                   Adrar        أدرار  ADR                           11,956
# 2                   Aflou         آفلو  LAG                           16,320
# 3               Aïn Arnat    عين أرنات  SET                            5,656
# 4                Aïn Azel     عين ازال  SET                            9,261
# 5               Aïn Béïda  عين البيضاء  OEB                           42,578
# ..                    ...          ...  ...                              ...
# 176            Tizi Ouzou      تيزىوزو  TIZ                           38,979
# 177  Tlemcen ( Tilimsen )       تلمسان  TLE                          109,408
# 178                 Tolga        طولقة  BIS                           14,921
# 179             Touggourt        توغرة  OUA                           42,519
# 180        Zighout Youcef   زيغود يوسف  CON                            9,877
#
# ...

# %%
df.isna().sum()
# Out:
# 0
# Name                                0
# Native                              3
# Adm.                                0
# Population Census (C) 1977-02-12    0
# Population Census (C) 1987-03-20    0
# Population Census (C) 1998-08-28    0
# Population Census (C) 2008-04-14    0
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
# 0                    Name       Native Adm. Population Census (C) 1977-02-12  \
# 1                   Adrar        أدرار  ADR                           11,956
# 2                   Aflou         آفلو  LAG                           16,320
# 3               Aïn Arnat    عين أرنات  SET                            5,656
# 4                Aïn Azel     عين ازال  SET                            9,261
# 5               Aïn Béïda  عين البيضاء  OEB                           42,578
# ..                    ...          ...  ...                              ...
# 176            Tizi Ouzou      تيزىوزو  TIZ                           38,979
# 177  Tlemcen ( Tilimsen )       تلمسان  TLE                          109,408
# 178                 Tolga        طولقة  BIS                           14,921
# 179             Touggourt        توغرة  OUA                           42,519
# 180        Zighout Youcef   زيغود يوسف  CON                            9,877
#
# ...

# %%
import numpy as np

# %%
df['Population Census (C) 1977-02-12'] = df['Population Census (C) 1977-02-12'].replace('...',np.NaN)
df['Population Census (C) 1987-03-20'] = df['Population Census (C) 1987-03-20'].replace('...',np.NaN)
df['Population Census (C) 1998-08-28'] = df['Population Census (C) 1998-08-28'].replace('...',np.NaN)
df['Population Census (C) 2008-04-14'] = df['Population Census (C) 2008-04-14'].replace('...',np.NaN)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22212\3669314336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population Census (C) 1977-02-12'] = df['Population Census (C) 1977-02-12'].replace('...',np.NaN)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22212\3669314336.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population Census (C) 1987-03-20'] = df['Population Census (C) 1987-03-20'].replace('...',np.NaN)
# ...

# %%
df
# Out:
# 0                    Name       Native Adm. Population Census (C) 1977-02-12  \
# 1                   Adrar        أدرار  ADR                           11,956
# 2                   Aflou         آفلو  LAG                           16,320
# 3               Aïn Arnat    عين أرنات  SET                            5,656
# 4                Aïn Azel     عين ازال  SET                            9,261
# 5               Aïn Béïda  عين البيضاء  OEB                           42,578
# ..                    ...          ...  ...                              ...
# 176            Tizi Ouzou      تيزىوزو  TIZ                           38,979
# 177  Tlemcen ( Tilimsen )       تلمسان  TLE                          109,408
# 178                 Tolga        طولقة  BIS                           14,921
# 179             Touggourt        توغرة  OUA                           42,519
# 180        Zighout Youcef   زيغود يوسف  CON                            9,877
#
# ...

# %%
df.isna().sum()
# Out:
# 0
# Name                                  0
# Native                                0
# Adm.                                  0
# Population Census (C) 1977-02-12     12
# Population Census (C) 1987-03-20    100
# Population Census (C) 1998-08-28      0
# Population Census (C) 2008-04-14      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177 entries, 1 to 180
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Name                              177 non-null    object
#  1   Native                            177 non-null    object
#  2   Adm.                              177 non-null    object
#  3   Population Census (C) 1977-02-12  165 non-null    object
#  4   Population Census (C) 1987-03-20  77 non-null     object
#  5   Population Census (C) 1998-08-28  177 non-null    object
#  6   Population Census (C) 2008-04-14  177 non-null    object
# dtypes: object(7)
# memory usage: 11.1+ KB

# %%
df['Population Census (C) 1977-02-12'] = df['Population Census (C) 1977-02-12'].str.replace(',','')
df['Population Census (C) 1987-03-20'] = df['Population Census (C) 1987-03-20'].str.replace(',','')
df['Population Census (C) 1998-08-28'] = df['Population Census (C) 1998-08-28'].str.replace(',','')
df['Population Census (C) 2008-04-14'] = df['Population Census (C) 2008-04-14'].str.replace(',','')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22212\4152318902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population Census (C) 1977-02-12'] = df['Population Census (C) 1977-02-12'].str.replace(',','')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22212\4152318902.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population Census (C) 1987-03-20'] = df['Population Census (C) 1987-03-20'].str.replace(',','')
# ...

# %%
df['Population Census (C) 1977-02-12']
# Out:
# 1       11956
# 2       16320
# 3        5656
# 4        9261
# 5       42578
#         ...
# 176     38979
# 177    109408
# 178     14921
# 179     42519
# 180      9877
# Name: Population Census (C) 1977-02-12, Length: 177, dtype: object

# %%
df['Population Census (C) 1977-02-12'] = df['Population Census (C) 1977-02-12'].astype(float)
df['Population Census (C) 1987-03-20'] = df['Population Census (C) 1987-03-20'].astype(float)
df['Population Census (C) 1998-08-28'] = df['Population Census (C) 1998-08-28'].astype(float)
df['Population Census (C) 2008-04-14'] = df['Population Census (C) 2008-04-14'].astype(float)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22212\2341510075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population Census (C) 1977-02-12'] = df['Population Census (C) 1977-02-12'].astype(float)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22212\2341510075.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population Census (C) 1987-03-20'] = df['Population Census (C) 1987-03-20'].astype(float)
# ...

# %%
df
# Out:
# 0                    Name       Native Adm.  Population Census (C) 1977-02-12  \
# 1                   Adrar        أدرار  ADR                           11956.0
# 2                   Aflou         آفلو  LAG                           16320.0
# 3               Aïn Arnat    عين أرنات  SET                            5656.0
# 4                Aïn Azel     عين ازال  SET                            9261.0
# 5               Aïn Béïda  عين البيضاء  OEB                           42578.0
# ..                    ...          ...  ...                               ...
# 176            Tizi Ouzou      تيزىوزو  TIZ                           38979.0
# 177  Tlemcen ( Tilimsen )       تلمسان  TLE                          109408.0
# 178                 Tolga        طولقة  BIS                           14921.0
# 179             Touggourt        توغرة  OUA                           42519.0
# 180        Zighout Youcef   زيغود يوسف  CON                            9877.0
#
# ...

# %%
df.describe()
# Out:
# 0      Population Census (C) 1977-02-12  Population Census (C) 1987-03-20  \
# count                      1.650000e+02                      7.700000e+01
# mean                       3.794104e+04                      8.916000e+04
# std                        1.263937e+05                      1.855295e+05
# min                        2.815000e+03                      5.286000e+03
# 25%                        1.113600e+04                      2.332900e+04
# 50%                        1.588200e+04                      5.533500e+04
# 75%                        2.817600e+04                      8.172100e+04
# max                        1.523000e+06                      1.507241e+06
#
# 0      Population Census (C) 1998-08-28  Population Census (C) 2008-04-14
# count                      1.770000e+02                      1.770000e+02
# mean                       7.391177e+04                      8.917509e+04
# std                        1.710381e+05                      1.921824e+05
# ...

# %%
import seaborn as sns

# %%
sns.displot(df['Population Census (C) 1977-02-12'])

# %%
df['Population Census (C) 1977-02-12']  = df['Population Census (C) 1977-02-12'].replace(np.NaN,df['Population Census (C) 1977-02-12'].median())
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22212\2837135259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population Census (C) 1977-02-12']  = df['Population Census (C) 1977-02-12'].replace(np.NaN,df['Population Census (C) 1977-02-12'].median())

# %%
df['Population Census (C) 1987-03-20'].isna().mean()
# Out:
# 0.5649717514124294

# %%
from matplotlib import pyplot as plt
sns.displot(df['Population Census (C) 1987-03-20'])
plt.show()

# %%
df['Population Census (C) 1987-03-20']  = df['Population Census (C) 1987-03-20'].replace(np.NaN,df['Population Census (C) 1987-03-20'].median())
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22212\4020500022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population Census (C) 1987-03-20']  = df['Population Census (C) 1987-03-20'].replace(np.NaN,df['Population Census (C) 1987-03-20'].median())

# %%
df.isna().sum()
# Out:
# 0
# Name                                0
# Native                              0
# Adm.                                0
# Population Census (C) 1977-02-12    0
# Population Census (C) 1987-03-20    0
# Population Census (C) 1998-08-28    0
# Population Census (C) 2008-04-14    0
# dtype: int64

# %%
df
# Out:
# 0                    Name       Native Adm.  Population Census (C) 1977-02-12  \
# 1                   Adrar        أدرار  ADR                           11956.0
# 2                   Aflou         آفلو  LAG                           16320.0
# 3               Aïn Arnat    عين أرنات  SET                            5656.0
# 4                Aïn Azel     عين ازال  SET                            9261.0
# 5               Aïn Béïda  عين البيضاء  OEB                           42578.0
# ..                    ...          ...  ...                               ...
# 176            Tizi Ouzou      تيزىوزو  TIZ                           38979.0
# 177  Tlemcen ( Tilimsen )       تلمسان  TLE                          109408.0
# 178                 Tolga        طولقة  BIS                           14921.0
# 179             Touggourt        توغرة  OUA                           42519.0
# 180        Zighout Youcef   زيغود يوسف  CON                            9877.0
#
# ...

# %%
df = df.rename(columns={"Population Census (C) 1977-02-12":'1977','Population Census (C) 1987-03-20':'1987','Population Census (C) 1998-08-28':'1988','Population Census (C) 2008-04-14':'2008'})

# %%
df = df.melt(id_vars=['Name','Native','Adm.'],var_name='Year',value_name='Value')

# %%
df
# Out:
#                      Name       Native Adm.  Year     Value
# 0                   Adrar        أدرار  ADR  1977   11956.0
# 1                   Aflou         آفلو  LAG  1977   16320.0
# 2               Aïn Arnat    عين أرنات  SET  1977    5656.0
# 3                Aïn Azel     عين ازال  SET  1977    9261.0
# 4               Aïn Béïda  عين البيضاء  OEB  1977   42578.0
# ..                    ...          ...  ...   ...       ...
# 703            Tizi Ouzou      تيزىوزو  TIZ  2008  104312.0
# 704  Tlemcen ( Tilimsen )       تلمسان  TLE  2008  173531.0
# 705                 Tolga        طولقة  BIS  2008   50575.0
# 706             Touggourt        توغرة  OUA  2008  143270.0
# 707        Zighout Youcef   زيغود يوسف  CON  2008   28764.0
#
# [708 rows x 5 columns]

# %%
df = df.rename(columns={'Name':'City'})

# %%
df
# Out:
#                      City       Native Adm.  Year     Value
# 0                   Adrar        أدرار  ADR  1977   11956.0
# 1                   Aflou         آفلو  LAG  1977   16320.0
# 2               Aïn Arnat    عين أرنات  SET  1977    5656.0
# 3                Aïn Azel     عين ازال  SET  1977    9261.0
# 4               Aïn Béïda  عين البيضاء  OEB  1977   42578.0
# ..                    ...          ...  ...   ...       ...
# 703            Tizi Ouzou      تيزىوزو  TIZ  2008  104312.0
# 704  Tlemcen ( Tilimsen )       تلمسان  TLE  2008  173531.0
# 705                 Tolga        طولقة  BIS  2008   50575.0
# 706             Touggourt        توغرة  OUA  2008  143270.0
# 707        Zighout Youcef   زيغود يوسف  CON  2008   28764.0
#
# [708 rows x 5 columns]

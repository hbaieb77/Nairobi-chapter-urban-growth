# %%
import pandas as pd

# %%
df = pd.read_csv("population-houseshold-kenya-data-2019.csv")

# %%
df
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0   Distribution of Population, Number of Househol...         NaN
# 1   Source: 2019 Kenya Population and Housing Cens...         NaN
# 2   https://www.knbs.or.ke/?wpdmpro=2019-kenya-pop...         NaN
# 3   Population, Households, Household size, County...         NaN
# 4                                                 NaN         NaN
# 5                                                name  Population
# 6                                               Kenya    47213282
# 7                                             Mombasa     1190987
# 8                                               Kwale      858748
# 9                                              Kilifi     1440958
# 10                                         Tana River      314710
# 11                                               Lamu      141909
# 12                                       Taita-Taveta      335747
# ...

# %% [markdown]
# ### Delete rows and change column names

# %%
df = df.drop(labels=range(0, 6), axis=0)

# %%
df = df.reset_index()
df
# Out:
#     index       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0       6            Kenya   47213282   12143913         39
# 1       7          Mombasa    1190987     378422         31
# 2       8            Kwale     858748     173176         50
# 3       9           Kilifi    1440958     298472         48
# 4      10       Tana River     314710      68242         46
# 5      11             Lamu     141909      37963         37
# 6      12     Taita-Taveta     335747      96429         35
# 7      13          Garissa     835482     141394         59
# 8      14            Wajir     775302     127932         61
# 9      15          Mandera     862079     125763         69
# 10     16         Marsabit     447150      77495         58
# 11     17           Isiolo     267997      58072         46
# 12     18             Meru    1535635     426360         36
# 13     19    Tharaka-Nithi     391303     109860         36
# 14     20             Embu     604769     182743         33
# ...

# %%
df = df.drop(columns=['index'],axis=1)

# %%
df
# Out:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0             Kenya   47213282   12143913         39
# 1           Mombasa    1190987     378422         31
# 2             Kwale     858748     173176         50
# 3            Kilifi    1440958     298472         48
# 4        Tana River     314710      68242         46
# 5              Lamu     141909      37963         37
# 6      Taita-Taveta     335747      96429         35
# 7           Garissa     835482     141394         59
# 8             Wajir     775302     127932         61
# 9           Mandera     862079     125763         69
# 10         Marsabit     447150      77495         58
# 11           Isiolo     267997      58072         46
# 12             Meru    1535635     426360         36
# 13    Tharaka-Nithi     391303     109860         36
# 14             Embu     604769     182743         33
# 15            Kitui    1130134     262942         43
# 16         Machakos    1414022     402466         35
# ...

# %%
df = df.rename(columns={'Unnamed: 0':'city','Unnamed: 1':'Population','Unnamed: 2':'No.of Households','Unnamed: 3':'Avg Household size'})

# %%
df
# Out:
#                city Population No.of Households Avg Household size
# 0             Kenya   47213282         12143913                 39
# 1           Mombasa    1190987           378422                 31
# 2             Kwale     858748           173176                 50
# 3            Kilifi    1440958           298472                 48
# 4        Tana River     314710            68242                 46
# 5              Lamu     141909            37963                 37
# 6      Taita-Taveta     335747            96429                 35
# 7           Garissa     835482           141394                 59
# 8             Wajir     775302           127932                 61
# 9           Mandera     862079           125763                 69
# 10         Marsabit     447150            77495                 58
# 11           Isiolo     267997            58072                 46
# 12             Meru    1535635           426360                 36
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city                48 non-null     object
#  1   Population          48 non-null     object
#  2   No.of Households    48 non-null     object
#  3   Avg Household size  48 non-null     object
# dtypes: object(4)
# memory usage: 1.6+ KB

# %%
# Change dtype
df['Population'] = df['Population'].astype('int')
df['No.of Households'] = df['No.of Households'].astype('int')
df['Avg Household size'] = df['Avg Household size'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city                48 non-null     object
#  1   Population          48 non-null     int32
#  2   No.of Households    48 non-null     int32
#  3   Avg Household size  48 non-null     int32
# dtypes: int32(3), object(1)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#          Population  No.of Households  Avg Household size
# count  4.800000e+01      4.800000e+01           48.000000
# mean   1.967220e+06      5.059964e+05           42.250000
# std    6.704047e+06      1.731138e+06            8.760404
# min    1.419090e+05      3.796300e+04           29.000000
# 25%    6.054148e+05      1.422370e+05           35.000000
# 50%    8.918595e+05      2.051120e+05           42.000000
# 75%    1.150202e+06      3.057208e+05           46.250000
# max    4.721328e+07      1.214391e+07           69.000000

# %%
df
# Out:
#                city  Population  No.of Households  Avg Household size
# 0             Kenya    47213282          12143913                  39
# 1           Mombasa     1190987            378422                  31
# 2             Kwale      858748            173176                  50
# 3            Kilifi     1440958            298472                  48
# 4        Tana River      314710             68242                  46
# 5              Lamu      141909             37963                  37
# 6      Taita-Taveta      335747             96429                  35
# 7           Garissa      835482            141394                  59
# 8             Wajir      775302            127932                  61
# 9           Mandera      862079            125763                  69
# 10         Marsabit      447150             77495                  58
# 11           Isiolo      267997             58072                  46
# ...

# %%
df=df.iloc[1:]

# %%
df['country'] = 'Kenya'
# Out:
# C:\Users\riley\AppData\Local\Temp\ipykernel_84684\4207019988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country'] = 'Kenya'

# %%
df['year'] = '2019'
# Out:
# C:\Users\riley\AppData\Local\Temp\ipykernel_84684\2137184485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = '2019'

# %%
df
# Out:
#                city  Population  No.of Households  Avg Household size country  \
# 1           Mombasa     1190987            378422                  31   Kenya
# 2             Kwale      858748            173176                  50   Kenya
# 3            Kilifi     1440958            298472                  48   Kenya
# 4        Tana River      314710             68242                  46   Kenya
# 5              Lamu      141909             37963                  37   Kenya
# 6      Taita-Taveta      335747             96429                  35   Kenya
# 7           Garissa      835482            141394                  59   Kenya
# 8             Wajir      775302            127932                  61   Kenya
# 9           Mandera      862079            125763                  69   Kenya
# 10         Marsabit      447150             77495                  58   Kenya
# 11           Isiolo      267997             58072                  46   Kenya
# ...

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
import numpy as np
import scipy.stats as stats
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\riley\\OneDrive\\Desktop\\Urban Developing Omdena\\population_luanda_1950-2035.csv")
df
# Out:
#           date   Population   Annual Change
# 0   12/31/1950       138000             NaN
# 1   12/31/1951       145000            5.07
# 2   12/31/1952       152000            4.83
# 3   12/31/1953       159000            4.61
# 4   12/31/1954       166000            4.40
# ..         ...          ...             ...
# 81  12/31/2031     12583000            3.74
# 82  12/31/2032     13047000            3.69
# 83  12/31/2033     13521000            3.63
# 84  12/31/2034     14004000            3.57
# 85  12/31/2035     14495000            3.51
#
# [86 rows x 3 columns]

# %%
df = df.rename(columns={
    ' Population': 'Population',
    ' Annual Change': 'Annual Change'
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           86 non-null     object
#  1   Population     86 non-null     int64
#  2   Annual Change  85 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#          Population  Annual Change
# count  8.600000e+01      85.000000
# mean   3.791105e+06       5.638824
# std    4.196739e+06       1.464843
# min    1.380000e+05       3.440000
# 25%    4.952500e+05       4.290000
# 50%    1.760000e+06       5.300000
# 75%    6.691500e+06       6.510000
# max    1.449500e+07       7.970000

# %%
df.isna().sum()
# Out:
# date             0
# Population       0
# Annual Change    1
# dtype: int64

# %%
median = df.dropna().median()
# fill in missing value with median
df = df.fillna(median)

# %%
df
# Out:
#           date  Population  Annual Change
# 0   12/31/1950      138000           5.30
# 1   12/31/1951      145000           5.07
# 2   12/31/1952      152000           4.83
# 3   12/31/1953      159000           4.61
# 4   12/31/1954      166000           4.40
# ..         ...         ...            ...
# 81  12/31/2031    12583000           3.74
# 82  12/31/2032    13047000           3.69
# 83  12/31/2033    13521000           3.63
# 84  12/31/2034    14004000           3.57
# 85  12/31/2035    14495000           3.51
#
# [86 rows x 3 columns]

# %%
sns.boxplot(df['Annual Change'])
plt.show()
sns.boxplot(df['Population'])
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['Year'] = df['date'].dt.year

# %%
df
# Out:
#          date  Population  Annual Change  Year
# 0  1950-12-31      138000           5.30  1950
# 1  1951-12-31      145000           5.07  1951
# 2  1952-12-31      152000           4.83  1952
# 3  1953-12-31      159000           4.61  1953
# 4  1954-12-31      166000           4.40  1954
# ..        ...         ...            ...   ...
# 81 2031-12-31    12583000           3.74  2031
# 82 2032-12-31    13047000           3.69  2032
# 83 2033-12-31    13521000           3.63  2033
# 84 2034-12-31    14004000           3.57  2034
# 85 2035-12-31    14495000           3.51  2035
#
# [86 rows x 4 columns]

# %%
df['Country'] ='Angola'

# %%
df['City'] = 'Luanda'

# %%
df = df.drop('date', axis=1)

# %%
df
# Out:
#     Population  Annual Change  Year Country    City
# 0       138000           5.30  1950  Angola  Luanda
# 1       145000           5.07  1951  Angola  Luanda
# 2       152000           4.83  1952  Angola  Luanda
# 3       159000           4.61  1953  Angola  Luanda
# 4       166000           4.40  1954  Angola  Luanda
# ..         ...            ...   ...     ...     ...
# 81    12583000           3.74  2031  Angola  Luanda
# 82    13047000           3.69  2032  Angola  Luanda
# 83    13521000           3.63  2033  Angola  Luanda
# 84    14004000           3.57  2034  Angola  Luanda
# 85    14495000           3.51  2035  Angola  Luanda
#
# [86 rows x 5 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv('south-sudan_osm.csv')
df1 = pd.read_csv('nigeria_osm.csv')
df2 = pd.read_csv('morocco_osm.csv')
df3 = pd.read_csv('kenya_osm.csv')
df4 = pd.read_csv('kano-nigeria_osm.csv')
df5 = pd.read_csv('giza-egypt_osm.csv')
df6 = pd.read_csv('ethiopia_osm.csv')
df7 = pd.read_csv('DRC_osm.csv')
df8 = pd.read_csv('douala-cameroon_osm.csv')
df9 = pd.read_csv('cameroon_osm.csv')
df10 = pd.read_csv('angola_osm.csv')
df11 = pd.read_csv('alexandria-giza_osm.csv')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25488\4179938413.py:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv('kano-nigeria_osm.csv')

# %%
df.head()
# Out:
#   element_type       osmid amenity     building  \
# 0         node  1858448490     NaN          yes
# 1         node  1858480753     NaN       office
# 2         node  1858480760     NaN       office
# 3         node  1916678620     NaN  manufacture
# 4         node  1916678622     NaN       office
#
#                                                name tourism  \
# 0                                   السفارة التركية     NaN
# 1                                             ستراك     NaN
# 2                                        دال موتورز     NaN
# 3                                    Shirouq Paints     NaN
# 4  High council for Environment & Rural Development     NaN
#
#                         geometry
# 0  POINT (32.5378842 15.6047409)
# 1  POINT (32.5756528 15.5344693)
# 2  POINT (32.5760862 15.5345654)
# 3  POINT (32.5123226 15.5877683)
# 4   POINT (32.512757 15.5901386)

# %%
df1.head()
# Out:
#   element_type      osmid amenity building name tourism  \
# 0          way  602684394     NaN      yes  NaN     NaN
# 1          way  602684395     NaN      yes  NaN     NaN
# 2          way  602684396     NaN      yes  NaN     NaN
# 3          way  602684397     NaN      yes  NaN     NaN
# 4          way  602684398     NaN      yes  NaN     NaN
#
#                                             geometry
# 0  POLYGON ((4.0162647 6.4327248, 4.0162976 6.432...
# 1  POLYGON ((4.0144622 6.4347185, 4.0143315 6.434...
# 2  POLYGON ((4.0142584 6.4343666, 4.0143217 6.434...
# 3  POLYGON ((4.0170424 6.4320334, 4.0165639 6.432...
# 4  POLYGON ((4.0167059 6.4313307, 4.016321 6.4314...

# %%
df2.head()
# Out:
#   element_type       osmid           amenity building  \
# 0         node   257474936           college   school
# 1         node  1980770242               NaN   office
# 2         node  2179576314               NaN      yes
# 3         node  2378015034  place_of_worship      yes
# 4         node  2378015035  place_of_worship      yes
#
#                                 name tourism                       geometry
# 0                                NaN     NaN  POINT (-7.5936521 33.5806507)
# 1  Office National de la Pêche - ONP     NaN   POINT (-7.5973929 33.597409)
# 2                Samsung Electronics     NaN   POINT (-7.643119 33.5400131)
# 3                   mosquée al ahali     NaN  POINT (-7.6539831 33.5156769)
# 4                    Mosquée attawba     NaN   POINT (-7.648337 33.5103663)

# %%
df3.head()
# Out:
#   element_type      osmid amenity      building                name tourism  \
# 0         node   30215039     NaN  construction    High Point Hotel   hotel
# 1         node  543401082     NaN        office  MS ActionAid Kenya     NaN
# 2         node  582828526     NaN           yes  Old Petrol Station     NaN
# 3         node  582828534     NaN           yes          Log Houses     NaN
# 4         node  612007115     NaN        public          Dcs Office     NaN
#
#                         geometry
# 0  POINT (36.8163654 -1.2942548)
# 1  POINT (36.7920136 -1.2644397)
# 2  POINT (36.8130471 -1.2334392)
# 3  POINT (36.8157054 -1.2362965)
# 4  POINT (36.7878934 -1.3060453)

# %%
df4.head()
# Out:
#   element_type      osmid   amenity  building                    name tourism  \
# 0          way  288807990       NaN  hospital      Karasa Health Post     NaN
# 1          way  288807991       NaN  hospital  Dukar Goma Health Post     NaN
# 2          way  288807998       NaN  hospital     Zainabi Health Post     NaN
# 3          way  288808001  hospital       yes                     NaN     NaN
# 4          way  288808002  hospital       yes                     NaN     NaN
#
#                                             geometry
# 0  POLYGON ((8.688331 10.8163922, 8.688411 10.816...
# 1  POLYGON ((8.624397 10.7601074, 8.6244678 10.76...
# 2  POLYGON ((8.771032099999999 10.7889685, 8.7711...
# 3  POLYGON ((8.727587099999999 10.7501521, 8.7278...
# 4  POLYGON ((8.727663700000001 10.7500826, 8.7277...

# %%
df5.head()
# Out:
#   element_type      osmid amenity building         name tourism  \
# 0          way   83688273     NaN      yes  فندق الرمال   hotel
# 1          way  360129078     NaN      yes          NaN     NaN
# 2          way   83688271     NaN      yes          NaN     NaN
# 3          way   83688272    cafe      yes    Cafe Saad     NaN
# 4          way  750559942     NaN    house          NaN     NaN
#
#                                             geometry
# 0  POLYGON ((28.8129261 28.3432638, 28.8131411 28...
# 1  POLYGON ((28.8141329 28.3450492, 28.8141452 28...
# 2  POLYGON ((28.6986147 28.0338249, 28.6982599 28...
# 3  POLYGON ((28.696775 28.0319676, 28.6965363 28....
# 4  POLYGON ((28.6402842 28.0261294, 28.6402869 28...

# %%
df6.head()
# Out:
#   element_type       osmid amenity building  \
# 0         node   765100140     NaN      yes
# 1         node   768599457     NaN      yes
# 2         node   838832149     NaN      yes
# 3         node   846942793     NaN      yes
# 4         node  1424008438     NaN      yes
#
#                                             name tourism  \
# 0                                            NaN     NaN
# 1                             Nigat & her family     NaN
# 2                                  Yezed's Plaza     NaN
# 3  Kirkos Sub City Kebele 12/13/25 Public Center     NaN
# 4                                 GIZ Guesthouse     NaN
#
#                                geometry
# 0  POINT (38.8097395 8.997288899999999)
# 1  POINT (38.7746227 9.032417799999999)
# 2          POINT (38.8032564 9.0003937)
# 3          POINT (38.7581212 9.0039757)
# 4          POINT (38.7626342 8.9998089)

# %%
df7.head()
# Out:
#   element_type      osmid amenity building name tourism  \
# 0          way  796687773     NaN      yes  NaN     NaN
# 1          way  796687774     NaN      yes  NaN     NaN
# 2          way  796687775     NaN      yes  NaN     NaN
# 3          way  796687776     NaN      yes  NaN     NaN
# 4          way  796687777     NaN      yes  NaN     NaN
#
#                                             geometry
# 0  POLYGON ((15.7652073 -4.8853913, 15.7652088 -4...
# 1  POLYGON ((15.7652035 -4.885459, 15.7652033 -4....
# 2  POLYGON ((15.7655197 -4.8853766, 15.765559 -4....
# 3  POLYGON ((15.7651815 -4.885513, 15.7651903 -4....
# 4  POLYGON ((15.7655466 -4.8855152, 15.7655586 -4...

# %%
df8.head()
# Out:
#   element_type       osmid amenity building  \
# 0         node  2429216285     NaN      yes
# 1         node  3779375469     NaN  station
# 2         node  4379369974    bank      yes
# 3         node  4382170113     NaN      yes
# 4         node  4382170115     NaN      yes
#
#                                   name tourism  \
# 0  Délégation régional ELECAM Littoral     NaN
# 1                     Douala Bessengué     NaN
# 2                        Express Union     NaN
# 3                   Auto-école Général     NaN
# 4                                  cbc     NaN
#
#                               geometry
# 0          POINT (9.7086144 4.0617921)
# 1  POINT (9.711143399999999 4.0535804)
# 2          POINT (9.7528688 4.1001541)
# 3          POINT (9.7464367 4.0757753)
# 4           POINT (9.751439 4.0772682)

# %%
df9.head()
# Out:
#   element_type       osmid           amenity building  \
# 0         node  1993204223               NaN      yes
# 1         node  1993239384  bureau_de_change      yes
# 2         node  2033820122               NaN   office
# 3         node  2033829769               NaN   public
# 4         node  2274991000               NaN      yes
#
#                                                 name tourism  \
# 0                                              ringo     NaN
# 1                                   Express exchange     NaN
# 2                                       Groupe BANGA     NaN
# 3  Service de Coopération et d'Action Culturelle ...     NaN
# 4                                                NaN     NaN
#
#                        geometry
# 0  POINT (11.5187125 3.8748142)
# 1  POINT (11.5200051 3.8643665)
# 2  POINT (11.5036155 3.8624189)
# 3  POINT (11.5200461 3.8628028)
# 4   POINT (11.5219284 3.920781)

# %%
df10.head()
# Out:
#   element_type       osmid amenity building                            name  \
# 0         node  1301788510     NaN      yes                      CPC Africa
# 1         node  1635379678     NaN   retail                         Chamavo
# 2         node  1635402581     NaN      yes  Rádio Nacional de Angola (RNA)
# 3         node  1635405212     NaN      yes                   Vauco Express
# 4         node  1731541041     NaN   office                             SOS
#
#   tourism                               geometry
# 0     NaN          POINT (13.2124267 -8.8923772)
# 1     NaN  POINT (13.2451325 -8.823510000000001)
# 2     NaN  POINT (13.2390975 -8.830591999999999)
# 3     NaN  POINT (13.2424602 -8.828140700000001)
# 4     NaN           POINT (13.2414545 -8.806772)

# %%
df11.head()
# Out:
#   element_type       osmid           amenity building name tourism  \
# 0         node  2713762426  place_of_worship   mosque  NaN     NaN
# 1          way  1113750189               NaN      yes  NaN     NaN
# 2          way    97807716               NaN     tank  NaN     NaN
# 3          way    97807717               NaN     tank  NaN     NaN
# 4          way    97807718               NaN     tank  NaN     NaN
#
#                                             geometry
# 0                      POINT (29.6568005 30.7690299)
# 1  POLYGON ((29.7595699 30.7173269, 29.7596156 30...
# 2  POLYGON ((29.6758212 31.054685, 29.675813 31.0...
# 3  POLYGON ((29.6792422 31.0471222, 29.679196 31....
# 4  POLYGON ((29.6778136 31.0444475, 29.6777228 31...

# %%
df.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.993711
# building        0.000000
# name            0.992407
# tourism         0.999923
# geometry        0.000000
# dtype: float64

# %%
df1.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.998872
# building        0.000000
# name            0.996796
# tourism         0.999927
# geometry        0.000000
# dtype: float64

# %%
df2.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.981799
# building        0.000000
# name            0.971788
# tourism         0.998869
# geometry        0.000000
# dtype: float64

# %%
df3.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.998471
# building        0.000000
# name            0.992729
# tourism         0.999520
# geometry        0.000000
# dtype: float64

# %%
df6.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.992758
# building        0.000000
# name            0.955519
# tourism         0.997141
# geometry        0.000000
# dtype: float64

# %%
df4.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.998399
# building        0.000000
# name            0.996513
# tourism         0.999992
# geometry        0.000000
# dtype: float64

# %%
df5.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.987523
# building        0.000000
# name            0.973397
# tourism         0.997549
# geometry        0.000000
# dtype: float64

# %%
df7.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.993307
# building        0.000000
# name            0.989982
# tourism         0.999688
# geometry        0.000000
# dtype: float64

# %%
df8.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.998779
# building        0.000000
# name            0.996816
# tourism         0.999647
# geometry        0.000000
# dtype: float64

# %%
df9.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.995667
# building        0.000000
# name            0.992102
# tourism         0.999446
# geometry        0.000000
# dtype: float64

# %%
df10.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.978802
# building        0.000000
# name            0.923303
# tourism         0.996320
# geometry        0.000000
# dtype: float64

# %%
df11.isna().mean()
# Out:
# element_type    0.000000
# osmid           0.000000
# amenity         0.987122
# building        0.000000
# name            0.974619
# tourism         0.996374
# geometry        0.000000
# dtype: float64

# %%
df = df.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df1 = df1.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df2 = df2.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df3 = df3.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df4 = df4.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df5 = df5.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df6 = df6.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df7 = df7.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df8 = df8.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df9 = df9.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df10 = df10.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df11 = df11.drop(columns=['amenity','name','tourism'],axis=1)

# %%
df
# Out:
#       element_type       osmid     building  \
# 0             node  1858448490          yes
# 1             node  1858480753       office
# 2             node  1858480760       office
# 3             node  1916678620  manufacture
# 4             node  1916678622       office
# ...            ...         ...          ...
# 65187     relation    12865873          yes
# 65188     relation    14152587          yes
# 65189     relation    14161230          yes
# 65190     relation    14277541          yes
# 65191     relation    14877923          yes
#
#                                                 geometry
# 0                          POINT (32.5378842 15.6047409)
# 1                          POINT (32.5756528 15.5344693)
# 2                          POINT (32.5760862 15.5345654)
# 3                          POINT (32.5123226 15.5877683)
# 4                           POINT (32.512757 15.5901386)
# ...                                                  ...
# ...

# %%
df['Country'] = 'South-sudan'
df1['Country'] = 'Nigeria'
df2['Country'] = 'Morocco'
df3['Country'] = 'Kenya'
df6['Country'] = 'Ethiopia'
df7['Country'] = 'DRC'
df9['Country'] = 'Cameroon'
df10['Country'] = 'Angola'
df11['City'] = 'Alexandria'
df11['Country'] = 'Egypt'
df4['City'] = 'Kano'
df4['Country'] = 'Nigeria'
df5['City'] = 'Giza'
df5['Country'] = 'Egypt'
df8['City'] = 'Douala'
df8['Country'] = 'Cameroon'

# %%
df
# Out:
#       element_type       osmid     building  \
# 0             node  1858448490          yes
# 1             node  1858480753       office
# 2             node  1858480760       office
# 3             node  1916678620  manufacture
# 4             node  1916678622       office
# ...            ...         ...          ...
# 65187     relation    12865873          yes
# 65188     relation    14152587          yes
# 65189     relation    14161230          yes
# 65190     relation    14277541          yes
# 65191     relation    14877923          yes
#
#                                                 geometry      Country
# 0                          POINT (32.5378842 15.6047409)  South-sudan
# 1                          POINT (32.5756528 15.5344693)  South-sudan
# 2                          POINT (32.5760862 15.5345654)  South-sudan
# 3                          POINT (32.5123226 15.5877683)  South-sudan
# 4                           POINT (32.512757 15.5901386)  South-sudan
# ...

# %%
df2
# Out:
#       element_type       osmid    building  \
# 0             node   257474936      school
# 1             node  1980770242      office
# 2             node  2179576314         yes
# 3             node  2378015034         yes
# 4             node  2378015035         yes
# ...            ...         ...         ...
# 36256     relation    14321278     stadium
# 36257     relation    14386229  apartments
# 36258     relation    14626637         yes
# 36259     relation    14713098  apartments
# 36260     relation    15624425         yes
#
#                                                 geometry  Country
# 0                          POINT (-7.5936521 33.5806507)  Morocco
# 1                           POINT (-7.5973929 33.597409)  Morocco
# 2                           POINT (-7.643119 33.5400131)  Morocco
# 3                          POINT (-7.6539831 33.5156769)  Morocco
# 4                           POINT (-7.648337 33.5103663)  Morocco
# ...

# %%
df3
# Out:
#        element_type      osmid      building  \
# 0              node   30215039  construction
# 1              node  543401082        office
# 2              node  582828526           yes
# 3              node  582828534           yes
# 4              node  612007115        public
# ...             ...        ...           ...
# 387141     relation   14354720           yes
# 387142     relation   14401782           yes
# 387143     relation   14482907           yes
# 387144     relation   14489408           yes
# 387145     relation   15477734           yes
#
#                                                  geometry Country
# 0                           POINT (36.8163654 -1.2942548)   Kenya
# 1                           POINT (36.7920136 -1.2644397)   Kenya
# 2                           POINT (36.8130471 -1.2334392)   Kenya
# 3                           POINT (36.8157054 -1.2362965)   Kenya
# 4                           POINT (36.7878934 -1.3060453)   Kenya
# ...

# %%
df4
# Out:
#        element_type      osmid  building  \
# 0               way  288807990  hospital
# 1               way  288807991  hospital
# 2               way  288807998  hospital
# 3               way  288808001       yes
# 4               way  288808002       yes
# ...             ...        ...       ...
# 381666          way  859018102       yes
# 381667          way  859018508       yes
# 381668          way  859020900       yes
# 381669          way  859021419       yes
# 381670     relation    3876135  hospital
#
#                                                  geometry  City  Country
# 0       POLYGON ((8.688331 10.8163922, 8.688411 10.816...  Kano  Nigeria
# 1       POLYGON ((8.624397 10.7601074, 8.6244678 10.76...  Kano  Nigeria
# 2       POLYGON ((8.771032099999999 10.7889685, 8.7711...  Kano  Nigeria
# 3       POLYGON ((8.727587099999999 10.7501521, 8.7278...  Kano  Nigeria
# 4       POLYGON ((8.727663700000001 10.7500826, 8.7277...  Kano  Nigeria
# ...

# %%
df5
# Out:
#       element_type      osmid building  \
# 0              way   83688273      yes
# 1              way  360129078      yes
# 2              way   83688271      yes
# 3              way   83688272      yes
# 4              way  750559942    house
# ...            ...        ...      ...
# 22436          way  261441099      yes
# 22437          way  261441104      yes
# 22438          way  285116637      yes
# 22439          way  285116638      yes
# 22440          way  285116654      yes
#
#                                                 geometry  City Country
# 0      POLYGON ((28.8129261 28.3432638, 28.8131411 28...  Giza   Egypt
# 1      POLYGON ((28.8141329 28.3450492, 28.8141452 28...  Giza   Egypt
# 2      POLYGON ((28.6986147 28.0338249, 28.6982599 28...  Giza   Egypt
# 3      POLYGON ((28.696775 28.0319676, 28.6965363 28....  Giza   Egypt
# 4      POLYGON ((28.6402842 28.0261294, 28.6402869 28...  Giza   Egypt
# ...

# %%
df6
# Out:
#       element_type       osmid  building  \
# 0             node   765100140       yes
# 1             node   768599457       yes
# 2             node   838832149       yes
# 3             node   846942793       yes
# 4             node  1424008438       yes
# ...            ...         ...       ...
# 26231     relation    14468095       yes
# 26232     relation    14468096       yes
# 26233     relation    14583643  hospital
# 26234     relation    14584565       yes
# 26235     relation    14768764       yes
#
#                                                 geometry   Country
# 0                   POINT (38.8097395 8.997288899999999)  Ethiopia
# 1                   POINT (38.7746227 9.032417799999999)  Ethiopia
# 2                           POINT (38.8032564 9.0003937)  Ethiopia
# 3                           POINT (38.7581212 9.0039757)  Ethiopia
# 4                           POINT (38.7626342 8.9998089)  Ethiopia
# ...

# %%
df7
# Out:
#        element_type      osmid building  \
# 0               way  796687773      yes
# 1               way  796687774      yes
# 2               way  796687775      yes
# 3               way  796687776      yes
# 4               way  796687777      yes
# ...             ...        ...      ...
# 432110     relation   14929848      yes
# 432111     relation   14950737      yes
# 432112     relation   14950756      yes
# 432113     relation   15096177      yes
# 432114     relation   15519146      yes
#
#                                                  geometry Country
# 0       POLYGON ((15.7652073 -4.8853913, 15.7652088 -4...     DRC
# 1       POLYGON ((15.7652035 -4.885459, 15.7652033 -4....     DRC
# 2       POLYGON ((15.7655197 -4.8853766, 15.765559 -4....     DRC
# 3       POLYGON ((15.7651815 -4.885513, 15.7651903 -4....     DRC
# 4       POLYGON ((15.7655466 -4.8855152, 15.7655586 -4...     DRC
# ...                                                   ...     ...
# ...

# %%
df8
# Out:
#        element_type       osmid building  \
# 0              node  2429216285      yes
# 1              node  3779375469  station
# 2              node  4379369974      yes
# 3              node  4382170113      yes
# 4              node  4382170115      yes
# ...             ...         ...      ...
# 280125     relation    11740709      yes
# 280126     relation    12043565      yes
# 280127     relation    12106040      yes
# 280128     relation    13654754  stadium
# 280129     relation    15510530   public
#
#                                                  geometry    City   Country
# 0                             POINT (9.7086144 4.0617921)  Douala  Cameroon
# 1                     POINT (9.711143399999999 4.0535804)  Douala  Cameroon
# 2                             POINT (9.7528688 4.1001541)  Douala  Cameroon
# 3                             POINT (9.7464367 4.0757753)  Douala  Cameroon
# 4                              POINT (9.751439 4.0772682)  Douala  Cameroon
# ...

# %%
df9
# Out:
#        element_type       osmid building  \
# 0              node  1993204223      yes
# 1              node  1993239384      yes
# 2              node  2033820122   office
# 3              node  2033829769   public
# 4              node  2274991000      yes
# ...             ...         ...      ...
# 261705     relation    12111861      yes
# 261706     relation    12333978      yes
# 261707     relation    13129663   public
# 261708     relation    13129874      yes
# 261709     relation    14480901      yes
#
#                                                  geometry   Country
# 0                            POINT (11.5187125 3.8748142)  Cameroon
# 1                            POINT (11.5200051 3.8643665)  Cameroon
# 2                            POINT (11.5036155 3.8624189)  Cameroon
# 3                            POINT (11.5200461 3.8628028)  Cameroon
# 4                             POINT (11.5219284 3.920781)  Cameroon
# ...

# %%
df10
# Out:
#      element_type       osmid  building  \
# 0            node  1301788510       yes
# 1            node  1635379678    retail
# 2            node  1635402581       yes
# 3            node  1635405212       yes
# 4            node  1731541041    office
# ...           ...         ...       ...
# 6788     relation    10755449       yes
# 6789     relation    11200899       yes
# 6790     relation    11356489  hospital
# 6791     relation    11371735       yes
# 6792     relation    11507784       yes
#
#                                                geometry Country
# 0                         POINT (13.2124267 -8.8923772)  Angola
# 1                 POINT (13.2451325 -8.823510000000001)  Angola
# 2                 POINT (13.2390975 -8.830591999999999)  Angola
# 3                 POINT (13.2424602 -8.828140700000001)  Angola
# 4                          POINT (13.2414545 -8.806772)  Angola
# ...                                                 ...     ...
# ...

# %%
df11
# Out:
#       element_type       osmid building  \
# 0             node  2713762426   mosque
# 1              way  1113750189      yes
# 2              way    97807716     tank
# 3              way    97807717     tank
# 4              way    97807718     tank
# ...            ...         ...      ...
# 15991     relation     9168341      yes
# 15992     relation     9188070      yes
# 15993     relation     9188072      yes
# 15994          way   669686457      yes
# 15995          way  1113749088      yes
#
#                                                 geometry        City Country
# 0                          POINT (29.6568005 30.7690299)  Alexandria   Egypt
# 1      POLYGON ((29.7595699 30.7173269, 29.7596156 30...  Alexandria   Egypt
# 2      POLYGON ((29.6758212 31.054685, 29.675813 31.0...  Alexandria   Egypt
# 3      POLYGON ((29.6792422 31.0471222, 29.679196 31....  Alexandria   Egypt
# 4      POLYGON ((29.6778136 31.0444475, 29.6777228 31...  Alexandria   Egypt
# ...

# %%
df12 = pd.read_csv('south-africa_osm.csv')

# %%
df12
# Out:
#   element_type      osmid     amenity building  \
# 0          way  143101443  courthouse      yes
#
#                                                 name  \
# 0  High Court, South Gauteng Local Division, Joha...
#
#                                             geometry
# 0  POLYGON ((28.0458118 -26.2018877, 28.0453645 -...

# %%
df12 = df12.drop(columns=['amenity','name'],axis=1)

# %%
df12
# Out:
#   element_type      osmid building  \
# 0          way  143101443      yes
#
#                                             geometry
# 0  POLYGON ((28.0458118 -26.2018877, 28.0453645 -...

# %%
df12['Country'] = 'South-africa'

# %%
final_data = pd.concat([df,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12])

# %%
final_data = final_data.reset_index()

# %%
final_data
# Out:
#          index element_type       osmid     building  \
# 0            0         node  1858448490          yes
# 1            1         node  1858480753       office
# 2            2         node  1858480760       office
# 3            3         node  1916678620  manufacture
# 4            4         node  1916678622       office
# ...        ...          ...         ...          ...
# 2301436  15992     relation     9188070          yes
# 2301437  15993     relation     9188072          yes
# 2301438  15994          way   669686457          yes
# 2301439  15995          way  1113749088          yes
# 2301440      0          way   143101443          yes
#
#                                                   geometry       Country  \
# 0                            POINT (32.5378842 15.6047409)   South-sudan
# 1                            POINT (32.5756528 15.5344693)   South-sudan
# 2                            POINT (32.5760862 15.5345654)   South-sudan
# ...

# %%
final_data = final_data.drop(columns=['index'])

# %%
final_data
# Out:
#         element_type       osmid     building  \
# 0               node  1858448490          yes
# 1               node  1858480753       office
# 2               node  1858480760       office
# 3               node  1916678620  manufacture
# 4               node  1916678622       office
# ...              ...         ...          ...
# 2301436     relation     9188070          yes
# 2301437     relation     9188072          yes
# 2301438          way   669686457          yes
# 2301439          way  1113749088          yes
# 2301440          way   143101443          yes
#
#                                                   geometry       Country  \
# 0                            POINT (32.5378842 15.6047409)   South-sudan
# 1                            POINT (32.5756528 15.5344693)   South-sudan
# 2                            POINT (32.5760862 15.5345654)   South-sudan
# 3                            POINT (32.5123226 15.5877683)   South-sudan
# ...

# %%
final_data['Year'] = '2023'

# %%
final_data
# Out:
#         element_type       osmid     building  \
# 0               node  1858448490          yes
# 1               node  1858480753       office
# 2               node  1858480760       office
# 3               node  1916678620  manufacture
# 4               node  1916678622       office
# ...              ...         ...          ...
# 2301436     relation     9188070          yes
# 2301437     relation     9188072          yes
# 2301438          way   669686457          yes
# 2301439          way  1113749088          yes
# 2301440          way   143101443          yes
#
#                                                   geometry       Country  \
# 0                            POINT (32.5378842 15.6047409)   South-sudan
# 1                            POINT (32.5756528 15.5344693)   South-sudan
# 2                            POINT (32.5760862 15.5345654)   South-sudan
# 3                            POINT (32.5123226 15.5877683)   South-sudan
# ...

# %%
final_data.Country.unique()
# Out:
# array(['South-sudan', 'Nigeria', 'Morocco', 'Kenya', 'Egypt', 'Ethiopia',
#        'DRC', 'Cameroon', 'Angola', 'South-africa'], dtype=object)

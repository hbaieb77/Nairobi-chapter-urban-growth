# %%
import pandas as pd

# %%
df = pd.read_csv('nairobi_data.csv')

# %%
df
# Out:
#     Unnamed: 0  year  GDL-%-of-women-in-50+-population-data  \
# 0            0  1992                                   38.0
# 1            1  1993                                   37.7
# 2            2  1994                                   37.3
# 3            3  1995                                   36.9
# 4            4  1996                                   36.5
# 5            5  1997                                   36.2
# 6            6  1998                                   35.8
# 7            7  1999                                   36.1
# 8            8  2000                                   36.4
# 9            9  2001                                   36.8
# 10          10  2002                                   37.1
# 11          11  2003                                   37.4
# 12          12  2004                                   38.8
# 13          13  2005                                   40.2
# 14          14  2006                                   41.6
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'GDL-%-of-women-in-50+-population-data',
#        'GDL-%-population-aged-15-65-data',
#        'GDL-%-population-aged-over-65-data',
#        'GDL-%-population-aged-under-15-data',
#        'GDL-%-population-in-urban-areas-data',
#        'GDL-Average-household-size-data', 'GDL-Dependency-ratio-data',
#        'GDL-Mean-International-Wealth-Index-(IWI)-score-of-region-data',
#        'GDL-Mean-age-at-first-birth-of-women-aged-20-50-data',
#        'GDL-Mean-age-at-first-marriage-of-women-aged-20-50-data',
#        'GDL-Mean-age-difference-partners-(husband-wife)-data',
#        'GDL-Mean-years-education-of-adults-aged-20+-data',
#        'GDL-Mean-years-education-of-adults-aged-20-39-data',
#        'GDL-Mean-years-education-of-adults-aged-25+-data',
#        'GDL-Mean-years-education-of-adults-aged-40-59-data',
#        'GDL-Mean-years-education-of-adults-aged-60+-data',
#        'GDL-Mean-years-education-of-men-aged-20+-data',
# ...

# %%
df = df.drop(columns=['Unnamed: 0'],axis=1)

# %%
df
# Out:
#     year  GDL-%-of-women-in-50+-population-data  \
# 0   1992                                   38.0
# 1   1993                                   37.7
# 2   1994                                   37.3
# 3   1995                                   36.9
# 4   1996                                   36.5
# 5   1997                                   36.2
# 6   1998                                   35.8
# 7   1999                                   36.1
# 8   2000                                   36.4
# 9   2001                                   36.8
# 10  2002                                   37.1
# 11  2003                                   37.4
# 12  2004                                   38.8
# 13  2005                                   40.2
# 14  2006                                   41.6
# 15  2007                                   43.0
# 16  2008                                   44.4
# 17  2009                                   43.2
# ...

# %%
df['Country'] = 'Kenya'

# %%
df['City'] = 'Nairobi'

# %%
df
# Out:
#     year  GDL-%-of-women-in-50+-population-data  \
# 0   1992                                   38.0
# 1   1993                                   37.7
# 2   1994                                   37.3
# 3   1995                                   36.9
# 4   1996                                   36.5
# 5   1997                                   36.2
# 6   1998                                   35.8
# 7   1999                                   36.1
# 8   2000                                   36.4
# 9   2001                                   36.8
# 10  2002                                   37.1
# 11  2003                                   37.4
# 12  2004                                   38.8
# 13  2005                                   40.2
# 14  2006                                   41.6
# 15  2007                                   43.0
# 16  2008                                   44.4
# 17  2009                                   43.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 37 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   year                                                            26 non-null     int64
#  1   GDL-%-of-women-in-50+-population-data                           26 non-null     float64
#  2   GDL-%-population-aged-15-65-data                                26 non-null     float64
#  3   GDL-%-population-aged-over-65-data                              26 non-null     float64
#  4   GDL-%-population-aged-under-15-data                             26 non-null     float64
#  5   GDL-%-population-in-urban-areas-data                            26 non-null     float64
#  6   GDL-Average-household-size-data                                 26 non-null     float64
# ...

# %%
df.describe()
# Out:
#               year  GDL-%-of-women-in-50+-population-data  \
# count    26.000000                              26.000000
# mean   2004.500000                              38.323077
# std       7.648529                               2.748135
# min    1992.000000                              33.700000
# 25%    1998.250000                              36.425000
# 50%    2004.500000                              37.350000
# 75%    2010.750000                              40.075000
# max    2017.000000                              44.400000
#
#        GDL-%-population-aged-15-65-data  GDL-%-population-aged-over-65-data  \
# count                         26.000000                           26.000000
# mean                          68.796154                            0.973462
# std                            1.448718                            0.091212
# min                           65.700000                            0.870000
# ...

# %%
df.isna().sum()
# Out:
# year                                                              0
# GDL-%-of-women-in-50+-population-data                             0
# GDL-%-population-aged-15-65-data                                  0
# GDL-%-population-aged-over-65-data                                0
# GDL-%-population-aged-under-15-data                               0
# GDL-%-population-in-urban-areas-data                              0
# GDL-Average-household-size-data                                   0
# GDL-Dependency-ratio-data                                         0
# GDL-Mean-International-Wealth-Index-(IWI)-score-of-region-data    0
# GDL-Mean-age-at-first-birth-of-women-aged-20-50-data              0
# GDL-Mean-age-at-first-marriage-of-women-aged-20-50-data           0
# GDL-Mean-age-difference-partners-(husband-wife)-data              0
# GDL-Mean-years-education-of-adults-aged-20+-data                  0
# GDL-Mean-years-education-of-adults-aged-20-39-data                0
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\riley\\OneDrive\\Desktop\\Urban Developing Omdena\\SHDI-SGDI-Total 7.0.csv")
# Out:
# C:\Users\riley\AppData\Local\Temp\ipykernel_36448\198217105.py:1: DtypeWarning: Columns (11,14,17,20,23,26,29,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\riley\\OneDrive\\Desktop\\Urban Developing Omdena\\SHDI-SGDI-Total 7.0.csv")

# %%
df.head()
# Out:
#   iso_code      country  year  GDLCODE   level  \
# 0      AFG  Afghanistan  1990  AFGr101  Subnat
# 1      AFG  Afghanistan  1990  AFGr102  Subnat
# 2      AFG  Afghanistan  1990  AFGr103  Subnat
# 3      AFG  Afghanistan  1990  AFGr104  Subnat
# 4      AFG  Afghanistan  1990  AFGr105  Subnat
#
#                                               region     continent sgdi  shdi  \
# 0  Central (Kabul Wardak Kapisa Logar Parwan Panj...  Asia/Pacific       .332
# 1                Central Highlands (Bamyan Daikundi)  Asia/Pacific       .281
# 2           East (Nangarhar Kunar Laghman Nooristan)  Asia/Pacific       .287
# 3    North (Samangan Sar-e-Pul Balkh Jawzjan Faryab)  Asia/Pacific       .259
# 4      North East (Baghlan Takhar Badakhshan Kunduz)  Asia/Pacific       .266
#
#   shdif  ...  lifexp lifexpf lifexpm      gnic gnicf gnicm  lgnic lgnicf  \
# 0        ...  46.975                  3549.393              8.175
# 1        ...  44.402                  2224.831              7.707
# ...

# %%
african_countries = ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon', 'Central African Republic (CAR)', 'Chad', 'Comoros', 'Democratic Republic of the Congo', 'Republic of the Congo', 'Cote d\'Ivoire', 'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini (formerly Swaziland)', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe']

# %%
df = df[df['country'].isin(african_countries)]

# %%
df.drop('continent', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['iso_code', 'country', 'year', 'GDLCODE', 'level', 'region', 'sgdi',
#        'shdi', 'shdif', 'shdim', 'healthindex', 'healthindexf', 'healthindexm',
#        'incindex', 'incindexf', 'incindexm', 'edindex', 'edindexf', 'edindexm',
#        'esch', 'eschf', 'eschm', 'msch', 'mschf', 'mschm', 'lifexp', 'lifexpf',
#        'lifexpm', 'gnic', 'gnicf', 'gnicm', 'lgnic', 'lgnicf', 'lgnicm',
#        'pop'],
#       dtype='object')

# %%
df.head()
# Out:
#     iso_code country  year  GDLCODE   level         region sgdi  shdi shdif  \
# 288      AGO  Angola  1999  AGOr201  Subnat        Cabinda       .401
# 289      AGO  Angola  1999  AGOr202  Subnat          Zaire       .336
# 290      AGO  Angola  1999  AGOr203  Subnat           Uige       .348
# 291      AGO  Angola  1999  AGOr204  Subnat         Luanda        .46
# 292      AGO  Angola  1999  AGOr205  Subnat   Kuanza Norte       .301
#
#     shdim  ...  lifexp lifexpf lifexpm       gnic gnicf gnicm  lgnic lgnicf  \
# 288        ...  43.228                   6407.467              8.765
# 289        ...  50.945                   1612.003              7.385
# 290        ...   45.54                   2658.305              7.885
# 291        ...  48.215                  10434.693              9.253
# 292        ...  42.342                   2044.276              7.623
#
#     lgnicm pop
# 288
# 289
# 290
# 291
# 292
#
# [5 rows x 35 columns]

# %%
df.repalce()
# Out:
# 288
# 289
# 290
# 291
# 292
#          ...
# 58879    .958
# 58880    .962
# 58881    .962
# 58882    .985
# 58883    .961
# Name: sgdi, Length: 14955, dtype: object

# %%
df = df.replace(r'^\s*$', np.nan, regex=True) # Replace all blanks with nulls

# %%
df
# Out:
#       iso_code   country  year  GDLCODE     level         region  sgdi  shdi  \
# 288        AGO    Angola  1999  AGOr201    Subnat        Cabinda   NaN  .401
# 289        AGO    Angola  1999  AGOr202    Subnat          Zaire   NaN  .336
# 290        AGO    Angola  1999  AGOr203    Subnat           Uige   NaN  .348
# 291        AGO    Angola  1999  AGOr204    Subnat         Luanda   NaN   .46
# 292        AGO    Angola  1999  AGOr205    Subnat   Kuanza Norte   NaN  .301
# ...        ...       ...   ...      ...       ...            ...   ...   ...
# 58879      ZWE  Zimbabwe  2021  ZWEr107    Subnat       Midlands  .958   .59
# 58880      ZWE  Zimbabwe  2021  ZWEr108    Subnat       Masvingo  .962  .588
# 58881      ZWE  Zimbabwe  2021  ZWEr109    Subnat         Harare  .962  .665
# 58882      ZWE  Zimbabwe  2021  ZWEr110    Subnat       Bulawayo  .985  .693
# 58883      ZWE  Zimbabwe  2021     ZWEt  National          Total  .961  .593
#
# ...

# %%
df.isnull().sum()/len(df)
# Out:
# iso_code        0.000000
# country         0.000000
# year            0.000000
# GDLCODE         0.000000
# level           0.000000
# region          0.000000
# sgdi            0.323571
# shdi            0.000401
# shdif           0.323504
# shdim           0.323571
# healthindex     0.000000
# healthindexf    0.306118
# healthindexm    0.306118
# incindex        0.000000
# incindexf       0.306118
# incindexm       0.306118
# edindex         0.000000
# edindexf        0.323504
# edindexm        0.323571
# esch            0.000000
# eschf           0.322166
# eschm           0.322233
# msch            0.000000
# mschf           0.322701
# mschm           0.322701
# lifexp          0.000000
# lifexpf         0.306118
# lifexpm         0.306118
# gnic            0.000000
# gnicf           0.306118
# gnicm           0.306118
# lgnic           0.000000
# lgnicf          0.306118
# lgnicm          0.306118
# pop             1.000000
# dtype: float64

# %%
df.drop('pop', axis=1, inplace=True)

# %%
df
# Out:
#       iso_code   country  year  GDLCODE     level         region  sgdi  shdi  \
# 288        AGO    Angola  1999  AGOr201    Subnat        Cabinda   NaN  .401
# 289        AGO    Angola  1999  AGOr202    Subnat          Zaire   NaN  .336
# 290        AGO    Angola  1999  AGOr203    Subnat           Uige   NaN  .348
# 291        AGO    Angola  1999  AGOr204    Subnat         Luanda   NaN   .46
# 292        AGO    Angola  1999  AGOr205    Subnat   Kuanza Norte   NaN  .301
# ...        ...       ...   ...      ...       ...            ...   ...   ...
# 58879      ZWE  Zimbabwe  2021  ZWEr107    Subnat       Midlands  .958   .59
# 58880      ZWE  Zimbabwe  2021  ZWEr108    Subnat       Masvingo  .962  .588
# 58881      ZWE  Zimbabwe  2021  ZWEr109    Subnat         Harare  .962  .665
# 58882      ZWE  Zimbabwe  2021  ZWEr110    Subnat       Bulawayo  .985  .693
# 58883      ZWE  Zimbabwe  2021     ZWEt  National          Total  .961  .593
#
# ...

# %%
df.to_csv("SHDI-SGDI-Total 7.0_preprocessed.csv")

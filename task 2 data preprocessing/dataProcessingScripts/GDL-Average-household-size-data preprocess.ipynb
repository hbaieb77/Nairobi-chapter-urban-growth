# %%
import pandas as pd

# %%
df = pd.read_csv("Africa_Average_HouseHold_1992-2021.csv")

# %%
df
# Out:
#       Country Continent ISO_Code     Level  GDLCODE  \
# 0     Algeria    Africa      DZA  National     DZAt
# 1     Algeria    Africa      DZA    Subnat  DZAr104
# 2     Algeria    Africa      DZA    Subnat  DZAr105
# 3     Algeria    Africa      DZA    Subnat  DZAr106
# 4     Algeria    Africa      DZA    Subnat  DZAr101
# ..        ...       ...      ...       ...      ...
# 603  Zimbabwe    Africa      ZWE    Subnat  ZWEr104
# 604  Zimbabwe    Africa      ZWE    Subnat  ZWEr108
# 605  Zimbabwe    Africa      ZWE    Subnat  ZWEr105
# 606  Zimbabwe    Africa      ZWE    Subnat  ZWEr106
# 607  Zimbabwe    Africa      ZWE    Subnat  ZWEr107
#
#                                                 Region  1992  1993  1994  \
# 0                                                Total   NaN   NaN   NaN
# 1      Hauts Plateaux Centre (Djelfa, Laghouat, MSila)   NaN   NaN   NaN
# 2    Hauts Plateaux Est (Setif, Batna, Khenchela, B...   NaN   NaN   NaN
# ...

# %% [markdown]
# ### Drop columns

# %%
df = df.drop(columns=['ISO_Code','GDLCODE'],axis=1)

# %%
df
# Out:
#       Country Continent     Level  \
# 0     Algeria    Africa  National
# 1     Algeria    Africa    Subnat
# 2     Algeria    Africa    Subnat
# 3     Algeria    Africa    Subnat
# 4     Algeria    Africa    Subnat
# ..        ...       ...       ...
# 603  Zimbabwe    Africa    Subnat
# 604  Zimbabwe    Africa    Subnat
# 605  Zimbabwe    Africa    Subnat
# 606  Zimbabwe    Africa    Subnat
# 607  Zimbabwe    Africa    Subnat
#
#                                                 Region  1992  1993  1994  \
# 0                                                Total   NaN   NaN   NaN
# 1      Hauts Plateaux Centre (Djelfa, Laghouat, MSila)   NaN   NaN   NaN
# 2    Hauts Plateaux Est (Setif, Batna, Khenchela, B...   NaN   NaN   NaN
# 3    Hauts Plateaux Ouest (Tiaret, Saida, Tissemsil...   NaN   NaN   NaN
# 4    Nord Centre (Alger, Blida, Boumerdes, Tipaza, ...   NaN   NaN   NaN
# ..                                                 ...   ...   ...   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    608 non-null    object
#  1   Continent  608 non-null    object
#  2   Level      608 non-null    object
#  3   Region     608 non-null    object
#  4   1992       132 non-null    float64
#  5   1993       153 non-null    float64
#  6   1994       174 non-null    float64
#  7   1995       235 non-null    float64
#  8   1996       231 non-null    float64
#  9   1997       309 non-null    float64
#  10  1998       333 non-null    float64
#  11  1999       341 non-null    float64
#  12  2000       342 non-null    float64
#  13  2001       353 non-null    float64
#  14  2002       368 non-null    float64
#  15  2003       409 non-null    float64
#  16  2004       422 non-null    float64
#  17  2005       444 non-null    float64
#  18  2006       437 non-null    float64
# ...

# %%
df.describe()
# Out:
#              1992        1993        1994        1995        1996        1997  \
# count  132.000000  153.000000  174.000000  235.000000  231.000000  309.000000
# mean     7.958333    7.921503    7.744540    7.748979    7.650130    7.266505
# std      2.369337    2.270066    2.189494    2.167591    2.100014    2.055436
# min      4.310000    4.350000    4.390000    4.360000    4.460000    3.630000
# 25%      6.325000    6.380000    6.305000    6.145000    6.130000    5.860000
# 50%      7.255000    7.210000    7.125000    7.290000    7.200000    6.700000
# 75%      8.480000    8.400000    8.275000    8.830000    8.585000    8.280000
# max     15.400000   15.100000   15.100000   15.100000   15.100000   15.100000
#
#              1998       1999        2000        2001  ...        2012  \
# count  333.000000  341.00000  342.000000  353.000000  ...  552.000000
# mean     7.269429    7.23563    7.177778    7.092918  ...    6.411413
# ...

# %% [markdown]
# ### Handling missing values

# %%
df.isna().sum()
# Out:
# Country        0
# Continent      0
# Level          0
# Region         0
# 1992         476
# 1993         455
# 1994         434
# 1995         373
# 1996         377
# 1997         299
# 1998         275
# 1999         267
# 2000         266
# 2001         255
# 2002         240
# 2003         199
# 2004         186
# 2005         164
# 2006         171
# 2007         171
# 2008         153
# 2009         145
# 2010          95
# 2011          95
# 2012          56
# 2013          56
# 2014          81
# 2015          80
# 2016         103
# 2017         144
# 2018         205
# 2019         244
# 2020         306
# 2021         330
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Continent', 'Level', 'Region', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
cols = ['1992', '1993', '1994',
       '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
       '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
       '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')

# %%
for col in cols:
    df[col] = imputer.fit_transform(df[col].values.reshape(-1, 1))

# %%
df.isna().sum()
# Out:
# Country      0
# Continent    0
# Level        0
# Region       0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# 2014         0
# 2015         0
# 2016         0
# 2017         0
# 2018         0
# 2019         0
# 2020         0
# 2021         0
# dtype: int64

# %%
df
# Out:
#       Country Continent     Level  \
# 0     Algeria    Africa  National
# 1     Algeria    Africa    Subnat
# 2     Algeria    Africa    Subnat
# 3     Algeria    Africa    Subnat
# 4     Algeria    Africa    Subnat
# ..        ...       ...       ...
# 603  Zimbabwe    Africa    Subnat
# 604  Zimbabwe    Africa    Subnat
# 605  Zimbabwe    Africa    Subnat
# 606  Zimbabwe    Africa    Subnat
# 607  Zimbabwe    Africa    Subnat
#
#                                                 Region      1992      1993  \
# 0                                                Total  7.958333  7.921503
# 1      Hauts Plateaux Centre (Djelfa, Laghouat, MSila)  7.958333  7.921503
# 2    Hauts Plateaux Est (Setif, Batna, Khenchela, B...  7.958333  7.921503
# 3    Hauts Plateaux Ouest (Tiaret, Saida, Tissemsil...  7.958333  7.921503
# 4    Nord Centre (Alger, Blida, Boumerdes, Tipaza, ...  7.958333  7.921503
# ..                                                 ...       ...       ...
# ...

# %%
melt_data = df.melt(id_vars=['Country','Continent','Level','Region'],var_name="Year",value_name="Value")

# %%
melt_data = melt_data.rename(columns={'Value':"avg_household_size"})

# %%
melt_data
# Out:
#         Country Continent     Level  \
# 0       Algeria    Africa  National
# 1       Algeria    Africa    Subnat
# 2       Algeria    Africa    Subnat
# 3       Algeria    Africa    Subnat
# 4       Algeria    Africa    Subnat
# ...         ...       ...       ...
# 18235  Zimbabwe    Africa    Subnat
# 18236  Zimbabwe    Africa    Subnat
# 18237  Zimbabwe    Africa    Subnat
# 18238  Zimbabwe    Africa    Subnat
# 18239  Zimbabwe    Africa    Subnat
#
#                                                   Region  Year  \
# 0                                                  Total  1992
# 1        Hauts Plateaux Centre (Djelfa, Laghouat, MSila)  1992
# 2      Hauts Plateaux Est (Setif, Batna, Khenchela, B...  1992
# 3      Hauts Plateaux Ouest (Tiaret, Saida, Tissemsil...  1992
# 4      Nord Centre (Alger, Blida, Boumerdes, Tipaza, ...  1992
# ...                                                  ...   ...
# 18235                                   Mashonaland West  2021
# ...

# %%
melt_data = melt_data.drop(['Continent', 'Level'], axis=1)

# %%
melt_data.to_csv('africa_average_household.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('un_compiled_housing_data_africa.csv')

# %%
df
# Out:
#     United Nations, Department of Economic and Social Affairs\nPopulation Division  \
# 0                                                  NaN
# 1    HOUSEHOLD SIZE AND COMPOSITION 2022\n\n\nCopyr...
# 2                                                  NaN
# 3                                      Country or area
# 4                                               Angola
# ..                                                 ...
# 111                        United Republic of Tanzania
# 112                        United Republic of Tanzania
# 113                        United Republic of Tanzania
# 114                        United Republic of Tanzania
# 115                        United Republic of Tanzania
#
#     Unnamed: 1            Unnamed: 2                   Unnamed: 3  \
# 0          NaN                   NaN                          NaN
# 1          NaN                   NaN                          NaN
# 2          NaN                   NaN                          NaN
# ...

# %% [markdown]
# ### Drop columns and change column names

# %%
df = df.drop(labels=range(0,3))

# %%
df = df.reset_index()

# %%
df
# Out:
#      index  \
# 0        3
# 1        4
# 2        5
# 3        6
# 4        7
# ..     ...
# 108    111
# 109    112
# 110    113
# 111    114
# 112    115
#
#     United Nations, Department of Economic and Social Affairs\nPopulation Division  \
# 0                                      Country or area
# 1                                               Angola
# 2                                               Angola
# 3                                               Angola
# 4                                               Angola
# ..                                                 ...
# 108                        United Republic of Tanzania
# 109                        United Republic of Tanzania
# 110                        United Republic of Tanzania
# 111                        United Republic of Tanzania
# 112                        United Republic of Tanzania
#
#     Unnamed: 1            Unnamed: 2                   Unnamed: 3  \
# ...

# %%
pd.options.display.max_columns = None
(df)
# Out:
#      index  \
# 0        3
# 1        4
# 2        5
# 3        6
# 4        7
# ..     ...
# 108    111
# 109    112
# 110    113
# 111    114
# 112    115
#
#     United Nations, Department of Economic and Social Affairs\nPopulation Division  \
# 0                                      Country or area
# 1                                               Angola
# 2                                               Angola
# 3                                               Angola
# 4                                               Angola
# ..                                                 ...
# 108                        United Republic of Tanzania
# 109                        United Republic of Tanzania
# 110                        United Republic of Tanzania
# 111                        United Republic of Tanzania
# 112                        United Republic of Tanzania
#
#     Unnamed: 1            Unnamed: 2                   Unnamed: 3  \
# ...

# %%
df = df.drop(df.columns[43:], axis=1)

# %%
df
# Out:
#      index  \
# 0        3
# 1        4
# 2        5
# 3        6
# 4        7
# ..     ...
# 108    111
# 109    112
# 110    113
# 111    114
# 112    115
#
#     United Nations, Department of Economic and Social Affairs\nPopulation Division  \
# 0                                      Country or area
# 1                                               Angola
# 2                                               Angola
# 3                                               Angola
# 4                                               Angola
# ..                                                 ...
# 108                        United Republic of Tanzania
# 109                        United Republic of Tanzania
# 110                        United Republic of Tanzania
# 111                        United Republic of Tanzania
# 112                        United Republic of Tanzania
#
#     Unnamed: 1            Unnamed: 2                   Unnamed: 3  \
# ...

# %%
new_header = df.iloc[0] 
df = df[1:] 
df.columns = new_header

# %%
df
# Out:
# 0      3              Country or area ISO Code Data source category  \
# 1      4                       Angola       24                 MICS
# 2      5                       Angola       24                  DHS
# 3      6                       Angola       24                  DHS
# 4      7                       Angola       24                  DHS
# 5      8                     Cameroon      120                IPUMS
# ..   ...                          ...      ...                  ...
# 108  111  United Republic of Tanzania      834                  DHS
# 109  112  United Republic of Tanzania      834                  DHS
# 110  113  United Republic of Tanzania      834                  DHS
# 111  114  United Republic of Tanzania      834                IPUMS
# 112  115  United Republic of Tanzania      834                  DHS
#
# 0   Reference date (dd/mm/yyyy) Average household size (number of members)  \
# ...

# %%
df = df.drop(columns=[3],axis=1)

# %%
df
# Out:
# 0                Country or area ISO Code Data source category  \
# 1                         Angola       24                 MICS
# 2                         Angola       24                  DHS
# 3                         Angola       24                  DHS
# 4                         Angola       24                  DHS
# 5                       Cameroon      120                IPUMS
# ..                           ...      ...                  ...
# 108  United Republic of Tanzania      834                  DHS
# 109  United Republic of Tanzania      834                  DHS
# 110  United Republic of Tanzania      834                  DHS
# 111  United Republic of Tanzania      834                IPUMS
# 112  United Republic of Tanzania      834                  DHS
#
# 0   Reference date (dd/mm/yyyy) Average household size (number of members)  \
# 1                      07-01-01                                       4.75
# ...

# %%
df = df.drop(columns=['ISO Code','Data source category','Reference date (dd/mm/yyyy)','Unknown'],axis=1)

# %%
df
# Out:
# 0                Country or area Average household size (number of members)  \
# 1                         Angola                                       4.75
# 2                         Angola                                       5.69
# 3                         Angola                                       4.98
# 4                         Angola                                       4.82
# 5                       Cameroon                                       5.07
# ..                           ...                                        ...
# 108  United Republic of Tanzania                                       4.99
# 109  United Republic of Tanzania                                       4.97
# 110  United Republic of Tanzania                                       5.12
# 111  United Republic of Tanzania                                       4.74
# 112  United Republic of Tanzania                                       4.85
#
# ...

# %% [markdown]
# ### Change dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 1 to 112
# Data columns (total 38 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Country or area                                                                  112 non-null    object
#  1   Average household size (number of members)                                       112 non-null    object
#  2   1 member                                                                         112 non-null    object
#  3   2-3 members                                                                      112 non-null    object
#  4   4-5 members                                                                      112 non-null    object
#  5   6 or more members                                                                112 non-null    object
# ...

# %%
import numpy as np

# %%
def remove_dot(dataset,columns,dot):
    dataset[columns] = dataset[columns].replace(dot,np.nan)

# %%
remove_dot(df,'Female head of household (percentage of households)','..')
remove_dot(df,'Under 20 years (aged 0-19)','..')
remove_dot(df,'Aged 20-64 years','..')
remove_dot(df,'Aged 60 years or over','..')
remove_dot(df,'Aged 65 years or over','..')
remove_dot(df,'One-person','..')
remove_dot(df,'Couple only','..')
remove_dot(df,'Couple with children','..')
remove_dot(df,'Single parent with children','..')
remove_dot(df,'Single mother with children','..')
remove_dot(df,'Single father with children','..')
remove_dot(df,'Extended family','..')
remove_dot(df,'Non-relatives','..')
remove_dot(df,'Nuclear','..')
remove_dot(df,'Multi-generation','..')
remove_dot(df,'Three generation','..')
remove_dot(df,'Average household size (number of members)','..')
remove_dot(df,'1 member','..')
remove_dot(df,'2-3 members','..')
remove_dot(df,'4-5 members','..')
remove_dot(df,'6 or more members','..')
remove_dot(df,'Under 15 years (aged 0-14)','..')
remove_dot(df,'Under 18 years (aged 0-17)','..')
remove_dot(df,'Under 20 years (aged 0-19)','..')
remove_dot(df,'Aged 60 years or over','..')
remove_dot(df,'Aged 65 years or over','..')
remove_dot(df,'Under 15 years AND 60 years or over','..')
remove_dot(df,'Under 15 years AND 65 years or over','..')
remove_dot(df,'Under 18 years AND 60 years or over','..')
remove_dot(df,'Under 18 years AND 65 years or over','..')
remove_dot(df,'Under 20 years AND 60 years or over','..')
remove_dot(df,'Under 20 years AND 65 years or over','..')
remove_dot(df,'Under age 15 years among all households','..')
remove_dot(df,'Under age 15 years among households with at least one member under age 15 years','..')
remove_dot(df,'Under age 20 years among all households','..')
remove_dot(df,'Under age 20 years among households with at least one member under age 20 years','..')
remove_dot(df,'Ages 20-64 years among all households','..')

# %%
df
# Out:
# 0                Country or area Average household size (number of members)  \
# 1                         Angola                                       4.75
# 2                         Angola                                       5.69
# 3                         Angola                                       4.98
# 4                         Angola                                       4.82
# 5                       Cameroon                                       5.07
# ..                           ...                                        ...
# 108  United Republic of Tanzania                                       4.99
# 109  United Republic of Tanzania                                       4.97
# 110  United Republic of Tanzania                                       5.12
# 111  United Republic of Tanzania                                       4.74
# 112  United Republic of Tanzania                                       4.85
#
# ...

# %%
df.isnull().sum()
# Out:
# 0
# Country or area                                                                     0
# Average household size (number of members)                                          3
# 1 member                                                                            1
# 2-3 members                                                                         1
# 4-5 members                                                                         1
# 6 or more members                                                                   1
# Female head of household (percentage of households)                                 4
# Under 20 years (aged 0-19)                                                          4
# Aged 20-64 years                                                                    4
# Aged 60 years or over                                                               4
# Aged 65 years or over                                                               4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 1 to 112
# Data columns (total 38 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Country or area                                                                  112 non-null    object
#  1   Average household size (number of members)                                       109 non-null    object
#  2   1 member                                                                         111 non-null    object
#  3   2-3 members                                                                      111 non-null    object
#  4   4-5 members                                                                      111 non-null    object
#  5   6 or more members                                                                111 non-null    object
# ...

# %%
for col in df.columns:
    if col != 'Country or area':
        df[col] = df[col].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 1 to 112
# Data columns (total 38 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Country or area                                                                  112 non-null    object
#  1   Average household size (number of members)                                       109 non-null    float64
#  2   1 member                                                                         111 non-null    float64
#  3   2-3 members                                                                      111 non-null    float64
#  4   4-5 members                                                                      111 non-null    float64
# ...

# %% [markdown]
# ### Handle missing values

# %%
df.isna().sum()
# Out:
# 0
# Country or area                                                                     0
# Average household size (number of members)                                          3
# 1 member                                                                            1
# 2-3 members                                                                         1
# 4-5 members                                                                         1
# 6 or more members                                                                   1
# Female head of household (percentage of households)                                 4
# Under 20 years (aged 0-19)                                                          4
# Aged 20-64 years                                                                    4
# Aged 60 years or over                                                               4
# Aged 65 years or over                                                               4
# ...

# %%
df.describe()
# Out:
# 0      Average household size (number of members)    1 member  2-3 members  \
# count                                  109.000000  111.000000   111.000000
# mean                                     4.869908   10.877297    25.130000
# std                                      0.615436    5.585439     3.987975
# min                                      3.200000    1.570000    16.670000
# 25%                                      4.580000    6.585000    22.730000
# 50%                                      4.900000   10.120000    25.240000
# 75%                                      5.200000   14.470000    26.870000
# max                                      6.290000   27.570000    36.700000
#
# 0      4-5 members  6 or more members  \
# count   111.000000         111.000000
# mean     28.755856          35.236757
# std       4.474278           8.469226
# min      19.810000          13.170000
# 25%      25.710000          31.240000
# 50%      28.440000          35.920000
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.displot(df['Average household size (number of members)'])

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
imputer_median = SimpleImputer(strategy='median')
cols_to_impute = ['Average household size (number of members)']
cols_to_impute_2 = ['1 member']
cols_to_impute_3 = ['2-3 members']
cols_to_impute_4 = ['4-5 members']
cols_to_impute_5 = ['6 or more members']
cols_to_impute_6 = ['Female head of household (percentage of households)']
cols_to_impute_7 = ['Under 20 years (aged 0-19)']
cols_to_impute_8 = ['Aged 20-64 years']
cols_to_impute_9 = ['Aged 60 years or over']
cols_to_impute_10 = ['Aged 65 years or over']
cols_to_impute_11 = ['Under 15 years (aged 0-14)']
cols_to_impute_12 = ['Under 18 years (aged 0-17)']
cols_to_impute_13 = ['Under 20 years (aged 0-19)']
cols_to_impute_14 = ['Aged 60 years or over']
cols_to_impute_15 = ['Aged 65 years or over']
cols_to_impute_16 = ['Non-relatives']
df[cols_to_impute] = imputer.fit_transform(df[cols_to_impute])
df[cols_to_impute_2] = imputer_median.fit_transform(df[cols_to_impute_2])
df[cols_to_impute_3] = imputer.fit_transform(df[cols_to_impute_3])
df[cols_to_impute_4] = imputer.fit_transform(df[cols_to_impute_4])
df[cols_to_impute_5] = imputer.fit_transform(df[cols_to_impute_5])
df[cols_to_impute_6] = imputer.fit_transform(df[cols_to_impute_6])
df[cols_to_impute_7] = imputer_median.fit_transform(df[cols_to_impute_7])
df[cols_to_impute_8] = imputer_median.fit_transform(df[cols_to_impute_8])
df[cols_to_impute_9] = imputer_median.fit_transform(df[cols_to_impute_9])
df[cols_to_impute_10] = imputer.fit_transform(df[cols_to_impute_10])
df[cols_to_impute_11] = imputer.fit_transform(df[cols_to_impute_11])
df[cols_to_impute_12] = imputer.fit_transform(df[cols_to_impute_12])
df[cols_to_impute_13] = imputer.fit_transform(df[cols_to_impute_13])
df[cols_to_impute_14] = imputer.fit_transform(df[cols_to_impute_14])
df[cols_to_impute_15] = imputer.fit_transform(df[cols_to_impute_15])
df[cols_to_impute_16] = imputer_median.fit_transform(df[cols_to_impute_16])

# %%
df.isna().sum()
# Out:
# 0
# Country or area                                                                     0
# Average household size (number of members)                                          0
# 1 member                                                                            0
# 2-3 members                                                                         0
# 4-5 members                                                                         0
# 6 or more members                                                                   0
# Female head of household (percentage of households)                                 0
# Under 20 years (aged 0-19)                                                          0
# Aged 20-64 years                                                                    0
# Aged 60 years or over                                                               0
# Aged 65 years or over                                                               0
# ...

# %%
cols_to_impute_17 = ['Under 15 years AND 60 years or over',
                  'Under 15 years AND 65 years or over',
                  'Under 18 years AND 60 years or over',
                  'Under 18 years AND 65 years or over',
                  'Under 20 years AND 60 years or over',
                  'Under 20 years AND 65 years or over',
                  'Under age 15 years among all households',
                  'Under age 15 years among households with at least one member under age 15 years',
                  'Under age 20 years among all households',
                  'Under age 20 years among households with at least one member under age 20 years',
                  'Ages 20-64 years among all households',
                  'One-person',
                  'Couple only',
                  'Couple with children',
                  'Single parent with children',
                  'Single mother with children',
                  'Single father with children',
                  'Extended family','Nuclear','Multi-generation','Three generation']

for col in cols_to_impute_17:
    df[col] = imputer.fit_transform(df[col].values.reshape(-1, 1))

# %%
df.isna().sum()
# Out:
# 0
# Country or area                                                                    0
# Average household size (number of members)                                         0
# 1 member                                                                           0
# 2-3 members                                                                        0
# 4-5 members                                                                        0
# 6 or more members                                                                  0
# Female head of household (percentage of households)                                0
# Under 20 years (aged 0-19)                                                         0
# Aged 20-64 years                                                                   0
# Aged 60 years or over                                                              0
# Aged 65 years or over                                                              0
# ...

# %%
df
# Out:
# 0                Country or area  Average household size (number of members)  \
# 1                         Angola                                        4.75
# 2                         Angola                                        5.69
# 3                         Angola                                        4.98
# 4                         Angola                                        4.82
# 5                       Cameroon                                        5.07
# ..                           ...                                         ...
# 108  United Republic of Tanzania                                        4.99
# 109  United Republic of Tanzania                                        4.97
# 110  United Republic of Tanzania                                        5.12
# 111  United Republic of Tanzania                                        4.74
# 112  United Republic of Tanzania                                        4.85
#
# ...

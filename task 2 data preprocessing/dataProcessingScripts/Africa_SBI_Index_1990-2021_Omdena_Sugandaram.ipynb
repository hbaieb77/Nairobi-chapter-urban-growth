# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir("D:\\Omdena\\Omdena Predictive Urban Growth and Planning\\nairobi-chapter-urban-growth-main\\nairobi-chapter-urban-growth-main\\src\\data\\city_growth_models")

# %%
df = pd.read_csv("Africa_SBI_Index_1990-2021.csv")

# %%
df.head()
# Out:
#    Country Continent ISO_Code     Level  GDLCODE  \
# 0  Algeria    Africa      DZA  National     DZAt
# 1  Algeria    Africa      DZA    Subnat  DZAr104
# 2  Algeria    Africa      DZA    Subnat  DZAr105
# 3  Algeria    Africa      DZA    Subnat  DZAr106
# 4  Algeria    Africa      DZA    Subnat  DZAr101
#
#                                               Region   1990   1991   1992  \
# 0                                              Total  0.591  0.594  0.599
# 1    Hauts Plateaux Centre (Djelfa, Laghouat, MSila)  0.562  0.565  0.569
# 2  Hauts Plateaux Est (Setif, Batna, Khenchela, B...  0.587  0.589  0.594
# 3  Hauts Plateaux Ouest (Tiaret, Saida, Tissemsil...  0.573  0.575  0.580
# 4  Nord Centre (Alger, Blida, Boumerdes, Tipaza, ...  0.615  0.618  0.623
#
#     1993  ...   2012   2013   2014   2015   2016   2017   2018   2019   2020  \
# 0  0.601  ...  0.729  0.731  0.735  0.740  0.743  0.744  0.745  0.748  0.736
# ...

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#    Country Continent ISO_Code     Level  GDLCODE  \
# 0  Algeria    Africa      DZA  National     DZAt
# 1  Algeria    Africa      DZA    Subnat  DZAr104
# 2  Algeria    Africa      DZA    Subnat  DZAr105
# 3  Algeria    Africa      DZA    Subnat  DZAr106
# 4  Algeria    Africa      DZA    Subnat  DZAr101
#
#                                               Region   1990   1991   1992  \
# 0                                              Total  0.591  0.594  0.599
# 1    Hauts Plateaux Centre (Djelfa, Laghouat, MSila)  0.562  0.565  0.569
# 2  Hauts Plateaux Est (Setif, Batna, Khenchela, B...  0.587  0.589  0.594
# 3  Hauts Plateaux Ouest (Tiaret, Saida, Tissemsil...  0.573  0.575  0.580
# 4  Nord Centre (Alger, Blida, Boumerdes, Tipaza, ...  0.615  0.618  0.623
#
#     1993  ...   2012   2013   2014   2015   2016   2017   2018   2019   2020  \
# 0  0.601  ...  0.729  0.731  0.735  0.740  0.743  0.744  0.745  0.748  0.736
# ...

# %%
df1.columns
# Out:
# Index(['Country', 'Continent', 'ISO_Code', 'Level', 'GDLCODE', 'Region',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
df1.describe()
# Out:
#              1990        1991        1992        1993        1994        1995  \
# count  395.000000  395.000000  395.000000  395.000000  389.000000  398.000000
# mean     0.422063    0.424370    0.424646    0.426777    0.432771    0.433327
# std      0.124120    0.125385    0.126492    0.126194    0.124808    0.123964
# min      0.172000    0.173000    0.176000    0.180000    0.184000    0.189000
# 25%      0.324000    0.323000    0.320000    0.324500    0.335000    0.340250
# 50%      0.406000    0.408000    0.406000    0.413000    0.425000    0.420500
# 75%      0.515500    0.518500    0.517000    0.515000    0.519000    0.519500
# max      0.713000    0.721000    0.728000    0.734000    0.741000    0.745000
#
#              1996        1997        1998        1999  ...        2012  \
# count  398.000000  398.000000  398.000000  433.000000  ...  592.000000
# mean     0.436294    0.438269    0.441570    0.438088  ...    0.505534
# ...

# %%
df1.isnull().sum()
# Out:
# Country        0
# Continent      0
# ISO_Code       0
# Level          0
# GDLCODE        0
# Region         0
# 1990         197
# 1991         197
# 1992         197
# 1993         197
# 1994         203
# 1995         194
# 1996         194
# 1997         194
# 1998         194
# 1999         159
# 2000          85
# 2001          85
# 2002          85
# 2003          47
# 2004          47
# 2005          30
# 2006          11
# 2007          11
# 2008          11
# 2009          11
# 2010           0
# 2011           0
# 2012           0
# 2013           0
# 2014           0
# 2015           0
# 2016           0
# 2017           0
# 2018           0
# 2019           0
# 2020           0
# 2021           0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.columns
# Out:
# Index(['Country', 'Continent', 'ISO_Code', 'Level', 'GDLCODE', 'Region',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %% [markdown]
# ## there are some missing value or null values.

# %%
plt.figure(figsize=(25,15))
sns.barplot(df1.isnull())
# Out:
# <AxesSubplot: >

# %%
values ={"1990":df["1990"].mean(),"1991":df["1991"].mean(),"1992":df["1992"].mean(),"1993":df["1993"].mean(),"1994":df["1994"].mean(),
        "1995":df["1995"].mean(),"1996":df["1996"].mean(),"1997":df["1997"].mean(),"1998":df["1998"].mean(),"1999":df["1999"].mean(),
        "2000":df["2000"].mean(),"1990":df["1990"].mean(),"2001":df["2001"].mean(),"2002":df["2002"].mean(),"2003":df["2003"].mean(),
        "2004":df["2004"].mean(),"2005":df["2005"].mean(),"2006":df["2006"].mean(),"2007":df["2007"].mean(),"2008":df["2008"].mean(),
        "2009":df["2009"].mean()}
df1.fillna(value = values, inplace = True)

# %%
df1.isnull().sum()
# Out:
# Country      0
# Continent    0
# ISO_Code     0
# Level        0
# GDLCODE      0
# Region       0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# 2014         0
# 2015         0
# 2016         0
# 2017         0
# 2018         0
# 2019         0
# 2020         0
# 2021         0
# dtype: int64

# %%
df1.head()
# Out:
#    Country Continent ISO_Code     Level  GDLCODE  \
# 0  Algeria    Africa      DZA  National     DZAt
# 1  Algeria    Africa      DZA    Subnat  DZAr104
# 2  Algeria    Africa      DZA    Subnat  DZAr105
# 3  Algeria    Africa      DZA    Subnat  DZAr106
# 4  Algeria    Africa      DZA    Subnat  DZAr101
#
#                                               Region   1990   1991   1992  \
# 0                                              Total  0.591  0.594  0.599
# 1    Hauts Plateaux Centre (Djelfa, Laghouat, MSila)  0.562  0.565  0.569
# 2  Hauts Plateaux Est (Setif, Batna, Khenchela, B...  0.587  0.589  0.594
# 3  Hauts Plateaux Ouest (Tiaret, Saida, Tissemsil...  0.573  0.575  0.580
# 4  Nord Centre (Alger, Blida, Boumerdes, Tipaza, ...  0.615  0.618  0.623
#
#     1993  ...   2012   2013   2014   2015   2016   2017   2018   2019   2020  \
# 0  0.601  ...  0.729  0.731  0.735  0.740  0.743  0.744  0.745  0.748  0.736
# ...

# %%
df1.describe()
# Out:
#              1990        1991        1992        1993        1994        1995  \
# count  592.000000  592.000000  592.000000  592.000000  592.000000  592.000000
# mean     0.422063    0.424370    0.424646    0.426777    0.432771    0.433327
# std      0.101343    0.102376    0.103280    0.103037    0.101127    0.101600
# min      0.172000    0.173000    0.176000    0.180000    0.184000    0.189000
# 25%      0.360500    0.363500    0.362000    0.363750    0.374000    0.368750
# 50%      0.422063    0.424370    0.424646    0.426777    0.432771    0.433327
# 75%      0.464250    0.466750    0.469000    0.470250    0.473000    0.470250
# max      0.713000    0.721000    0.728000    0.734000    0.741000    0.745000
#
#              1996        1997        1998        1999  ...        2012  \
# count  592.000000  592.000000  592.000000  592.000000  ...  592.000000
# mean     0.436294    0.438269    0.441570    0.438088  ...    0.505534
# ...

# %%
df1.sample(n=500)
# Out:
#                Country Continent ISO_Code   Level  GDLCODE             Region  \
# 425            Nigeria    Africa      NGA  Subnat  NGAr130               Yobe
# 480            Somalia    Africa      SOM  Subnat  SOMr104               Sool
# 81          Cape Verde    Africa      CPV  Subnat  CPVr103  Santiago-Interior
# 419            Nigeria    Africa      NGA  Subnat  NGAr128               Osun
# 491       South Africa    Africa      ZAF  Subnat  ZAFr109  Northern Province
# ..                 ...       ...      ...     ...      ...                ...
# 495        South Sudan    Africa      SSD  Subnat  SSDr110  Eastern Equatoria
# 246              Kenya    Africa      KEN  Subnat  KENr103              Coast
# 103  Congo Brazzaville    Africa      COG  Subnat  COGr204            Bouenza
# 465            Somalia    Africa      SOM  Subnat  SOMr102              Awdal
# 196              Gabon    Africa      GAB  Subnat  GABr102        Haut Ogooue
#
# ...

# %%
df2 = df1.copy()

# %%
df2.drop('ISO_Code', inplace = True, axis = 1)

# %%
df2.head()
# Out:
#    Country Continent     Level  GDLCODE  \
# 0  Algeria    Africa  National     DZAt
# 1  Algeria    Africa    Subnat  DZAr104
# 2  Algeria    Africa    Subnat  DZAr105
# 3  Algeria    Africa    Subnat  DZAr106
# 4  Algeria    Africa    Subnat  DZAr101
#
#                                               Region   1990   1991   1992  \
# 0                                              Total  0.591  0.594  0.599
# 1    Hauts Plateaux Centre (Djelfa, Laghouat, MSila)  0.562  0.565  0.569
# 2  Hauts Plateaux Est (Setif, Batna, Khenchela, B...  0.587  0.589  0.594
# 3  Hauts Plateaux Ouest (Tiaret, Saida, Tissemsil...  0.573  0.575  0.580
# 4  Nord Centre (Alger, Blida, Boumerdes, Tipaza, ...  0.615  0.618  0.623
#
#     1993   1994  ...   2012   2013   2014   2015   2016   2017   2018   2019  \
# 0  0.601  0.602  ...  0.729  0.731  0.735  0.740  0.743  0.744  0.745  0.748
# 1  0.570  0.571  ...  0.695  0.697  0.703  0.709  0.714  0.716  0.720  0.724
# ...

# %%
df2.Level.unique()
# Out:
# array(['National', 'Subnat'], dtype=object)

# %%
df2.Region.unique()
# Out:
# array(['Total', 'Hauts Plateaux Centre (Djelfa, Laghouat, MSila)',
#        'Hauts Plateaux Est (Setif, Batna, Khenchela, Bordj Bou Arreridj, Oum El Bouaghi, Tebessa)',
#        'Hauts Plateaux Ouest (Tiaret, Saida, Tissemsilt, Naama, El Bayadh)',
#        'Nord Centre (Alger, Blida, Boumerdes, Tipaza, Bouira, Medea, Tizi-Ouzou, Bejaia, Chlef, Ain Defla)',
#        'Nord Est (Annaba, Constantine, Skikda, Jijel, Mila, Souk Ahras, El Tarf, Guelma)',
#        'Nord Ouest (Oran, Tlemcen, Mostaganem, Ain Temouchent, Relizane, Sidi Bel Abbes, Mascara)',
#        'Sud (Bechar, Tindouf, Adrar, Ghardaia, Biskra, El Oued, Ouargla, Tamanrasset,Illizi)',
#        ' Bengo', ' Benguela', ' Bie', ' Cabinda', ' Cunene', ' Huambo',
#        ' Huila', ' Kuando Kubango', ' Kuanza Norte', ' Kuanza Sul',
#        ' Luanda', ' Lunda Norte', ' Lunda Sul', ' Malange', ' Moxico',
#        ' Namibe', ' Uige', ' Zaire', 'Atacora (incl Donga)',
# ...

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Level',y='1990',data=df2, hue = "Country")
# Out:
# <AxesSubplot: xlabel='Level', ylabel='1990'>

# %%
df2[['Country','Level', 'Region']].groupby(['Country','Level', 'Region']).size().reset_index()
# Out:
#       Country     Level                                             Region  0
# 0     Algeria  National                                              Total  1
# 1     Algeria    Subnat    Hauts Plateaux Centre (Djelfa, Laghouat, MSila)  1
# 2     Algeria    Subnat  Hauts Plateaux Est (Setif, Batna, Khenchela, B...  1
# 3     Algeria    Subnat  Hauts Plateaux Ouest (Tiaret, Saida, Tissemsil...  1
# 4     Algeria    Subnat  Nord Centre (Alger, Blida, Boumerdes, Tipaza, ...  1
# ..        ...       ...                                                ... ..
# 587  Zimbabwe    Subnat                                   Mashonaland West  1
# 588  Zimbabwe    Subnat                                           Masvingo  1
# 589  Zimbabwe    Subnat                                 Matebeleland North  1
# 590  Zimbabwe    Subnat                                 Matebeleland South  1
# 591  Zimbabwe    Subnat                                           Midlands  1
#
# [592 rows x 4 columns]

# %%
df2.columns
# Out:
# Index(['Country', 'Continent', 'Level', 'GDLCODE', 'Region', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
df2['Country']
# Out:
# 0       Algeria
# 1       Algeria
# 2       Algeria
# 3       Algeria
# 4       Algeria
#          ...
# 587    Zimbabwe
# 588    Zimbabwe
# 589    Zimbabwe
# 590    Zimbabwe
# 591    Zimbabwe
# Name: Country, Length: 592, dtype: object

# %%
count_df2=df2.groupby(["Country"])["Country"].count().to_frame()
count_df2.rename(columns={"Country":"count"},inplace=True)

# %%
count_df2.sort_values(by="count").reset_index()
count_df2
# Out:
#                               count
# Country
# Algeria                           8
# Angola                           19
# Benin                             7
# Botswana                         11
# Burkina Faso                     14
# Burundi                           6
# Cameroon                         11
# Cape Verde                        6
# Central African Republic CAR      7
# Chad                              9
# Comoros                           4
# Congo Brazzaville                13
# Congo Democratic Republic        12
# Cote d'Ivoire                    11
# Djibouti                          3
# Egypt                            23
# Equatorial Guinea                 6
# Eritrea                           7
# Eswatini                          5
# Ethiopia                         12
# Gabon                            11
# Gambia                            9
# Ghana                            11
# Guinea                            9
# Guinea Bissau                    10
# ...

# %%
al=df2[df2['Country']=='Algeria']
al
# Out:
#    Country Continent     Level  GDLCODE  \
# 0  Algeria    Africa  National     DZAt
# 1  Algeria    Africa    Subnat  DZAr104
# 2  Algeria    Africa    Subnat  DZAr105
# 3  Algeria    Africa    Subnat  DZAr106
# 4  Algeria    Africa    Subnat  DZAr101
# 5  Algeria    Africa    Subnat  DZAr102
# 6  Algeria    Africa    Subnat  DZAr103
# 7  Algeria    Africa    Subnat  DZAr107
#
#                                               Region   1990   1991   1992  \
# 0                                              Total  0.591  0.594  0.599
# 1    Hauts Plateaux Centre (Djelfa, Laghouat, MSila)  0.562  0.565  0.569
# 2  Hauts Plateaux Est (Setif, Batna, Khenchela, B...  0.587  0.589  0.594
# 3  Hauts Plateaux Ouest (Tiaret, Saida, Tissemsil...  0.573  0.575  0.580
# 4  Nord Centre (Alger, Blida, Boumerdes, Tipaza, ...  0.615  0.618  0.623
# 5  Nord Est (Annaba, Constantine, Skikda, Jijel, ...  0.594  0.597  0.602
# 6  Nord Ouest (Oran, Tlemcen, Mostaganem, Ain Tem...  0.572  0.575  0.580
# ...

# %%
zw=df2[df2['Country']=='Zimbabwe']
zw
# Out:
#       Country Continent     Level  GDLCODE               Region   1990   1991  \
# 581  Zimbabwe    Africa  National     ZWEt                Total  0.509  0.512
# 582  Zimbabwe    Africa    Subnat  ZWEr110             Bulawayo  0.622  0.626
# 583  Zimbabwe    Africa    Subnat  ZWEr109               Harare  0.623  0.627
# 584  Zimbabwe    Africa    Subnat  ZWEr101           Manicaland  0.471  0.474
# 585  Zimbabwe    Africa    Subnat  ZWEr102  Mashonaland Central  0.450  0.453
# 586  Zimbabwe    Africa    Subnat  ZWEr103     Mashonaland East  0.495  0.498
# 587  Zimbabwe    Africa    Subnat  ZWEr104     Mashonaland West  0.458  0.461
# 588  Zimbabwe    Africa    Subnat  ZWEr108             Masvingo  0.480  0.483
# 589  Zimbabwe    Africa    Subnat  ZWEr105   Matebeleland North  0.458  0.461
# 590  Zimbabwe    Africa    Subnat  ZWEr106   Matebeleland South  0.471  0.474
# 591  Zimbabwe    Africa    Subnat  ZWEr107             Midlands  0.510  0.513
#
# ...

# %%
ag=df2[df2['Country']=='Angola']
ag
# Out:
#    Country Continent     Level  GDLCODE           Region      1990     1991  \
# 8   Angola    Africa  National     AGOt            Total  0.422063  0.42437
# 9   Angola    Africa    Subnat  AGOr218            Bengo  0.422063  0.42437
# 10  Angola    Africa    Subnat  AGOr209         Benguela  0.422063  0.42437
# 11  Angola    Africa    Subnat  AGOr211              Bie  0.422063  0.42437
# 12  Angola    Africa    Subnat  AGOr201          Cabinda  0.422063  0.42437
# 13  Angola    Africa    Subnat  AGOr216           Cunene  0.422063  0.42437
# 14  Angola    Africa    Subnat  AGOr210           Huambo  0.422063  0.42437
# 15  Angola    Africa    Subnat  AGOr215            Huila  0.422063  0.42437
# 16  Angola    Africa    Subnat  AGOr213   Kuando Kubango  0.422063  0.42437
# 17  Angola    Africa    Subnat  AGOr205     Kuanza Norte  0.422063  0.42437
# 18  Angola    Africa    Subnat  AGOr206       Kuanza Sul  0.422063  0.42437
# ...

# %%
df2_1=df2.copy()

# %%
count_df2_1=df2_1.groupby(["Level"])["Level"].count().to_frame()
count_df2_1.rename(columns={"Level":"count"},inplace=True)

# %%
count_df2_1.sort_values(by="count").reset_index()
count_df2_1
# Out:
#           count
# Level
# National     53
# Subnat      539

# %%
sns.distplot(df2['1990'])
# Out:
# C:\Users\Ram\AppData\Local\Temp\ipykernel_13240\4281944568.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['1990'])
# <AxesSubplot: xlabel='1990', ylabel='Density'>

# %%
sns.distplot(df2['1991'])
# Out:
# C:\Users\Ram\AppData\Local\Temp\ipykernel_13240\2179504933.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['1991'])
# <AxesSubplot: xlabel='1991', ylabel='Density'>

# %%
sns.distplot(df2['1992'])
# Out:
# C:\Users\Ram\AppData\Local\Temp\ipykernel_13240\1410698188.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['1992'])
# <AxesSubplot: xlabel='1992', ylabel='Density'>

# %%
sns.distplot(df2['1993'])
# Out:
# C:\Users\Ram\AppData\Local\Temp\ipykernel_13240\603401540.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['1993'])
# <AxesSubplot: xlabel='1993', ylabel='Density'>

# %%
sns.distplot(df2['1994'])
# Out:
# C:\Users\Ram\AppData\Local\Temp\ipykernel_13240\3076177536.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['1994'])
# <AxesSubplot: xlabel='1994', ylabel='Density'>

# %%
df3=df2.copy()

# %%
df3.columns
# Out:
# Index(['Country', 'Continent', 'Level', 'GDLCODE', 'Region', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 37 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    592 non-null    object
#  1   Continent  592 non-null    object
#  2   Level      592 non-null    object
#  3   GDLCODE    592 non-null    object
#  4   Region     592 non-null    object
#  5   1990       592 non-null    float64
#  6   1991       592 non-null    float64
#  7   1992       592 non-null    float64
#  8   1993       592 non-null    float64
#  9   1994       592 non-null    float64
#  10  1995       592 non-null    float64
#  11  1996       592 non-null    float64
#  12  1997       592 non-null    float64
#  13  1998       592 non-null    float64
#  14  1999       592 non-null    float64
#  15  2000       592 non-null    float64
#  16  2001       592 non-null    float64
#  17  2002       592 non-null    float64
#  18  2003       592 non-null    float64
# ...

# %%
df4 = df3[['Country', 'Continent', 'Level', 'GDLCODE', 'Region']]
df4.head()
# Out:
#    Country Continent     Level  GDLCODE  \
# 0  Algeria    Africa  National     DZAt
# 1  Algeria    Africa    Subnat  DZAr104
# 2  Algeria    Africa    Subnat  DZAr105
# 3  Algeria    Africa    Subnat  DZAr106
# 4  Algeria    Africa    Subnat  DZAr101
#
#                                               Region
# 0                                              Total
# 1    Hauts Plateaux Centre (Djelfa, Laghouat, MSila)
# 2  Hauts Plateaux Est (Setif, Batna, Khenchela, B...
# 3  Hauts Plateaux Ouest (Tiaret, Saida, Tissemsil...
# 4  Nord Centre (Alger, Blida, Boumerdes, Tipaza, ...

# %%
df5=df3[['1990', '1991',
       '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
       '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
       '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
       '2019', '2020', '2021']]
df5.head()
# Out:
#     1990   1991   1992   1993   1994   1995   1996   1997   1998   1999  ...  \
# 0  0.591  0.594  0.599  0.601  0.602  0.606  0.617  0.624  0.633  0.641  ...
# 1  0.562  0.565  0.569  0.570  0.571  0.574  0.585  0.592  0.600  0.608  ...
# 2  0.587  0.589  0.594  0.596  0.596  0.600  0.611  0.618  0.626  0.635  ...
# 3  0.573  0.575  0.580  0.582  0.582  0.586  0.597  0.604  0.612  0.620  ...
# 4  0.615  0.618  0.623  0.625  0.627  0.631  0.642  0.650  0.659  0.668  ...
#
#     2012   2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0  0.729  0.731  0.735  0.740  0.743  0.744  0.745  0.748  0.736  0.745
# 1  0.695  0.697  0.703  0.709  0.714  0.716  0.720  0.724  0.712  0.722
# 2  0.729  0.732  0.734  0.737  0.738  0.737  0.737  0.737  0.725  0.735
# 3  0.707  0.710  0.715  0.720  0.724  0.726  0.728  0.732  0.720  0.729
# 4  0.743  0.744  0.750  0.756  0.760  0.762  0.765  0.769  0.757  0.767
#
# [5 rows x 32 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df4=df4.apply(le.fit_transform)
df4.head()
# Out:
#    Country  Continent  Level  GDLCODE  Region
# 0        0          0      0      131     480
# 1        0          0      1      127     223
# 2        0          0      1      128     224
# 3        0          0      1      129     225
# 4        0          0      1      124     348

# %%
df6=pd.concat([df4,df5], axis = 1)
df6.head()
# Out:
#    Country  Continent  Level  GDLCODE  Region   1990   1991   1992   1993  \
# 0        0          0      0      131     480  0.591  0.594  0.599  0.601
# 1        0          0      1      127     223  0.562  0.565  0.569  0.570
# 2        0          0      1      128     224  0.587  0.589  0.594  0.596
# 3        0          0      1      129     225  0.573  0.575  0.580  0.582
# 4        0          0      1      124     348  0.615  0.618  0.623  0.625
#
#     1994  ...   2012   2013   2014   2015   2016   2017   2018   2019   2020  \
# 0  0.602  ...  0.729  0.731  0.735  0.740  0.743  0.744  0.745  0.748  0.736
# 1  0.571  ...  0.695  0.697  0.703  0.709  0.714  0.716  0.720  0.724  0.712
# 2  0.596  ...  0.729  0.732  0.734  0.737  0.738  0.737  0.737  0.737  0.725
# 3  0.582  ...  0.707  0.710  0.715  0.720  0.724  0.726  0.728  0.732  0.720
# 4  0.627  ...  0.743  0.744  0.750  0.756  0.760  0.762  0.765  0.769  0.757
#
#     2021
# 0  0.745
# 1  0.722
# 2  0.735
# 3  0.729
# ...

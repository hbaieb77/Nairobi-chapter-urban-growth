# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('population_economy_africa_2000_2020.csv')

# %%
df
# Out:
#        SDG  SDG target   SDG indicator  Indicator Code  \
# 0      NaN         NaN  AG.LND.AGRI.ZS  AG.LND.AGRI.ZS
# 1      NaN         NaN  AG.LND.AGRI.ZS  AG.LND.AGRI.ZS
# 2      NaN         NaN  AG.LND.AGRI.ZS  AG.LND.AGRI.ZS
# 3      NaN         NaN  AG.LND.AGRI.ZS  AG.LND.AGRI.ZS
# 4      NaN         NaN  AG.LND.AGRI.ZS  AG.LND.AGRI.ZS
# ...    ...         ...             ...             ...
# 33534  NaN         NaN             NaN             NaN
# 33535  NaN         NaN             NaN             NaN
# 33536  NaN         NaN             NaN             NaN
# 33537  NaN         NaN             NaN             NaN
# 33538  NaN         NaN             NaN             NaN
#
#                            Indicator name Geographical area code  \
# 0      Agricultural land (% of land area)                Country
# 1      Agricultural land (% of land area)                Country
# 2      Agricultural land (% of land area)                Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33539 entries, 0 to 33538
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   SDG                      0 non-null      float64
#  1   SDG target               0 non-null      float64
#  2   SDG indicator            33503 non-null  object
#  3   Indicator Code           33503 non-null  object
#  4   Indicator name           33503 non-null  object
#  5   Geographical area code   33503 non-null  object
#  6   Geographical area name   33503 non-null  object
#  7   Year                     33503 non-null  float64
#  8   Value                    27228 non-null  float64
#  9   Time detail              0 non-null      float64
#  10  Source                   26724 non-null  object
#  11  Footnote                 0 non-null      float64
#  12  Type of data             0 non-null      float64
#  13  Units                    26717 non-null  object
# ...

# %%
df.isnull().mean()
# Out:
# SDG                        1.000000
# SDG target                 1.000000
# SDG indicator              0.001073
# Indicator Code             0.001073
# Indicator name             0.001073
# Geographical area code     0.001073
# Geographical area name     0.001073
# Year                       0.001073
# Value                      0.188169
# Time detail                1.000000
# Source                     0.203196
# Footnote                   1.000000
# Type of data               1.000000
# Units                      0.203405
# Age group                  1.000000
# Bounds                     1.000000
# Frequency                  1.000000
# Level/Status               1.000000
# Location                   1.000000
# Type of reporting          1.000000
# Sex                        1.000000
# SDG 6 Data portal level    0.001073
# dtype: float64

# %%
missing_data = df.isnull().mean()

# %%
missing_data[missing_data<1]
# Out:
# SDG indicator              0.001073
# Indicator Code             0.001073
# Indicator name             0.001073
# Geographical area code     0.001073
# Geographical area name     0.001073
# Year                       0.001073
# Value                      0.188169
# Source                     0.203196
# Units                      0.203405
# SDG 6 Data portal level    0.001073
# dtype: float64

# %%
missing_data[missing_data==1]
# Out:
# SDG                  1.0
# SDG target           1.0
# Time detail          1.0
# Footnote             1.0
# Type of data         1.0
# Age group            1.0
# Bounds               1.0
# Frequency            1.0
# Level/Status         1.0
# Location             1.0
# Type of reporting    1.0
# Sex                  1.0
# dtype: float64

# %%
df = df.dropna(axis=1, how='all')

# %%
df.isnull().mean()
# Out:
# SDG indicator              0.001073
# Indicator Code             0.001073
# Indicator name             0.001073
# Geographical area code     0.001073
# Geographical area name     0.001073
# Year                       0.001073
# Value                      0.188169
# Source                     0.203196
# Units                      0.203405
# SDG 6 Data portal level    0.001073
# dtype: float64

# %%
df['SDG indicator'].unique()
# Out:
# array(['AG.LND.AGRI.ZS', 'AG.LND.FRST.ZS', 'AG.LND.TOTL.K2',
#        'AG.SRF.TOTL.K2', 'EG.ELC.ACCS.RU.ZS', 'EG.ELC.ACCS.UR.ZS',
#        'EG.ELC.ACCS.ZS', 'EG.FEC.RNEW.ZS', 'EG.USE.PCAP.KG.OE',
#        'EN.ATM.CO2E.PC', 'EN.ATM.PM25.MC.ZS', 'EN.POP.DNST', 'GII', 'HDI',
#        'NV.AGR.TOTL.ZS', 'NV.IND.TOTL.ZS', 'NV.SRV.TOTL.ZS',
#        'NY.GDP.MKTP.PP.KD', 'NY.GDP.PCAP.PP.KD', 'NY.GNP.MKTP.PP.KD',
#        'NY.GNP.PCAP.PP.KD', 'SE.ENR.PRIM.FM.ZS', 'SE.ENR.SECO.FM.ZS',
#        'SE.ENR.TERT.FM.ZS', 'SE.PRM.CMPT.ZS', 'SI.POV.DDAY',
#        'SI.POV.GINI', 'SI.POV.NAHC', 'SP.POP.TOTL', 'SP.RUR.TOTL',
#        'SP.URB.TOTL', nan], dtype=object)

# %%
df.tail(10)
# Out:
#       SDG indicator Indicator Code Indicator name Geographical area code  \
# 33529           NaN            NaN            NaN                    NaN
# 33530           NaN            NaN            NaN                    NaN
# 33531           NaN            NaN            NaN                    NaN
# 33532           NaN            NaN            NaN                    NaN
# 33533           NaN            NaN            NaN                    NaN
# 33534           NaN            NaN            NaN                    NaN
# 33535           NaN            NaN            NaN                    NaN
# 33536           NaN            NaN            NaN                    NaN
# 33537           NaN            NaN            NaN                    NaN
# 33538           NaN            NaN            NaN                    NaN
#
#       Geographical area name  Year  Value Source Units SDG 6 Data portal level
# 33529                    NaN   NaN    NaN    NaN   NaN                     NaN
# ...

# %%
df = df.dropna(axis=0, how='all')

# %%
df.isnull().sum()
# Out:
# SDG indicator                 0
# Indicator Code                0
# Indicator name                0
# Geographical area code        0
# Geographical area name        0
# Year                          0
# Value                      6275
# Source                     6779
# Units                      6786
# SDG 6 Data portal level       0
# dtype: int64

# %%
df['Value']
# Out:
# 0        1.463206e+01
# 1        8.780704e+00
# 2        6.964267e+01
# 3        5.016971e+01
# 4        3.163442e+01
#              ...
# 33498    1.141421e+07
# 33499    4.378173e+07
# 33500    2.104257e+07
# 33501    6.397866e+06
# 33502    8.204576e+06
# Name: Value, Length: 33503, dtype: float64

# %%
df.describe()
# Out:
#                Year         Value
# count  33503.000000  2.722800e+04
# mean    2009.612214  1.180690e+10
# std        5.828458  1.371490e+11
# min     2000.000000  1.631270e-02
# 25%     2005.000000  1.399175e+01
# 50%     2010.000000  6.588110e+01
# 75%     2015.000000  1.184800e+05
# max     2021.000000  4.305966e+12

# %%
df
# Out:
#         SDG indicator  Indicator Code                      Indicator name  \
# 0      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 1      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 2      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 3      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 4      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# ...               ...             ...                                 ...
# 33498     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33499     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33500     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33501     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33502     SP.URB.TOTL     SP.URB.TOTL                    Urban population
#
#       Geographical area code       Geographical area name    Year  \
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean')

# %%
df['Value'] = imputer.fit_transform(df[['Value']]).reshape(-1, 1)

# %%
df.Value.isnull().mean()
# Out:
# 0.0

# %%
df['Source'].unique()
# Out:
# array(['World Bank', nan, 'UNDP',
#        '(1) United Nations Population Division. World Population Prospects: 2019 Revision. (2) Census reports and other statistical publications from national statistical offices, (3) Eurostat: Demographic Statistics, (4) United Nations Statistical Division. Population and Vital Statistics Reprot (various years), (5) U.S. Census Bureau: International Database, and (6) Secretariat of the Pacific Community: Statistics and Demography Programme.'],
#       dtype=object)

# %%
df = df.drop(columns=['Source'],axis=1)

# %%
df
# Out:
#         SDG indicator  Indicator Code                      Indicator name  \
# 0      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 1      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 2      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 3      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 4      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# ...               ...             ...                                 ...
# 33498     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33499     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33500     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33501     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33502     SP.URB.TOTL     SP.URB.TOTL                    Urban population
#
#       Geographical area code       Geographical area name    Year  \
# ...

# %%
df.Units.unique()
# Out:
# array(['Number of people', nan,
#        'Index between 0 and 1, where 0 expresses the highest level of equality',
#        'Index between 0 and 1, where 1 expresses the highest level of human development'],
#       dtype=object)

# %%
df.Units.value_counts()
# Out:
# Number of people                                                                   25203
# Index between 0 and 1, where 1 expresses the highest level of human development     1037
# Index between 0 and 1, where 0 expresses the highest level of equality               477
# Name: Units, dtype: int64

# %%
df = df.dropna(subset=['Units'])

# %%
df
# Out:
#         SDG indicator  Indicator Code                      Indicator name  \
# 0      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 1      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 2      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 3      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 4      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# ...               ...             ...                                 ...
# 33498     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33499     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33500     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33501     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 33502     SP.URB.TOTL     SP.URB.TOTL                    Urban population
#
#       Geographical area code       Geographical area name    Year  \
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#        index   SDG indicator  Indicator Code  \
# 0          0  AG.LND.AGRI.ZS  AG.LND.AGRI.ZS
# 1          1  AG.LND.AGRI.ZS  AG.LND.AGRI.ZS
# 2          2  AG.LND.AGRI.ZS  AG.LND.AGRI.ZS
# 3          3  AG.LND.AGRI.ZS  AG.LND.AGRI.ZS
# 4          4  AG.LND.AGRI.ZS  AG.LND.AGRI.ZS
# ...      ...             ...             ...
# 26712  33498     SP.URB.TOTL     SP.URB.TOTL
# 26713  33499     SP.URB.TOTL     SP.URB.TOTL
# 26714  33500     SP.URB.TOTL     SP.URB.TOTL
# 26715  33501     SP.URB.TOTL     SP.URB.TOTL
# 26716  33502     SP.URB.TOTL     SP.URB.TOTL
#
#                            Indicator name Geographical area code  \
# 0      Agricultural land (% of land area)                Country
# 1      Agricultural land (% of land area)                Country
# 2      Agricultural land (% of land area)                Country
# 3      Agricultural land (% of land area)                Country
# 4      Agricultural land (% of land area)                Country
# ...

# %%
df = df.drop(columns=['index'])

# %%
df
# Out:
#         SDG indicator  Indicator Code                      Indicator name  \
# 0      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 1      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 2      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 3      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 4      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# ...               ...             ...                                 ...
# 26712     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26713     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26714     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26715     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26716     SP.URB.TOTL     SP.URB.TOTL                    Urban population
#
#       Geographical area code       Geographical area name    Year  \
# ...

# %%
df['Year'] = df['Year'].astype('int')

# %%
df
# Out:
#         SDG indicator  Indicator Code                      Indicator name  \
# 0      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 1      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 2      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 3      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 4      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# ...               ...             ...                                 ...
# 26712     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26713     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26714     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26715     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26716     SP.URB.TOTL     SP.URB.TOTL                    Urban population
#
#       Geographical area code       Geographical area name  Year         Value  \
# ...

# %%
df['Country'] = 'Africa'

# %%
df
# Out:
#         SDG indicator  Indicator Code                      Indicator name  \
# 0      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 1      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 2      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 3      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# 4      AG.LND.AGRI.ZS  AG.LND.AGRI.ZS  Agricultural land (% of land area)
# ...               ...             ...                                 ...
# 26712     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26713     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26714     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26715     SP.URB.TOTL     SP.URB.TOTL                    Urban population
# 26716     SP.URB.TOTL     SP.URB.TOTL                    Urban population
#
#       Geographical area code       Geographical area name  Year         Value  \
# ...

# %%
df = df.drop(columns=['SDG indicator','Indicator Code','Geographical area code','Country'],axis=1)

# %%
df
# Out:
#                            Indicator name       Geographical area name  Year  \
# 0      Agricultural land (% of land area)                      Liberia  2000
# 1      Agricultural land (% of land area)                        Libya  2000
# 2      Agricultural land (% of land area)                   Madagascar  2000
# 3      Agricultural land (% of land area)                       Malawi  2000
# 4      Agricultural land (% of land area)                         Mali  2000
# ...                                   ...                          ...   ...
# 26712                    Urban population                       Uganda  2020
# 26713                    Urban population                        Egypt  2020
# 26714                    Urban population  United Republic of Tanzania  2020
# 26715                    Urban population                 Burkina Faso  2020
# 26716                    Urban population                       Zambia  2020
#
#               Value             Units  \
# ...

# %%
df
# Out:
#                            Indicator name       Geographical area name  Year  \
# 0      Agricultural land (% of land area)                      Liberia  2000
# 1      Agricultural land (% of land area)                        Libya  2000
# 2      Agricultural land (% of land area)                   Madagascar  2000
# 3      Agricultural land (% of land area)                       Malawi  2000
# 4      Agricultural land (% of land area)                         Mali  2000
# ...                                   ...                          ...   ...
# 26712                    Urban population                       Uganda  2020
# 26713                    Urban population                        Egypt  2020
# 26714                    Urban population  United Republic of Tanzania  2020
# 26715                    Urban population                 Burkina Faso  2020
# 26716                    Urban population                       Zambia  2020
#
#               Value             Units  \
# ...

# %%
df = df.rename(columns={'Geographical area name':'Country'})

# %%
df
# Out:
#                            Indicator name                      Country  Year  \
# 0      Agricultural land (% of land area)                      Liberia  2000
# 1      Agricultural land (% of land area)                        Libya  2000
# 2      Agricultural land (% of land area)                   Madagascar  2000
# 3      Agricultural land (% of land area)                       Malawi  2000
# 4      Agricultural land (% of land area)                         Mali  2000
# ...                                   ...                          ...   ...
# 26712                    Urban population                       Uganda  2020
# 26713                    Urban population                        Egypt  2020
# 26714                    Urban population  United Republic of Tanzania  2020
# 26715                    Urban population                 Burkina Faso  2020
# 26716                    Urban population                       Zambia  2020
#
#               Value             Units  \
# ...

# %%
pivot_table = pd.pivot_table(df,index=["Country", "Year"], columns="Indicator name", values="Value")

# %%
pivot_table.reset_index()
# Out:
# Indicator name   Country  Year  Agricultural land (% of land area)  \
# 0                Algeria  2000                           16.803261
# 1                Algeria  2001                           16.840209
# 2                Algeria  2002                           16.733565
# 3                Algeria  2003                           16.754851
# 4                Algeria  2004                           17.275185
# ...                  ...   ...                                 ...
# 1198            Zimbabwe  2017                           41.876696
# 1199            Zimbabwe  2018                           41.876696
# 1200            Zimbabwe  2019                                 NaN
# 1201            Zimbabwe  2020                                 NaN
# 1202            Zimbabwe  2021                                 NaN
#
# Indicator name  CO2 emissions  Energy use per capita  \
# 0                    2.531712             869.609756
# ...

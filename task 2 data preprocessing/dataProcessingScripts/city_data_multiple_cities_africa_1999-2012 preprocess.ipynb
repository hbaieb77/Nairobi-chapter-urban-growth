# %%
import pandas as pd

# %%
df = pd.read_csv('city_data_multiple_cities_africa_1999-2012.csv')

# %%
df.head(3)
# Out:
#   Indicator (italics indicate national -level data)  \
# 0                                               NaN
# 1                 Annual city growth rate 1995-2010
# 2             Share of city in national population
#
#                             Unit   \
# 0                             NaN
# 1  % of growth from previous year
# 2       % of national population
#
#                                               Source  \
# 0                                                NaN
# 1  UNDESA 2012 World Urbanization Prospects: The ...
# 2  UNDESA 2010 World Urbanization Prospects: The ...
#
#   Year of source consulted(* indicates year of creation of institution, if available)  \
# 0                                                NaN
# 1                                               2012
# 2                                               2010
#
#   Maputo, Mozambique Ibadan, Nigeria Kano, Nigeria  \
# 0                NaN             NaN           NaN
# ...

# %% [markdown]
# ### Remove columns

# %%
df.columns
# Out:
# Index(['Indicator (italics indicate national -level data)', 'Unit ', 'Source',
#        'Year of source consulted(* indicates year of creation of institution, if available)',
#        'Maputo, Mozambique', 'Ibadan, Nigeria', 'Kano, Nigeria',
#        'Johannesburg, South Africa', 'Cape Town, South Africa',
#        'Durban, South Africa', 'Al-Khartum (Khartoum), Sudan',
#        'Lusaka, Zambia ', 'Harare, Zimbabwe', 'Cotonou, Benin',
#        'Douala, Cameroon', 'Yaoundé, Cameroon', 'Abidjan, Cote d'Ivoire ',
#        'Addis Ababa, Ethiopia', 'Accra, Ghana', 'Kumasi, Ghana',
#        'Conakry, Guinea', 'Nairobi, Kenya', 'Lagos, Nigeria', 'Dakar, Senegal',
#        'Kampala, Uganda', 'Luanda, Angola', 'Ouagadougou, Burkina Faso',
#        'Kinshasa, Democratic Republic of the Congo',
#        'Lubumbashi, Democratic Republic of the Congo',
#        'Mbuji-Mayi, Democratic Republic of the Congo', 'Brazzaville, Congo',
#        'Blantyre, Malawi', 'Lilongwe, Malawi', 'Abuja, Nigeria',
# ...

# %%
df = df.drop(columns=[ 'Unit ', 'Source','Year of source consulted(* indicates year of creation of institution, if available)'
       ],axis=1)

# %%
df = df.rename(columns={'Indicator (italics indicate national -level data)':'Indicator'})

# %%
df.shape
# Out:
# (303, 32)

# %% [markdown]
# ### Handling missing values

# %%
df = df.tail(-1)

# %%
df
# Out:
#                                              Indicator Maputo, Mozambique  \
# 1                    Annual city growth rate 1995-2010               1.37
# 2                Share of city in national population                 6.9
# 3    Projection, Share of city in national populati...                9.8
# 4                                        City density                7000
# 5    Solid waste collected (public and private coll...                 70
# ..                                                 ...                ...
# 298                                     Cholera cases                 NaN
# 299                                     Cholera cases                 NaN
# 300                                     Cholera cases                 NaN
# 301                                     Cholera cases                 NaN
# 302                                       Flood events                 10
#
#     Ibadan, Nigeria Kano, Nigeria  Johannesburg, South Africa  \
# ...

# %%
df.isnull().sum()
# Out:
# Indicator                                         0
# Maputo, Mozambique                              268
# Ibadan, Nigeria                                 275
# Kano, Nigeria                                   279
# Johannesburg, South Africa                      270
# Cape Town, South Africa                         269
# Durban, South Africa                            272
# Al-Khartum (Khartoum), Sudan                    273
# Lusaka, Zambia                                  273
# Harare, Zimbabwe                                284
# Cotonou, Benin                                  270
# Douala, Cameroon                                275
# Yaoundé, Cameroon                               279
# Abidjan, Cote d'Ivoire                          280
# Addis Ababa, Ethiopia                           273
# Accra, Ghana                                    271
# Kumasi, Ghana                                   278
# Conakry, Guinea                                 278
# ...

# %%
df.head()
# Out:
#                                            Indicator Maputo, Mozambique  \
# 1                  Annual city growth rate 1995-2010               1.37
# 2              Share of city in national population                 6.9
# 3  Projection, Share of city in national populati...                9.8
# 4                                      City density                7000
# 5  Solid waste collected (public and private coll...                 70
#
#   Ibadan, Nigeria Kano, Nigeria  Johannesburg, South Africa  \
# 1            2.39          2.23                        2.38
# 2             1.7           2.1                        7.30
# 3             1.6           2.2                        7.60
# 4            7900         15600                     2900.00
# 5             NaN           NaN                         NaN
#
#    Cape Town, South Africa  Durban, South Africa  \
# 1                     2.52                  2.33
# 2                     6.70                  5.70
# ...

# %%
nan_rows = df[df.isna().all(axis=1)]

# %%
nan_rows
# Out:
# Empty DataFrame
# Columns: [Indicator, Maputo, Mozambique, Ibadan, Nigeria, Kano, Nigeria, Johannesburg, South Africa, Cape Town, South Africa, Durban, South Africa, Al-Khartum (Khartoum), Sudan, Lusaka, Zambia , Harare, Zimbabwe, Cotonou, Benin, Douala, Cameroon, Yaoundé, Cameroon, Abidjan, Cote d'Ivoire , Addis Ababa, Ethiopia, Accra, Ghana, Kumasi, Ghana, Conakry, Guinea, Nairobi, Kenya, Lagos, Nigeria, Dakar, Senegal, Kampala, Uganda, Luanda, Angola, Ouagadougou, Burkina Faso, Kinshasa, Democratic Republic of the Congo, Lubumbashi, Democratic Republic of the Congo, Mbuji-Mayi, Democratic Republic of the Congo, Brazzaville, Congo, Blantyre, Malawi, Lilongwe, Malawi, Abuja, Nigeria, Dar es Salaam, Tanzania]
# Index: []
#
# [0 rows x 32 columns]

# %%
df = df.dropna(how='all')

# %%
df
# Out:
#                                              Indicator Maputo, Mozambique  \
# 1                    Annual city growth rate 1995-2010               1.37
# 2                Share of city in national population                 6.9
# 3    Projection, Share of city in national populati...                9.8
# 4                                        City density                7000
# 5    Solid waste collected (public and private coll...                 70
# ..                                                 ...                ...
# 298                                     Cholera cases                 NaN
# 299                                     Cholera cases                 NaN
# 300                                     Cholera cases                 NaN
# 301                                     Cholera cases                 NaN
# 302                                       Flood events                 10
#
#     Ibadan, Nigeria Kano, Nigeria  Johannesburg, South Africa  \
# ...

# %%
df.head(20)
# Out:
#                                             Indicator Maputo, Mozambique  \
# 1                   Annual city growth rate 1995-2010               1.37
# 2               Share of city in national population                 6.9
# 3   Projection, Share of city in national populati...                9.8
# 4                                       City density                7000
# 5   Solid waste collected (public and private coll...                 70
# 6   Solid waste collected (public and private coll...                NaN
# 7   Solid waste collected (public and private coll...                NaN
# 8   Solid waste collected (public and private coll...                NaN
# 9   Solid waste collected (public and private coll...                NaN
# 10  Solid waste collected (public and private coll...                NaN
# 11  Solid waste collected (public and private coll...                NaN
# 12  Solid waste collected (public and private coll...                NaN
# ...

# %% [markdown]
# ### Handle missing values

# %%
import missingno as mngo

# %%
mngo.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.fillna(df.median())
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3860\2553712938.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.median())
#                                              Indicator Maputo, Mozambique  \
# 1                    Annual city growth rate 1995-2010               1.37
# 2                Share of city in national population                 6.9
# 3    Projection, Share of city in national populati...                9.8
# 4                                        City density                7000
# 5    Solid waste collected (public and private coll...                 70
# ..                                                 ...                ...
# 298                                     Cholera cases                 NaN
# 299                                     Cholera cases                 NaN
# ...

# %%
df.isnull().mean()
# Out:
# Indicator                                       0.000000
# Maputo, Mozambique                              0.887417
# Ibadan, Nigeria                                 0.910596
# Kano, Nigeria                                   0.923841
# Johannesburg, South Africa                      0.894040
# Cape Town, South Africa                         0.890728
# Durban, South Africa                            0.900662
# Al-Khartum (Khartoum), Sudan                    0.903974
# Lusaka, Zambia                                  0.903974
# Harare, Zimbabwe                                0.940397
# Cotonou, Benin                                  0.894040
# Douala, Cameroon                                0.910596
# Yaoundé, Cameroon                               0.923841
# Abidjan, Cote d'Ivoire                          0.927152
# Addis Ababa, Ethiopia                           0.903974
# Accra, Ghana                                    0.897351
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#                                              Indicator Maputo, Mozambique  \
# 2                Share of city in national population                 6.9
# 3    Projection, Share of city in national populati...                9.8
# 4                                        City density                7000
# 150              Average Annual Runoff at Basin Level               56.37
# 151                                     Low flow (Q90)              27.27
# 152                                    High flow (Q10)              93.10
# 153                                           Baseflow              19.87
# 154                                        Basin Yield              42.16
# 302                                       Flood events                 10
#
#     Ibadan, Nigeria Kano, Nigeria  Johannesburg, South Africa  \
# 2               1.7           2.1                        7.30
# 3               1.6           2.2                        7.60
# ...

# %%
df = df.reset_index()

# %%
df = df.drop(columns=['index'],axis=1)

# %%
df
# Out:
#                                            Indicator Maputo, Mozambique  \
# 0              Share of city in national population                 6.9
# 1  Projection, Share of city in national populati...                9.8
# 2                                      City density                7000
# 3              Average Annual Runoff at Basin Level               56.37
# 4                                     Low flow (Q90)              27.27
# 5                                    High flow (Q10)              93.10
# 6                                           Baseflow              19.87
# 7                                        Basin Yield              42.16
# 8                                       Flood events                 10
#
#   Ibadan, Nigeria Kano, Nigeria  Johannesburg, South Africa  \
# 0             1.7           2.1                        7.30
# 1             1.6           2.2                        7.60
# 2            7900         15600                     2900.00
# ...

# %%
df.columns
# Out:
# Index(['Indicator', 'Maputo, Mozambique', 'Ibadan, Nigeria', 'Kano, Nigeria',
#        'Johannesburg, South Africa', 'Cape Town, South Africa',
#        'Durban, South Africa', 'Al-Khartum (Khartoum), Sudan',
#        'Lusaka, Zambia ', 'Harare, Zimbabwe', 'Cotonou, Benin',
#        'Douala, Cameroon', 'Yaoundé, Cameroon', 'Abidjan, Cote d'Ivoire ',
#        'Addis Ababa, Ethiopia', 'Accra, Ghana', 'Kumasi, Ghana',
#        'Conakry, Guinea', 'Nairobi, Kenya', 'Lagos, Nigeria', 'Dakar, Senegal',
#        'Kampala, Uganda', 'Luanda, Angola', 'Ouagadougou, Burkina Faso',
#        'Kinshasa, Democratic Republic of the Congo',
#        'Lubumbashi, Democratic Republic of the Congo',
#        'Mbuji-Mayi, Democratic Republic of the Congo', 'Brazzaville, Congo',
#        'Blantyre, Malawi', 'Lilongwe, Malawi', 'Abuja, Nigeria',
#        'Dar es Salaam, Tanzania'],
#       dtype='object')

# %%
df
# Out:
#                                            Indicator Maputo, Mozambique  \
# 0              Share of city in national population                 6.9
# 1  Projection, Share of city in national populati...                9.8
# 2                                      City density                7000
# 3              Average Annual Runoff at Basin Level               56.37
# 4                                     Low flow (Q90)              27.27
# 5                                    High flow (Q10)              93.10
# 6                                           Baseflow              19.87
# 7                                        Basin Yield              42.16
# 8                                       Flood events                 10
#
#   Ibadan, Nigeria Kano, Nigeria  Johannesburg, South Africa  \
# 0             1.7           2.1                        7.30
# 1             1.6           2.2                        7.60
# 2            7900         15600                     2900.00
# ...

# %%
df.columns
# Out:
# Index(['Indicator', 'Maputo, Mozambique', 'Ibadan, Nigeria', 'Kano, Nigeria',
#        'Johannesburg, South Africa', 'Cape Town, South Africa',
#        'Durban, South Africa', 'Al-Khartum (Khartoum), Sudan',
#        'Lusaka, Zambia ', 'Harare, Zimbabwe', 'Cotonou, Benin',
#        'Douala, Cameroon', 'Yaoundé, Cameroon', 'Abidjan, Cote d'Ivoire ',
#        'Addis Ababa, Ethiopia', 'Accra, Ghana', 'Kumasi, Ghana',
#        'Conakry, Guinea', 'Nairobi, Kenya', 'Lagos, Nigeria', 'Dakar, Senegal',
#        'Kampala, Uganda', 'Luanda, Angola', 'Ouagadougou, Burkina Faso',
#        'Kinshasa, Democratic Republic of the Congo',
#        'Lubumbashi, Democratic Republic of the Congo',
#        'Mbuji-Mayi, Democratic Republic of the Congo', 'Brazzaville, Congo',
#        'Blantyre, Malawi', 'Lilongwe, Malawi', 'Abuja, Nigeria',
#        'Dar es Salaam, Tanzania'],
#       dtype='object')

# %%
df
# Out:
#                                            Indicator Maputo, Mozambique  \
# 0              Share of city in national population                 6.9
# 1  Projection, Share of city in national populati...                9.8
# 2                                      City density                7000
# 3              Average Annual Runoff at Basin Level               56.37
# 4                                     Low flow (Q90)              27.27
# 5                                    High flow (Q10)              93.10
# 6                                           Baseflow              19.87
# 7                                        Basin Yield              42.16
# 8                                       Flood events                 10
#
#   Ibadan, Nigeria Kano, Nigeria  Johannesburg, South Africa  \
# 0             1.7           2.1                        7.30
# 1             1.6           2.2                        7.60
# 2            7900         15600                     2900.00
# ...

# %%
df = df.transpose()
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header
df.index.name = 'City'
df = df.reset_index()

# %%
df
# Out:
# Indicator                                          City  \
# 0                                    Maputo, Mozambique
# 1                                       Ibadan, Nigeria
# 2                                         Kano, Nigeria
# 3                            Johannesburg, South Africa
# 4                               Cape Town, South Africa
# 5                                  Durban, South Africa
# 6                          Al-Khartum (Khartoum), Sudan
# 7                                       Lusaka, Zambia
# 8                                      Harare, Zimbabwe
# 9                                        Cotonou, Benin
# 10                                     Douala, Cameroon
# 11                                    Yaoundé, Cameroon
# 12                              Abidjan, Cote d'Ivoire
# 13                                Addis Ababa, Ethiopia
# 14                                         Accra, Ghana
# 15                                        Kumasi, Ghana
# ...

# %%
df = df.drop(range(0,1))

# %%
df
# Out:
# Indicator                                          City  \
# 1                                       Ibadan, Nigeria
# 2                                         Kano, Nigeria
# 3                            Johannesburg, South Africa
# 4                               Cape Town, South Africa
# 5                                  Durban, South Africa
# 6                          Al-Khartum (Khartoum), Sudan
# 7                                       Lusaka, Zambia
# 8                                      Harare, Zimbabwe
# 9                                        Cotonou, Benin
# 10                                     Douala, Cameroon
# 11                                    Yaoundé, Cameroon
# 12                              Abidjan, Cote d'Ivoire
# 13                                Addis Ababa, Ethiopia
# 14                                         Accra, Ghana
# 15                                        Kumasi, Ghana
# 16                                      Conakry, Guinea
# ...

# %%
df.columns
# Out:
# Index(['City', 'Share of city in national population ',
#        'Projection, Share of city in national population in 2025',
#        'City density ', 'Average Annual Runoff at Basin Level ',
#        'Low flow (Q90)', 'High flow (Q10)', 'Baseflow', 'Basin Yield',
#        'Flood events'],
#       dtype='object', name='Indicator')

# %%
df['Country'] = 'Africa'

# %%
df
# Out:
# Indicator                                          City  \
# 1                                       Ibadan, Nigeria
# 2                                         Kano, Nigeria
# 3                            Johannesburg, South Africa
# 4                               Cape Town, South Africa
# 5                                  Durban, South Africa
# 6                          Al-Khartum (Khartoum), Sudan
# 7                                       Lusaka, Zambia
# 8                                      Harare, Zimbabwe
# 9                                        Cotonou, Benin
# 10                                     Douala, Cameroon
# 11                                    Yaoundé, Cameroon
# 12                              Abidjan, Cote d'Ivoire
# 13                                Addis Ababa, Ethiopia
# 14                                         Accra, Ghana
# 15                                        Kumasi, Ghana
# 16                                      Conakry, Guinea
# ...

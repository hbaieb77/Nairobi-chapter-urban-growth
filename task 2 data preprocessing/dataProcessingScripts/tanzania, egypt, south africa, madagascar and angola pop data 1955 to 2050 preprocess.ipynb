# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tanzania_1955_to_2050_pop_data.csv' ,engine='python',encoding="cp1252")
df_1 = pd.read_excel('angola_population_1955_to_2020.xlsx')
df_2 = pd.read_csv('egypt_1955_to_2050_pop_data.csv',engine='python',encoding="cp1252")
df_3 = pd.read_csv('south africa_1955_to_2050_pop_data.csv',engine='python',encoding="cp1252")
df_4 = pd.read_csv('madagascar_population_1955_to_2020.csv',engine='python',encoding="cp1252")

# %%
df_4.head()
# Out:
#      Year  Population Yearly %   Yearly Migrants (net)  Median Age  \
# 0     NaN         NaN   Change   Change            NaN         NaN
# 1  2020.0  27,691,018    2.68%  721,711         -1,500        19.6
# 2  2019.0  26,969,307    2.69%  706,994         -1,500        18.9
# 3  2018.0  26,262,313    2.71%  691,801         -1,500        18.9
# 4  2017.0  25,570,512    2.72%  676,142         -1,500        18.9
#
#    Fertility Rate  Density (P/Km²)   Urban Urban Population  \
# 0             NaN              NaN   Pop %              NaN
# 1            4.11             48.0  38.50%       10,670,252
# 2            4.34             46.0  37.90%       10,211,029
# 3            4.34             45.0  37.20%        9,767,285
# 4            4.34             44.0  36.50%        9,339,025
#
#   Country's Share of World Population   Madagascar
# 0          World Pop              NaN  Global Rank
# 1              0.36%    7,794,798,739           51
# ...

# %%
df_3.head()
# Out:
#      Year   Population Yearly %    Yearly Migrants (net)  Median Age  \
# 0     NaN          NaN   Change    Change            NaN         NaN
# 1  2050.0  7,55,17,920    0.51%  3,79,675            NaN        33.9
# 2  2045.0  7,36,19,543    0.62%  4,48,848         58,397        32.7
# 3  2040.0  7,13,75,305    0.73%  5,11,264         59,663        31.6
# 4  2035.0  6,88,18,987    0.85%  5,72,581         76,008        30.5
#
#    Fertility Rate  Density (P/Km²)   Urban Urban Population Country's Share   \
# 0             NaN              NaN   Pop %              NaN     of World Pop
# 1            2.41             62.0  76.90%      5,80,56,843            0.78%
# 2            2.41             61.0  75.30%      5,54,47,449            0.78%
# 3            2.41             59.0  73.70%      5,26,25,241            0.78%
# 4            2.41             57.0  72.10%      4,96,31,106            0.77%
#
#   World Population South Africa
# 0              NaN  Global Rank
# ...

# %%
df_2.head()
# Out:
#      Year    Population Yearly %     Yearly Migrants (net)  Median Age  \
# 0     NaN           NaN   Change     Change            NaN         NaN
# 1  2050.0  15,99,56,808    1.25%  19,20,351            NaN        29.7
# 2  2045.0  15,03,55,053    1.39%  20,00,934        -30,000        28.5
# 3  2040.0  14,03,50,381    1.49%  20,02,003        -30,000        27.3
# 4  2035.0  13,03,40,364    1.53%  19,01,761        -30,000        26.2
#
#    Fertility Rate  Density (P/Km²)   Urban Urban Population Country's Share  \
# 0             NaN              NaN   Pop %              NaN    of World Pop
# 1            3.33            161.0  53.30%      8,53,20,777           1.64%
# 2            3.33            151.0  50.80%      7,64,39,477           1.59%
# 3            3.33            141.0  48.30%      6,77,30,752           1.53%
# 4            3.33            131.0  46.00%      5,99,88,198           1.47%
#
#   World Population        Egypt
# 0              NaN  Global Rank
# ...

# %%
df
# Out:
#       Year    Population Yearly %     Yearly Migrants (net)  Median Age  \
# 0      NaN           NaN   Change     Change            NaN         NaN
# 1   2050.0  12,93,86,839    2.28%  27,58,164            NaN        22.3
# 2   2045.0  11,55,96,020    2.42%  26,01,898        -40,154        21.5
# 3   2040.0  10,25,86,529    2.56%  24,34,187        -40,132        20.7
# 4   2035.0   9,04,15,596    2.69%  22,50,574        -40,116        20.0
# 5   2030.0   7,91,62,725    2.81%  20,45,712        -40,102        19.3
# 6   2025.0   6,89,34,163    2.91%  18,39,989        -40,086        18.6
# 7   2020.0   5,97,34,218    2.98%  17,28,755        -40,076        18.0
# 8   2019.0   5,80,05,463    3.00%  16,92,025        -40,076        17.6
# 9   2018.0   5,63,13,438    3.02%  16,53,099        -40,076        17.6
# 10  2017.0   5,46,60,339    3.04%  16,11,109        -40,076        17.6
# 11  2016.0   5,30,49,230    3.04%  15,66,597        -40,076        17.6
# ...

# %% [markdown]
# ### Change Column Names

# %%
df = df.rename(columns={'Urban':'Urban (Pop %)','Urban.1':'Urban (Population)','Tanzania':'Tanzania (Global Rank)',"Country's Share ":"Country's Share of World Pop"})
df_1 = df_1.rename(columns={'Urban':'Urban (Pop %)','Angola':'Angola (Global Rank)',"Country's Share of":"Country's Share of World Pop"})
df_2 = df_2.rename(columns={'Urban':'Urban (Pop %)','Urban Population':'Urban (Population)','Egypt':'Egypt (Global Rank)',"Country's Share":"Country's Share of World Pop"})
df_3 = df_3.rename(columns={'Urban':'Urban (Pop %)','South Africa':'South Africa (Global Rank)',"Country's Share ":"Country's Share of World Pop"})
df_4 = df_4.rename(columns={'Urban':'Urban (Pop %)','Madagascar':'Madagascar (Global Rank)',"Country's Share of":"Country's Share of World Pop"})

# %%
df_4.columns
# Out:
# Index(['Year', 'Population', 'Yearly %', 'Yearly', 'Migrants (net)',
#        'Median Age', 'Fertility Rate', 'Density (P/Km²)', 'Urban (Pop %)',
#        'Urban Population', 'Country's Share of World Pop', 'World Population',
#        'Madagascar (Global Rank)'],
#       dtype='object')

# %%
df_3.columns
# Out:
# Index(['Year', 'Population', 'Yearly %', 'Yearly', 'Migrants (net)',
#        'Median Age', 'Fertility Rate', 'Density (P/Km²)', 'Urban (Pop %)',
#        'Urban Population', 'Country's Share of World Pop', 'World Population',
#        'South Africa (Global Rank)'],
#       dtype='object')

# %%
df_2.columns
# Out:
# Index(['Year', 'Population', 'Yearly %', 'Yearly', 'Migrants (net)',
#        'Median Age', 'Fertility Rate', 'Density (P/Km²)', 'Urban (Pop %)',
#        'Urban (Population)', 'Country's Share of World Pop',
#        'World Population', 'Egypt (Global Rank)'],
#       dtype='object')

# %%
df_1.columns
# Out:
# Index(['Year', 'Population', 'Yearly %', 'Yearly', 'Migrants (net)',
#        'Median Age', 'Fertility Rate', 'Density (P/Km²)', 'Urban (Pop %)',
#        'Urban Population', 'Country's Share of World Pop', 'World Population',
#        'Angola (Global Rank)'],
#       dtype='object')

# %%
df_1
# Out:
#       Year  Population Yearly %   Yearly  Migrants (net)  Median Age  \
# 0      NaN         NaN   Change   Change             NaN         NaN
# 1   2020.0  32866272.0   0.0327  1040977          6413.0        16.7
# 2   2019.0  31825295.0    0.033  1015508          6413.0        16.4
# 3   2018.0  30809787.0   0.0333   993021          6413.0        16.4
# 4   2017.0  29816766.0   0.0338   974277          6413.0        16.4
# 5   2016.0  28842489.0   0.0344   958108          6413.0        16.4
# 6   2015.0  27884381.0   0.0361   905627         33253.0        16.4
# 7   2010.0  23356246.0   0.0375   784529         71460.0        16.4
# 8   2005.0  19433602.0   0.0346   607626         52220.0        16.4
# 9   2000.0  16395473.0   0.0329   490053         39960.0        16.3
# 10  1995.0  13945206.0   0.0331   419364         28562.0        16.1
# 11  1990.0  11848386.0   0.0353   377278         37698.0        16.1
# 12  1985.0   9961997.0   0.0362   324142         46830.0        16.3
# ...

# %%
df
# Out:
#       Year    Population Yearly %     Yearly Migrants (net)  Median Age  \
# 0      NaN           NaN   Change     Change            NaN         NaN
# 1   2050.0  12,93,86,839    2.28%  27,58,164            NaN        22.3
# 2   2045.0  11,55,96,020    2.42%  26,01,898        -40,154        21.5
# 3   2040.0  10,25,86,529    2.56%  24,34,187        -40,132        20.7
# 4   2035.0   9,04,15,596    2.69%  22,50,574        -40,116        20.0
# 5   2030.0   7,91,62,725    2.81%  20,45,712        -40,102        19.3
# 6   2025.0   6,89,34,163    2.91%  18,39,989        -40,086        18.6
# 7   2020.0   5,97,34,218    2.98%  17,28,755        -40,076        18.0
# 8   2019.0   5,80,05,463    3.00%  16,92,025        -40,076        17.6
# 9   2018.0   5,63,13,438    3.02%  16,53,099        -40,076        17.6
# 10  2017.0   5,46,60,339    3.04%  16,11,109        -40,076        17.6
# 11  2016.0   5,30,49,230    3.04%  15,66,597        -40,076        17.6
# ...

# %%
df
# Out:
#       Year    Population Yearly %     Yearly Migrants (net)  Median Age  \
# 0      NaN           NaN   Change     Change            NaN         NaN
# 1   2050.0  12,93,86,839    2.28%  27,58,164            NaN        22.3
# 2   2045.0  11,55,96,020    2.42%  26,01,898        -40,154        21.5
# 3   2040.0  10,25,86,529    2.56%  24,34,187        -40,132        20.7
# 4   2035.0   9,04,15,596    2.69%  22,50,574        -40,116        20.0
# 5   2030.0   7,91,62,725    2.81%  20,45,712        -40,102        19.3
# 6   2025.0   6,89,34,163    2.91%  18,39,989        -40,086        18.6
# 7   2020.0   5,97,34,218    2.98%  17,28,755        -40,076        18.0
# 8   2019.0   5,80,05,463    3.00%  16,92,025        -40,076        17.6
# 9   2018.0   5,63,13,438    3.02%  16,53,099        -40,076        17.6
# 10  2017.0   5,46,60,339    3.04%  16,11,109        -40,076        17.6
# 11  2016.0   5,30,49,230    3.04%  15,66,597        -40,076        17.6
# ...

# %% [markdown]
# ### Delete first row

# %%
df_4 = df_4.tail(-1)
df_4
# Out:
#       Year  Population Yearly %   Yearly Migrants (net)  Median Age  \
# 1   2020.0  27,691,018    2.68%  721,711         -1,500        19.6
# 2   2019.0  26,969,307    2.69%  706,994         -1,500        18.9
# 3   2018.0  26,262,313    2.71%  691,801         -1,500        18.9
# 4   2017.0  25,570,512    2.72%  676,142         -1,500        18.9
# 5   2016.0  24,894,370    2.72%  660,282         -1,500        18.9
# 6   2015.0  24,234,088    2.76%  616,490         -1,500        18.7
# 7   2010.0  21,151,640    2.90%  562,983         -1,500        18.0
# 8   2005.0  18,336,724    3.07%  513,984         -1,500        17.5
# 9   2000.0  15,766,806    3.19%  458,281         -1,700        17.3
# 10  1995.0  13,475,400    3.05%  375,353         -1,900        17.2
# 11  1990.0  11,598,633    2.88%  307,028         -2,000        17.1
# 12  1985.0  10,063,495    2.92%  269,388         -2,000        16.9
# 13  1980.0   8,716,553    2.90%  232,105         -6,000        16.8
# ...

# %%
df_3 = df_3.tail(-1)
df_3
# Out:
#       Year   Population Yearly %    Yearly Migrants (net)  Median Age  \
# 1   2050.0  7,55,17,920    0.51%  3,79,675            NaN        33.9
# 2   2045.0  7,36,19,543    0.62%  4,48,848         58,397        32.7
# 3   2040.0  7,13,75,305    0.73%  5,11,264         59,663        31.6
# 4   2035.0  6,88,18,987    0.85%  5,72,581         76,008        30.5
# 5   2030.0  6,59,56,081    0.98%  6,30,680         91,759        29.6
# 6   2025.0  6,28,02,683    1.15%  6,98,799       1,12,349        28.7
# 7   2020.0  5,93,08,690    1.28%  7,50,420       1,45,405        27.6
# 8   2019.0  5,85,58,270    1.33%  7,65,752       1,45,405        26.6
# 9   2018.0  5,77,92,518    1.37%  7,82,762       1,45,405        26.6
# 10  2017.0  5,70,09,756    1.43%  8,02,110       1,45,405        26.6
# 11  2016.0  5,62,07,646    1.48%  8,21,279       1,45,405        26.6
# 12  2015.0  5,53,86,367    1.58%  8,33,881       1,83,939        26.4
# ...

# %%
df_2 = df_2.tail(-1)

# %%
df_2
# Out:
#       Year    Population Yearly %     Yearly Migrants (net)  Median Age  \
# 1   2050.0  15,99,56,808    1.25%  19,20,351            NaN        29.7
# 2   2045.0  15,03,55,053    1.39%  20,00,934        -30,000        28.5
# 3   2040.0  14,03,50,381    1.49%  20,02,003        -30,000        27.3
# 4   2035.0  13,03,40,364    1.53%  19,01,761        -30,000        26.2
# 5   2030.0  12,08,31,557    1.58%  18,20,747        -40,000        25.6
# 6   2025.0  11,17,27,822    1.77%  18,78,684        -40,000        25.1
# 7   2020.0  10,23,34,404    1.94%  19,46,331        -38,033        24.6
# 8   2019.0  10,03,88,073    2.00%  19,64,475        -38,033        24.3
# 9   2018.0   9,84,23,598    2.05%  19,81,007        -38,033        24.3
# 10  2017.0   9,64,42,591    2.11%  19,95,518        -38,033        24.3
# 11  2016.0   9,44,47,073    2.17%  20,04,526        -38,033        24.3
# 12  2015.0   9,24,42,547    2.24%  19,36,262        -56,189        24.3
# ...

# %%
df_4.describe()
# Out:
#               Year  Median Age  Fertility Rate  Density (P/Km²)
# count    18.000000   18.000000       18.000000        18.000000
# mean   1994.166667   18.122222        5.776667        27.166667
# std      22.350813    1.051361        1.274386        14.825455
# min    1955.000000   16.800000        4.110000         8.000000
# 25%    1976.250000   17.200000        4.355000        13.500000
# 50%    1997.500000   17.950000        5.950000        25.000000
# 75%    2015.750000   18.900000        7.137500        42.750000
# max    2020.000000   20.200000        7.300000        48.000000

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 1 to 18
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          18 non-null     float64
#  1   Population                    18 non-null     object
#  2   Yearly %                      18 non-null     object
#  3   Yearly                        18 non-null     object
#  4   Migrants (net)                18 non-null     object
#  5   Median Age                    18 non-null     float64
#  6   Fertility Rate                18 non-null     float64
#  7   Density (P/Km²)               18 non-null     float64
#  8   Urban (Pop %)                 18 non-null     object
#  9   Urban Population              18 non-null     object
#  10  Country's Share of World Pop  18 non-null     object
#  11  World Population              18 non-null     object
# ...

# %%
print(df_3.describe())
df_3.info()
# Out:
#               Year  Median Age  Fertility Rate  Density (P/Km²)
# count    24.000000   24.000000       24.000000        24.000000
# mean   2005.000000   24.879167        3.536667        39.333333
# std      27.489128    4.751840        1.454820        15.652939
# min    1955.000000   19.100000        2.410000        13.000000
# 25%    1983.750000   19.875000        2.410000        26.250000
# 50%    2012.500000   25.700000        2.580000        44.000000
# 75%    2021.250000   27.875000        4.937500        49.750000
# max    2050.000000   33.900000        6.050000        62.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          24 non-null     float64
#  1   Population                    24 non-null     object
# ...

# %%
df_3.isnull().sum()
# Out:
# Year                            0
# Population                      0
# Yearly %                        0
# Yearly                          0
# Migrants (net)                  1
# Median Age                      0
# Fertility Rate                  0
# Density (P/Km²)                 0
# Urban (Pop %)                   0
# Urban Population                0
# Country's Share of World Pop    0
# World Population                0
# South Africa (Global Rank)      0
# dtype: int64

# %%
print(df_2.describe())
df_2.info()
# Out:
#               Year  Median Age  Fertility Rate  Density (P/Km²)
# count    24.000000   24.000000       24.000000        24.000000
# mean   2005.000000   23.020833        4.299583        83.333333
# std      27.489128    3.195646        1.362796        40.544840
# min    1955.000000   19.000000        3.020000        23.000000
# 25%    1983.750000   19.850000        3.330000        47.750000
# 50%    2012.500000   24.000000        3.430000        88.000000
# 75%    2021.250000   24.725000        5.542500       105.250000
# max    2050.000000   29.700000        6.750000       161.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          24 non-null     float64
#  1   Population                    24 non-null     object
# ...

# %%
df_2.isna().sum()
# Out:
# Year                            0
# Population                      0
# Yearly %                        0
# Yearly                          0
# Migrants (net)                  1
# Median Age                      0
# Fertility Rate                  0
# Density (P/Km²)                 0
# Urban (Pop %)                   0
# Urban (Population)              0
# Country's Share of World Pop    0
# World Population                0
# Egypt (Global Rank)             0
# dtype: int64

# %%
df_1 = df_1.tail(-1)

# %%
df_1
# Out:
#       Year  Population Yearly %   Yearly  Migrants (net)  Median Age  \
# 1   2020.0  32866272.0   0.0327  1040977          6413.0        16.7
# 2   2019.0  31825295.0    0.033  1015508          6413.0        16.4
# 3   2018.0  30809787.0   0.0333   993021          6413.0        16.4
# 4   2017.0  29816766.0   0.0338   974277          6413.0        16.4
# 5   2016.0  28842489.0   0.0344   958108          6413.0        16.4
# 6   2015.0  27884381.0   0.0361   905627         33253.0        16.4
# 7   2010.0  23356246.0   0.0375   784529         71460.0        16.4
# 8   2005.0  19433602.0   0.0346   607626         52220.0        16.4
# 9   2000.0  16395473.0   0.0329   490053         39960.0        16.3
# 10  1995.0  13945206.0   0.0331   419364         28562.0        16.1
# 11  1990.0  11848386.0   0.0353   377278         37698.0        16.1
# 12  1985.0   9961997.0   0.0362   324142         46830.0        16.3
# 13  1980.0   8341289.0    0.035   263458         39960.0        16.8
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 1 to 18
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          18 non-null     float64
#  1   Population                    18 non-null     float64
#  2   Yearly %                      18 non-null     object
#  3   Yearly                        18 non-null     object
#  4   Migrants (net)                18 non-null     float64
#  5   Median Age                    18 non-null     float64
#  6   Fertility Rate                18 non-null     float64
#  7   Density (P/Km²)               18 non-null     float64
#  8   Urban (Pop %)                 18 non-null     object
#  9   Urban Population              18 non-null     float64
#  10  Country's Share of World Pop  18 non-null     object
#  11  World Population              18 non-null     float64
# ...

# %%
df_1.describe()
# Out:
#               Year    Population  Migrants (net)  Median Age  Fertility Rate  \
# count    18.000000  1.800000e+01        18.00000   18.000000       18.000000
# mean   1994.166667  1.747279e+07     11699.50000   16.988889        6.581111
# std      22.350813  1.060955e+07     44993.28945    1.202394        0.667620
# min    1955.000000  5.043247e+06   -117457.00000   16.100000        5.550000
# 25%    1976.250000  7.353322e+06      6413.00000   16.400000        5.932500
# 50%    1997.500000  1.517034e+07     17487.50000   16.400000        6.525000
# 75%    2015.750000  2.860296e+07     39960.00000   16.875000        7.250000
# max    2020.000000  3.286627e+07     71460.00000   20.200000        7.500000
#
#        Density (P/Km²)  Urban Population  World Population
# count        18.000000      1.800000e+01      1.800000e+01
# mean         14.111111      9.570853e+06      5.694506e+09
# std           8.470634      8.299109e+06      1.786229e+09
# ...

# %%
df = df.tail(-1)

# %%
df
# Out:
#       Year    Population Yearly %     Yearly Migrants (net)  Median Age  \
# 1   2050.0  12,93,86,839    2.28%  27,58,164            NaN        22.3
# 2   2045.0  11,55,96,020    2.42%  26,01,898        -40,154        21.5
# 3   2040.0  10,25,86,529    2.56%  24,34,187        -40,132        20.7
# 4   2035.0   9,04,15,596    2.69%  22,50,574        -40,116        20.0
# 5   2030.0   7,91,62,725    2.81%  20,45,712        -40,102        19.3
# 6   2025.0   6,89,34,163    2.91%  18,39,989        -40,086        18.6
# 7   2020.0   5,97,34,218    2.98%  17,28,755        -40,076        18.0
# 8   2019.0   5,80,05,463    3.00%  16,92,025        -40,076        17.6
# 9   2018.0   5,63,13,438    3.02%  16,53,099        -40,076        17.6
# 10  2017.0   5,46,60,339    3.04%  16,11,109        -40,076        17.6
# 11  2016.0   5,30,49,230    3.04%  15,66,597        -40,076        17.6
# 12  2015.0   5,14,82,633    3.03%  14,27,222        -50,087        17.6
# ...

# %%
df_1.isna().sum()
# Out:
# Year                            0
# Population                      0
# Yearly %                        0
# Yearly                          0
# Migrants (net)                  0
# Median Age                      0
# Fertility Rate                  0
# Density (P/Km²)                 0
# Urban (Pop %)                   0
# Urban Population                0
# Country's Share of World Pop    0
# World Population                0
# Angola (Global Rank)            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          24 non-null     float64
#  1   Population                    24 non-null     object
#  2   Yearly %                      24 non-null     object
#  3   Yearly                        24 non-null     object
#  4   Migrants (net)                23 non-null     object
#  5   Median Age                    24 non-null     float64
#  6   Fertility Rate                24 non-null     float64
#  7   Density (P/Km²)               24 non-null     float64
#  8   Urban (Pop %)                 24 non-null     object
#  9   Urban (Population)            24 non-null     object
#  10  Country's Share of World Pop  24 non-null     object
#  11  World Population              24 non-null     object
# ...

# %%
df.describe()
# Out:
#               Year  Median Age  Fertility Rate  Density (P/Km²)
# count    24.000000   24.000000       24.000000        24.000000
# mean   2005.000000   18.066667        5.705000        55.875000
# std      27.489128    1.546572        0.773068        38.669517
# min    1955.000000   16.800000        4.920000        10.000000
# 25%    1983.750000   17.100000        4.920000        23.250000
# 50%    2012.500000   17.500000        5.410000        54.000000
# 75%    2021.250000   18.150000        6.595000        69.750000
# max    2050.000000   22.300000        6.800000       146.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Year                            0
# Population                      0
# Yearly %                        0
# Yearly                          0
# Migrants (net)                  1
# Median Age                      0
# Fertility Rate                  0
# Density (P/Km²)                 0
# Urban (Pop %)                   0
# Urban (Population)              0
# Country's Share of World Pop    0
# World Population                0
# Tanzania (Global Rank)          0
# dtype: int64

# %%
df
# Out:
#       Year    Population Yearly %     Yearly Migrants (net)  Median Age  \
# 1   2050.0  12,93,86,839    2.28%  27,58,164            NaN        22.3
# 2   2045.0  11,55,96,020    2.42%  26,01,898        -40,154        21.5
# 3   2040.0  10,25,86,529    2.56%  24,34,187        -40,132        20.7
# 4   2035.0   9,04,15,596    2.69%  22,50,574        -40,116        20.0
# 5   2030.0   7,91,62,725    2.81%  20,45,712        -40,102        19.3
# 6   2025.0   6,89,34,163    2.91%  18,39,989        -40,086        18.6
# 7   2020.0   5,97,34,218    2.98%  17,28,755        -40,076        18.0
# 8   2019.0   5,80,05,463    3.00%  16,92,025        -40,076        17.6
# 9   2018.0   5,63,13,438    3.02%  16,53,099        -40,076        17.6
# 10  2017.0   5,46,60,339    3.04%  16,11,109        -40,076        17.6
# 11  2016.0   5,30,49,230    3.04%  15,66,597        -40,076        17.6
# 12  2015.0   5,14,82,633    3.03%  14,27,222        -50,087        17.6
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Population', 'Yearly %', 'Yearly', 'Migrants (net)',
#        'Median Age', 'Fertility Rate', 'Density (P/Km²)', 'Urban (Pop %)',
#        'Urban (Population)', 'Country's Share of World Pop',
#        'World Population', 'Tanzania (Global Rank)'],
#       dtype='object')

# %%
df[['Yearly %','Urban (Pop %)',"Country's Share of World Pop"]]
# Out:
#    Yearly % Urban (Pop %) Country's Share of World Pop
# 1     2.28%        59.20%                        1.33%
# 2     2.42%        55.70%                        1.22%
# 3     2.56%        52.20%                        1.12%
# 4     2.69%        48.70%                        1.02%
# 5     2.81%        44.90%                        0.93%
# 6     2.91%        41.00%                        0.84%
# 7     2.98%        37.00%                        0.77%
# 8     3.00%        36.20%                        0.75%
# 9     3.02%        35.40%                        0.74%
# 10    3.04%        34.70%                        0.72%
# 11    3.04%        33.90%                        0.71%
# 12    3.03%        33.10%                        0.70%
# 13    2.89%        29.20%                        0.64%
# 14    2.80%        25.50%                        0.59%
# 15    2.47%        22.80%                        0.55%
# 16    3.30%        20.80%                        0.52%
# ...

# %% [markdown]
# ### Remove percentage symbol

# %%
df['Yearly %'] = df['Yearly %'].str.rstrip('%').astype(float)
df['Urban (Pop %)'] = df['Urban (Pop %)'].str.rstrip('%').astype(float)
df['Country\'s Share of World Pop'] = df['Country\'s Share of World Pop'].str.rstrip('%').astype(float)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1405801332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Yearly %'] = df['Yearly %'].str.rstrip('%').astype(float)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1405801332.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Urban (Pop %)'] = df['Urban (Pop %)'].str.rstrip('%').astype(float)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1405801332.py:3: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#       Year    Population  Yearly %     Yearly Migrants (net)  Median Age  \
# 1   2050.0  12,93,86,839      2.28  27,58,164            NaN        22.3
# 2   2045.0  11,55,96,020      2.42  26,01,898        -40,154        21.5
# 3   2040.0  10,25,86,529      2.56  24,34,187        -40,132        20.7
# 4   2035.0   9,04,15,596      2.69  22,50,574        -40,116        20.0
# 5   2030.0   7,91,62,725      2.81  20,45,712        -40,102        19.3
# 6   2025.0   6,89,34,163      2.91  18,39,989        -40,086        18.6
# 7   2020.0   5,97,34,218      2.98  17,28,755        -40,076        18.0
# 8   2019.0   5,80,05,463      3.00  16,92,025        -40,076        17.6
# 9   2018.0   5,63,13,438      3.02  16,53,099        -40,076        17.6
# 10  2017.0   5,46,60,339      3.04  16,11,109        -40,076        17.6
# 11  2016.0   5,30,49,230      3.04  15,66,597        -40,076        17.6
# 12  2015.0   5,14,82,633      3.03  14,27,222        -50,087        17.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          24 non-null     float64
#  1   Population                    24 non-null     object
#  2   Yearly %                      24 non-null     float64
#  3   Yearly                        24 non-null     object
#  4   Migrants (net)                23 non-null     object
#  5   Median Age                    24 non-null     float64
#  6   Fertility Rate                24 non-null     float64
#  7   Density (P/Km²)               24 non-null     float64
#  8   Urban (Pop %)                 24 non-null     float64
#  9   Urban (Population)            24 non-null     object
#  10  Country's Share of World Pop  24 non-null     float64
#  11  World Population              24 non-null     object
# ...

# %%
df_2.columns
# Out:
# Index(['Year', 'Population', 'Yearly %', 'Yearly', 'Migrants (net)',
#        'Median Age', 'Fertility Rate', 'Density (P/Km²)', 'Urban (Pop %)',
#        'Urban (Population)', 'Country's Share of World Pop',
#        'World Population', 'Egypt (Global Rank)'],
#       dtype='object')

# %%
df_2['Yearly %'] = df_2['Yearly %'].str.rstrip('%').astype(float)
df_2['Urban (Pop %)'] = df_2['Urban (Pop %)'].str.rstrip('%').astype(float)
df_2['Country\'s Share of World Pop'] = df_2['Country\'s Share of World Pop'].str.rstrip('%').astype(float)

# %%
df_3['Yearly %'] = df_3['Yearly %'].str.rstrip('%').astype(float)
df_3['Urban (Pop %)'] = df_3['Urban (Pop %)'].str.rstrip('%').astype(float)
df_3['Country\'s Share of World Pop'] = df_3['Country\'s Share of World Pop'].str.rstrip('%').astype(float)

# %%
df_4['Yearly %'] = df_4['Yearly %'].str.rstrip('%').astype(float)
df_4['Urban (Pop %)'] = df_4['Urban (Pop %)'].str.rstrip('%').astype(float)
df_4['Country\'s Share of World Pop'] = df_4['Country\'s Share of World Pop'].str.rstrip('%').astype(float)

# %% [markdown]
# ### Remove comma

# %%
df['Population'] = df['Population'].str.replace(',','')
df['Yearly'] = df['Yearly'].str.replace(',','')
df['Urban (Population)'] = df['Urban (Population)'].str.replace(',','')
df['World Population'] = df['World Population'].str.replace(',','')
df['Migrants (net)'] = df['Migrants (net)'].str.replace(',','')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\3151545789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population'] = df['Population'].str.replace(',','')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\3151545789.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Yearly'] = df['Yearly'].str.replace(',','')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\3151545789.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#       Year Population  Yearly %   Yearly Migrants (net)  Median Age  \
# 1   2050.0  129386839      2.28  2758164            NaN        22.3
# 2   2045.0  115596020      2.42  2601898         -40154        21.5
# 3   2040.0  102586529      2.56  2434187         -40132        20.7
# 4   2035.0   90415596      2.69  2250574         -40116        20.0
# 5   2030.0   79162725      2.81  2045712         -40102        19.3
# 6   2025.0   68934163      2.91  1839989         -40086        18.6
# 7   2020.0   59734218      2.98  1728755         -40076        18.0
# 8   2019.0   58005463      3.00  1692025         -40076        17.6
# 9   2018.0   56313438      3.02  1653099         -40076        17.6
# 10  2017.0   54660339      3.04  1611109         -40076        17.6
# 11  2016.0   53049230      3.04  1566597         -40076        17.6
# 12  2015.0   51482633      3.03  1427222         -50087        17.6
# 13  2010.0   44346525      2.89  1179241        -100171        17.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          24 non-null     float64
#  1   Population                    24 non-null     object
#  2   Yearly %                      24 non-null     float64
#  3   Yearly                        24 non-null     object
#  4   Migrants (net)                23 non-null     object
#  5   Median Age                    24 non-null     float64
#  6   Fertility Rate                24 non-null     float64
#  7   Density (P/Km²)               24 non-null     float64
#  8   Urban (Pop %)                 24 non-null     float64
#  9   Urban (Population)            24 non-null     object
#  10  Country's Share of World Pop  24 non-null     float64
#  11  World Population              24 non-null     object
# ...

# %%
df_2['Population'] = df_2['Population'].str.replace(',','')
df_2['Yearly'] = df_2['Yearly'].str.replace(',','')
df_2['Urban (Population)'] = df_2['Urban (Population)'].str.replace(',','')
df_2['World Population'] = df_2['World Population'].str.replace(',','')
df_2['Migrants (net)'] = df_2['Migrants (net)'].str.replace(',','')

# %%
df_3['Population'] = df_3['Population'].str.replace(',','')
df_3['Yearly'] = df_3['Yearly'].str.replace(',','')
df_3['Urban Population'] = df_3['Urban Population'].str.replace(',','')
df_3['World Population'] = df_3['World Population'].str.replace(',','')
df_3['Migrants (net)'] = df_3['Migrants (net)'].str.replace(',','')

# %%
df_4['Population'] = df_4['Population'].str.replace(',','')
df_4['Yearly'] = df_4['Yearly'].str.replace(',','')
df_4['Urban Population'] = df_4['Urban Population'].str.replace(',','')
df_4['World Population'] = df_4['World Population'].str.replace(',','')
df_4['Migrants (net)'] = df_4['Migrants (net)'].str.replace(',','')

# %% [markdown]
# ### Change dtype

# %%
df['Year'] = df['Year'].astype('int')
df['Yearly'] = df['Yearly'].astype('float')
df['Population'] = df['Population'].astype('float')
df['Urban (Population)'] = df['Urban (Population)'].astype('float')
df['World Population'] = df['World Population'].astype('float')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1537476325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].astype('int')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1537476325.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Yearly'] = df['Yearly'].astype('float')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1537476325.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_4['Year'] = df_4['Year'].astype('int')
df_4['Yearly'] = df_4['Yearly'].astype('float')
df_4['Population'] = df_4['Population'].astype('float')
df_4['Urban Population'] = df_4['Urban Population'].astype('float')
df_4['World Population'] = df_4['World Population'].astype('float')
df_4['Migrants (net)'] = df_4['Migrants (net)'].astype('int')

# %%
df_3['Year'] = df_3['Year'].astype('int')
df_3['Yearly'] = df_3['Yearly'].astype('float')
df_3['Population'] = df_3['Population'].astype('float')
df_3['Urban Population'] = df_3['Urban Population'].astype('float')
df_3['World Population'] = df_3['World Population'].astype('float')

# %%
df_1['Yearly %'] = df_1['Yearly %'].astype('float')
df_1['Yearly'] = df_1['Yearly'].astype('float')
df_1['Urban (Pop %)'] = df_1['Urban (Pop %)'].astype('float')
df_1['Migrants (net)'] = df_1['Migrants (net)'].astype('int')
df_1['Year'] = df_1['Year'].astype('int')

df_1["Country's Share of World Pop"] = df_1["Country's Share of World Pop"].astype('float')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1541881967.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Yearly %'] = df_1['Yearly %'].astype('float')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1541881967.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Yearly'] = df_1['Yearly'].astype('float')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1541881967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_2['Year'] = df_2['Year'].astype('int')
df_2['Yearly'] = df_2['Yearly'].astype('float')
df_2['Population'] = df_2['Population'].astype('float')
df_2['Urban (Population)'] = df_2['Urban (Population)'].astype('float')
df_2['World Population'] = df_2['World Population'].astype('float')

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 1 to 18
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          18 non-null     int32
#  1   Population                    18 non-null     float64
#  2   Yearly %                      18 non-null     float64
#  3   Yearly                        18 non-null     float64
#  4   Migrants (net)                18 non-null     int32
#  5   Median Age                    18 non-null     float64
#  6   Fertility Rate                18 non-null     float64
#  7   Density (P/Km²)               18 non-null     float64
#  8   Urban (Pop %)                 18 non-null     float64
#  9   Urban Population              18 non-null     float64
#  10  Country's Share of World Pop  18 non-null     float64
#  11  World Population              18 non-null     float64
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          24 non-null     int32
#  1   Population                    24 non-null     float64
#  2   Yearly %                      24 non-null     float64
#  3   Yearly                        24 non-null     float64
#  4   Migrants (net)                23 non-null     object
#  5   Median Age                    24 non-null     float64
#  6   Fertility Rate                24 non-null     float64
#  7   Density (P/Km²)               24 non-null     float64
#  8   Urban (Pop %)                 24 non-null     float64
#  9   Urban (Population)            24 non-null     float64
#  10  Country's Share of World Pop  24 non-null     float64
#  11  World Population              24 non-null     float64
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 1 to 18
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          18 non-null     int32
#  1   Population                    18 non-null     float64
#  2   Yearly %                      18 non-null     float64
#  3   Yearly                        18 non-null     float64
#  4   Migrants (net)                18 non-null     int32
#  5   Median Age                    18 non-null     float64
#  6   Fertility Rate                18 non-null     float64
#  7   Density (P/Km²)               18 non-null     float64
#  8   Urban (Pop %)                 18 non-null     float64
#  9   Urban Population              18 non-null     float64
#  10  Country's Share of World Pop  18 non-null     float64
#  11  World Population              18 non-null     float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          24 non-null     int32
#  1   Population                    24 non-null     float64
#  2   Yearly %                      24 non-null     float64
#  3   Yearly                        24 non-null     float64
#  4   Migrants (net)                23 non-null     object
#  5   Median Age                    24 non-null     float64
#  6   Fertility Rate                24 non-null     float64
#  7   Density (P/Km²)               24 non-null     float64
#  8   Urban (Pop %)                 24 non-null     float64
#  9   Urban (Population)            24 non-null     float64
#  10  Country's Share of World Pop  24 non-null     float64
#  11  World Population              24 non-null     float64
# ...

# %%
df
# Out:
#     Year   Population  Yearly %     Yearly Migrants (net)  Median Age  \
# 1   2050  129386839.0      2.28  2758164.0            NaN        22.3
# 2   2045  115596020.0      2.42  2601898.0         -40154        21.5
# 3   2040  102586529.0      2.56  2434187.0         -40132        20.7
# 4   2035   90415596.0      2.69  2250574.0         -40116        20.0
# 5   2030   79162725.0      2.81  2045712.0         -40102        19.3
# 6   2025   68934163.0      2.91  1839989.0         -40086        18.6
# 7   2020   59734218.0      2.98  1728755.0         -40076        18.0
# 8   2019   58005463.0      3.00  1692025.0         -40076        17.6
# 9   2018   56313438.0      3.02  1653099.0         -40076        17.6
# 10  2017   54660339.0      3.04  1611109.0         -40076        17.6
# 11  2016   53049230.0      3.04  1566597.0         -40076        17.6
# 12  2015   51482633.0      3.03  1427222.0         -50087        17.6
# ...

# %% [markdown]
# ### Missing Values

# %%
sns.displot(df['Migrants (net)'])
plt.xticks(rotation=90)
plt.show()

# %%
df.isnull().sum()
# Out:
# Year                            0
# Population                      0
# Yearly %                        0
# Yearly                          0
# Migrants (net)                  1
# Median Age                      0
# Fertility Rate                  0
# Density (P/Km²)                 0
# Urban (Pop %)                   0
# Urban (Population)              0
# Country's Share of World Pop    0
# World Population                0
# Tanzania (Global Rank)          0
# dtype: int64

# %%
df['Migrants (net)'] = pd.to_numeric(df['Migrants (net)'], errors='coerce')
df
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\3679744997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Migrants (net)'] = pd.to_numeric(df['Migrants (net)'], errors='coerce')
#     Year   Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 1   2050  129386839.0      2.28  2758164.0             NaN        22.3
# 2   2045  115596020.0      2.42  2601898.0        -40154.0        21.5
# 3   2040  102586529.0      2.56  2434187.0        -40132.0        20.7
# 4   2035   90415596.0      2.69  2250574.0        -40116.0        20.0
# 5   2030   79162725.0      2.81  2045712.0        -40102.0        19.3
# 6   2025   68934163.0      2.91  1839989.0        -40086.0        18.6
# ...

# %%
df['Migrants (net)'] = df['Migrants (net)'].replace(np.NaN, df['Migrants (net)'].mean())
df['Migrants (net)'] = df['Migrants (net)'].astype(int)
df
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1626355962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Migrants (net)'] = df['Migrants (net)'].replace(np.NaN, df['Migrants (net)'].mean())
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1626355962.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Migrants (net)'] = df['Migrants (net)'].astype(int)
#     Year   Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# ...

# %%
df_2['Migrants (net)'] = pd.to_numeric(df_2['Migrants (net)'], errors='coerce')
df_2
# Out:
#     Year   Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 1   2050  159956808.0      1.25  1920351.0             NaN        29.7
# 2   2045  150355053.0      1.39  2000934.0        -30000.0        28.5
# 3   2040  140350381.0      1.49  2002003.0        -30000.0        27.3
# 4   2035  130340364.0      1.53  1901761.0        -30000.0        26.2
# 5   2030  120831557.0      1.58  1820747.0        -40000.0        25.6
# 6   2025  111727822.0      1.77  1878684.0        -40000.0        25.1
# 7   2020  102334404.0      1.94  1946331.0        -38033.0        24.6
# 8   2019  100388073.0      2.00  1964475.0        -38033.0        24.3
# 9   2018   98423598.0      2.05  1981007.0        -38033.0        24.3
# 10  2017   96442591.0      2.11  1995518.0        -38033.0        24.3
# 11  2016   94447073.0      2.17  2004526.0        -38033.0        24.3
# 12  2015   92442547.0      2.24  1936262.0        -56189.0        24.3
# ...

# %%
df_2['Migrants (net)'] = df_2['Migrants (net)'].replace(np.NaN, df_2['Migrants (net)'].mean())
df_2['Migrants (net)'] = df_2['Migrants (net)'].astype(int)
df_2
# Out:
#     Year   Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 1   2050  159956808.0      1.25  1920351.0          -45745        29.7
# 2   2045  150355053.0      1.39  2000934.0          -30000        28.5
# 3   2040  140350381.0      1.49  2002003.0          -30000        27.3
# 4   2035  130340364.0      1.53  1901761.0          -30000        26.2
# 5   2030  120831557.0      1.58  1820747.0          -40000        25.6
# 6   2025  111727822.0      1.77  1878684.0          -40000        25.1
# 7   2020  102334404.0      1.94  1946331.0          -38033        24.6
# 8   2019  100388073.0      2.00  1964475.0          -38033        24.3
# 9   2018   98423598.0      2.05  1981007.0          -38033        24.3
# 10  2017   96442591.0      2.11  1995518.0          -38033        24.3
# 11  2016   94447073.0      2.17  2004526.0          -38033        24.3
# 12  2015   92442547.0      2.24  1936262.0          -56189        24.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          24 non-null     int32
#  1   Population                    24 non-null     float64
#  2   Yearly %                      24 non-null     float64
#  3   Yearly                        24 non-null     float64
#  4   Migrants (net)                24 non-null     int32
#  5   Median Age                    24 non-null     float64
#  6   Fertility Rate                24 non-null     float64
#  7   Density (P/Km²)               24 non-null     float64
#  8   Urban (Pop %)                 24 non-null     float64
#  9   Urban (Population)            24 non-null     float64
#  10  Country's Share of World Pop  24 non-null     float64
#  11  World Population              24 non-null     float64
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 1 to 18
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          18 non-null     int32
#  1   Population                    18 non-null     float64
#  2   Yearly %                      18 non-null     float64
#  3   Yearly                        18 non-null     float64
#  4   Migrants (net)                18 non-null     int32
#  5   Median Age                    18 non-null     float64
#  6   Fertility Rate                18 non-null     float64
#  7   Density (P/Km²)               18 non-null     float64
#  8   Urban (Pop %)                 18 non-null     float64
#  9   Urban Population              18 non-null     float64
#  10  Country's Share of World Pop  18 non-null     float64
#  11  World Population              18 non-null     float64
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          24 non-null     int32
#  1   Population                    24 non-null     float64
#  2   Yearly %                      24 non-null     float64
#  3   Yearly                        24 non-null     float64
#  4   Migrants (net)                24 non-null     int32
#  5   Median Age                    24 non-null     float64
#  6   Fertility Rate                24 non-null     float64
#  7   Density (P/Km²)               24 non-null     float64
#  8   Urban (Pop %)                 24 non-null     float64
#  9   Urban (Population)            24 non-null     float64
#  10  Country's Share of World Pop  24 non-null     float64
#  11  World Population              24 non-null     float64
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 1 to 24
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          24 non-null     int32
#  1   Population                    24 non-null     float64
#  2   Yearly %                      24 non-null     float64
#  3   Yearly                        24 non-null     float64
#  4   Migrants (net)                23 non-null     object
#  5   Median Age                    24 non-null     float64
#  6   Fertility Rate                24 non-null     float64
#  7   Density (P/Km²)               24 non-null     float64
#  8   Urban (Pop %)                 24 non-null     float64
#  9   Urban Population              24 non-null     float64
#  10  Country's Share of World Pop  24 non-null     float64
#  11  World Population              24 non-null     float64
# ...

# %%
df_3['Migrants (net)'] = pd.to_numeric(df_3['Migrants (net)'], errors='coerce')
df_3['Migrants (net)'] = df_3['Migrants (net)'].replace(np.NaN, df_3['Migrants (net)'].mean())
df_3['Migrants (net)'] = df_3['Migrants (net)'].astype(int)
df_3
# Out:
#     Year  Population  Yearly %    Yearly  Migrants (net)  Median Age  \
# 1   2050  75517920.0      0.51  379675.0           90234        33.9
# 2   2045  73619543.0      0.62  448848.0           58397        32.7
# 3   2040  71375305.0      0.73  511264.0           59663        31.6
# 4   2035  68818987.0      0.85  572581.0           76008        30.5
# 5   2030  65956081.0      0.98  630680.0           91759        29.6
# 6   2025  62802683.0      1.15  698799.0          112349        28.7
# 7   2020  59308690.0      1.28  750420.0          145405        27.6
# 8   2019  58558270.0      1.33  765752.0          145405        26.6
# 9   2018  57792518.0      1.37  782762.0          145405        26.6
# 10  2017  57009756.0      1.43  802110.0          145405        26.6
# 11  2016  56207646.0      1.48  821279.0          145405        26.6
# 12  2015  55386367.0      1.58  833881.0          183939        26.4
# 13  2010  51216964.0      1.36  667273.0          172444        25.0
# ...

# %% [markdown]
# ### Merge

# %%
df
# Out:
#     Year   Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 1   2050  129386839.0      2.28  2758164.0          -22554        22.3
# 2   2045  115596020.0      2.42  2601898.0          -40154        21.5
# 3   2040  102586529.0      2.56  2434187.0          -40132        20.7
# 4   2035   90415596.0      2.69  2250574.0          -40116        20.0
# 5   2030   79162725.0      2.81  2045712.0          -40102        19.3
# 6   2025   68934163.0      2.91  1839989.0          -40086        18.6
# 7   2020   59734218.0      2.98  1728755.0          -40076        18.0
# 8   2019   58005463.0      3.00  1692025.0          -40076        17.6
# 9   2018   56313438.0      3.02  1653099.0          -40076        17.6
# 10  2017   54660339.0      3.04  1611109.0          -40076        17.6
# 11  2016   53049230.0      3.04  1566597.0          -40076        17.6
# 12  2015   51482633.0      3.03  1427222.0          -50087        17.6
# ...

# %%
df['Country'] = 'Tanzania'
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1837680123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country'] = 'Tanzania'

# %%
df
# Out:
#     Year   Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 1   2050  129386839.0      2.28  2758164.0          -22554        22.3
# 2   2045  115596020.0      2.42  2601898.0          -40154        21.5
# 3   2040  102586529.0      2.56  2434187.0          -40132        20.7
# 4   2035   90415596.0      2.69  2250574.0          -40116        20.0
# 5   2030   79162725.0      2.81  2045712.0          -40102        19.3
# 6   2025   68934163.0      2.91  1839989.0          -40086        18.6
# 7   2020   59734218.0      2.98  1728755.0          -40076        18.0
# 8   2019   58005463.0      3.00  1692025.0          -40076        17.6
# 9   2018   56313438.0      3.02  1653099.0          -40076        17.6
# 10  2017   54660339.0      3.04  1611109.0          -40076        17.6
# 11  2016   53049230.0      3.04  1566597.0          -40076        17.6
# 12  2015   51482633.0      3.03  1427222.0          -50087        17.6
# ...

# %%
df_1
# Out:
#     Year  Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 1   2020  32866272.0    0.0327  1040977.0            6413        16.7
# 2   2019  31825295.0    0.0330  1015508.0            6413        16.4
# 3   2018  30809787.0    0.0333   993021.0            6413        16.4
# 4   2017  29816766.0    0.0338   974277.0            6413        16.4
# 5   2016  28842489.0    0.0344   958108.0            6413        16.4
# 6   2015  27884381.0    0.0361   905627.0           33253        16.4
# 7   2010  23356246.0    0.0375   784529.0           71460        16.4
# 8   2005  19433602.0    0.0346   607626.0           52220        16.4
# 9   2000  16395473.0    0.0329   490053.0           39960        16.3
# 10  1995  13945206.0    0.0331   419364.0           28562        16.1
# 11  1990  11848386.0    0.0353   377278.0           37698        16.1
# 12  1985   9961997.0    0.0362   324142.0           46830        16.3
# ...

# %%
df_1['Country'] = 'Angola'
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6164\1054488315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Country'] = 'Angola'

# %%
df_2['Country'] = 'Egypt'

# %%
df_3['Country'] = 'South Africa'

# %%
df_4['Country'] = 'Madagascar'

# %%
df.head(2)
# Out:
#    Year   Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 1  2050  129386839.0      2.28  2758164.0          -22554        22.3
# 2  2045  115596020.0      2.42  2601898.0          -40154        21.5
#
#    Fertility Rate  Density (P/Km²)  Urban (Pop %)  Urban (Population)  \
# 1            4.92            146.0           59.2          76542196.0
# 2            4.92            130.0           55.7          64407122.0
#
#    Country's Share of World Pop  World Population Tanzania (Global Rank)  \
# 1                          1.33      9.735034e+09                     15
# 2                          1.22      9.481803e+09                     15
#
#     Country
# 1  Tanzania
# 2  Tanzania

# %%
df_1.head(2)
# Out:
#    Year  Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 1  2020  32866272.0    0.0327  1040977.0            6413        16.7
# 2  2019  31825295.0    0.0330  1015508.0            6413        16.4
#
#    Fertility Rate  Density (P/Km²)  Urban (Pop %)  Urban Population  \
# 1            5.55             26.0          0.667        21936953.0
# 2            5.91             26.0          0.661        21035940.0
#
#    Country's Share of World Pop  World Population Angola (Global Rank) Country
# 1                        0.0042      7.794799e+09                   44  Angola
# 2                        0.0041      7.713468e+09                   45  Angola

# %%
df_2.head(2)
# Out:
#    Year   Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 1  2050  159956808.0      1.25  1920351.0          -45745        29.7
# 2  2045  150355053.0      1.39  2000934.0          -30000        28.5
#
#    Fertility Rate  Density (P/Km²)  Urban (Pop %)  Urban (Population)  \
# 1            3.33            161.0           53.3          85320777.0
# 2            3.33            151.0           50.8          76439477.0
#
#    Country's Share of World Pop  World Population Egypt (Global Rank) Country
# 1                          1.64      9.735034e+09                  11   Egypt
# 2                          1.59      9.481803e+09                  12   Egypt

# %%
df_3.head(2)
# Out:
#    Year  Population  Yearly %    Yearly  Migrants (net)  Median Age  \
# 1  2050  75517920.0      0.51  379675.0           90234        33.9
# 2  2045  73619543.0      0.62  448848.0           58397        32.7
#
#    Fertility Rate  Density (P/Km²)  Urban (Pop %)  Urban Population  \
# 1            2.41             62.0           76.9        58056843.0
# 2            2.41             61.0           75.3        55447449.0
#
#    Country's Share of World Pop  World Population South Africa (Global Rank)  \
# 1                          0.78      9.735034e+09                         25
# 2                          0.78      9.481803e+09                         23
#
#         Country
# 1  South Africa
# 2  South Africa

# %%
df = df.rename(columns={'Urban (Population)':'Urban Population','Tanzania (Global Rank)':'Global Rank'})
df_1 = df_1.rename(columns={'Angola (Global Rank)':'Global Rank'})
df_2 = df_2.rename(columns={'Urban (Population)':'Urban Population','Egypt (Global Rank)':'Global Rank'})
df_3 = df_3.rename(columns={'South Africa (Global Rank)':'Global Rank'})
df_4 = df_4.rename(columns={'Madagascar (Global Rank)':'Global Rank'})

# %%
countryPop = pd.concat([df,df_1,df_2,df_3,df_4])

# %%
countryPop
# Out:
#     Year   Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 1   2050  129386839.0      2.28  2758164.0          -22554        22.3
# 2   2045  115596020.0      2.42  2601898.0          -40154        21.5
# 3   2040  102586529.0      2.56  2434187.0          -40132        20.7
# 4   2035   90415596.0      2.69  2250574.0          -40116        20.0
# 5   2030   79162725.0      2.81  2045712.0          -40102        19.3
# ..   ...          ...       ...        ...             ...         ...
# 14  1975    7556026.0      2.82   195944.0           -3800        17.0
# 15  1970    6576305.0      2.65   161417.0           -1600        17.2
# 16  1965    5769218.0      2.50   133969.0               0        17.9
# 17  1960    5099373.0      2.34   111166.0               0        19.2
# 18  1955    4543542.0      2.16    91998.0               0        20.2
#
#     Fertility Rate  Density (P/Km²)  Urban (Pop %)  Urban Population  \
# ...

# %%
countryPop = countryPop.reset_index(drop=True)

# %%
countryPop
# Out:
#      Year   Population  Yearly %     Yearly  Migrants (net)  Median Age  \
# 0    2050  129386839.0      2.28  2758164.0          -22554        22.3
# 1    2045  115596020.0      2.42  2601898.0          -40154        21.5
# 2    2040  102586529.0      2.56  2434187.0          -40132        20.7
# 3    2035   90415596.0      2.69  2250574.0          -40116        20.0
# 4    2030   79162725.0      2.81  2045712.0          -40102        19.3
# ..    ...          ...       ...        ...             ...         ...
# 103  1975    7556026.0      2.82   195944.0           -3800        17.0
# 104  1970    6576305.0      2.65   161417.0           -1600        17.2
# 105  1965    5769218.0      2.50   133969.0               0        17.9
# 106  1960    5099373.0      2.34   111166.0               0        19.2
# 107  1955    4543542.0      2.16    91998.0               0        20.2
#
#      Fertility Rate  Density (P/Km²)  Urban (Pop %)  Urban Population  \
# ...

# %%
countryPop.isna().sum()
# Out:
# Year                            0
# Population                      0
# Yearly %                        0
# Yearly                          0
# Migrants (net)                  0
# Median Age                      0
# Fertility Rate                  0
# Density (P/Km²)                 0
# Urban (Pop %)                   0
# Urban Population                0
# Country's Share of World Pop    0
# World Population                0
# Global Rank                     0
# Country                         0
# dtype: int64

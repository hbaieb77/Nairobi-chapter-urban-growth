# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
import numpy as np
import scipy.stats as stats
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\riley\\OneDrive\\Desktop\\Urban Developing Omdena\\population_density_kenya_2009.csv")

# %%
df = df.rename(columns={'County':'City'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   County              48 non-null     object
#  1   Population_Density  48 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 896.0+ bytes

# %%
df.isnull().sum()
# Out:
# County                0
# Population_Density    0
# dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Baringo            1
# Bomet              1
# Migori             1
# Mombasa            1
# Murang'A           1
# Nairobi            1
# Nakuru             1
# Nandi              1
# Narok              1
# Nyamira            1
# Nyandarua          1
# Nyeri              1
# Samburu            1
# Siaya              1
# Taita-Taveta       1
# Tana River         1
# Tharaka Nithi      1
# Trans-Nzoia        1
# Turkana            1
# Uasin Gishu        1
# Vihiga             1
# Wajir              1
# West Pokot         1
# Meru               1
# Marsabit           1
# Mandera            1
# Kericho            1
# Bungoma            1
# Busia              1
# Elgeyo-Marakwet    1
# Embu               1
# Garissa            1
# Homa Bay           1
# Isiolo             1
# Kajiado            1
# Kakamega           1
# Kiambu             1
# Makueni            1
# Kilifi             1
# Kirinyaga          1
# Kisii              1
# Kisumu             1
# Kitui              1
# ...

# %%
sns.boxplot(df['Population_Density'])
plt.show()

# %%
def detect_outliers(dataset, columns):
    df = dataset.copy()
    df[columns] = stats.zscore(df[columns])
    outliers = df[(df[columns] < -3) | (df[columns] > 3)]
    print(f"The number of outliers: {outliers.shape[0]}")
    df = df[(df[columns] > -3) & (df[columns] < 3)].reset_index(drop=True)
    return df

# %%
detect_outliers(df,'Population_Density')
# Out:
# The number of outliers: 2
#             Country  Population_Density  Country_code
# 0           Baringo           -0.405085           0.0
# 1             Bomet           -0.125011           1.0
# 2           Bungoma            0.060223           2.0
# 3             Busia            0.043380           3.0
# 4   Elgeyo-Marakwet           -0.322333           4.0
# 5              Embu           -0.251841           5.0
# 6           Garissa           -0.447039           6.0
# 7          Homa Bay           -0.113778           7.0
# 8            Isiolo           -0.456782           8.0
# 9           Kajiado           -0.427090           9.0
# 10         Kakamega            0.165015          10.0
# 11          Kericho           -0.110153          12.0
# 12           Kiambu            0.273500          13.0
# 13           Kilifi           -0.361712          14.0
# 14        Kirinyaga           -0.051160          15.0
# 15            Kisii            0.546359          16.0
# ...

# %%
detect_outliers(df,'Population_Density')
# Out:
# The number of outliers: 0
#             Country  Population_Density  Country_code
# 0           Baringo           -0.800634           0.0
# 1             Bomet            0.190258           1.0
# 2           Bungoma            0.845611           2.0
# 3             Busia            0.786019           3.0
# 4   Elgeyo-Marakwet           -0.507859           4.0
# 5              Embu           -0.258461           5.0
# 6           Garissa           -0.949063           6.0
# 7          Homa Bay            0.230000           7.0
# 8            Isiolo           -0.983536           8.0
# 9           Kajiado           -0.878484           9.0
# 10         Kakamega            1.216358          10.0
# 11          Kericho            0.242825          12.0
# 12           Kiambu            1.600176          13.0
# 13           Kilifi           -0.647180          14.0
# 14        Kirinyaga            0.451542          15.0
# 15            Kisii            2.355644          16.0
# ...

# %%
df = df.drop(df[df['City'] == 'Kenya'].index)

# %%
df['Country'] ='Kenya'

# %%
df['Year'] = 2009

# %%
df
# Out:
#                City  Population_Density Country  Year
# 0           Baringo               50.44   Kenya  2009
# 1             Bomet              293.04   Kenya  2009
# 2           Bungoma              453.49   Kenya  2009
# 3             Busia              438.90   Kenya  2009
# 4   Elgeyo-Marakwet              122.12   Kenya  2009
# 5              Embu              183.18   Kenya  2009
# 6           Garissa               14.10   Kenya  2009
# 7          Homa Bay              302.77   Kenya  2009
# 8            Isiolo                5.66   Kenya  2009
# 9           Kajiado               31.38   Kenya  2009
# 10         Kakamega              544.26   Kenya  2009
# 11          Kericho              305.91   Kenya  2009
# 12           Kiambu              638.23   Kenya  2009
# 13           Kilifi               88.01   Kenya  2009
# 14        Kirinyaga              357.01   Kenya  2009
# 15            Kisii              874.58   Kenya  2009
# ...

# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Omdena/merged_output_v1.csv')

# %%
df = df[df['country']=='Nigeria']

# %%
df
# Out:
#      unnamed:_0  population_growth  population_growth_rate  population  year  \
# 430         430           211949.0                0.033289   6578980.0  2035
# 431         431           209076.0                0.033952   6367031.0  2034
# 432         432           205970.0                0.034605   6157955.0  2033
# 433         433           202246.0                0.035175   5951985.0  2032
# 434         434           198553.0                0.035768   5749739.0  2031
# ..          ...                ...                     ...         ...   ...
# 511         511            10619.0                0.078794    145389.0  1954
# 512         512             6142.0                0.047750    134770.0  1953
# 513         513             2810.0                0.022334    128628.0  1952
# 514         514             2745.0                0.022304    125818.0  1951
# 515         515                0.0                0.000000    123073.0  1950
#
# ...

# %%
df = df.drop(columns=['land_area_(sq._km)','population_density_(no._per_sq._km)','real_gdp','unnamed:_0'])

# %%
df
# Out:
#      population_growth  population_growth_rate  population  year  city  \
# 430           211949.0                0.033289   6578980.0  2035  Kano
# 431           209076.0                0.033952   6367031.0  2034  Kano
# 432           205970.0                0.034605   6157955.0  2033  Kano
# 433           202246.0                0.035175   5951985.0  2032  Kano
# 434           198553.0                0.035768   5749739.0  2031  Kano
# ..                 ...                     ...         ...   ...   ...
# 511            10619.0                0.078794    145389.0  1954  Kano
# 512             6142.0                0.047750    134770.0  1953  Kano
# 513             2810.0                0.022334    128628.0  1952  Kano
# 514             2745.0                0.022304    125818.0  1951  Kano
# 515                0.0                0.000000    123073.0  1950  Kano
#
#      country
# 430  Nigeria
# 431  Nigeria
# 432  Nigeria
# 433  Nigeria
# 434  Nigeria
# ..       ...
# ...

# %%
df
# Out:
#      population_growth  population_growth_rate  population  year  city  \
# 430           211949.0                0.033289   6578980.0  2035  Kano
# 431           209076.0                0.033952   6367031.0  2034  Kano
# 432           205970.0                0.034605   6157955.0  2033  Kano
# 433           202246.0                0.035175   5951985.0  2032  Kano
# 434           198553.0                0.035768   5749739.0  2031  Kano
# ..                 ...                     ...         ...   ...   ...
# 511            10619.0                0.078794    145389.0  1954  Kano
# 512             6142.0                0.047750    134770.0  1953  Kano
# 513             2810.0                0.022334    128628.0  1952  Kano
# 514             2745.0                0.022304    125818.0  1951  Kano
# 515                0.0                0.000000    123073.0  1950  Kano
#
#      country
# 430  Nigeria
# 431  Nigeria
# 432  Nigeria
# 433  Nigeria
# 434  Nigeria
# ..       ...
# ...

# %%
df
# Out:
#      population_growth  population_growth_rate  population  year  city  \
# 430           211949.0                0.033289   6578980.0  2035  Kano
# 431           209076.0                0.033952   6367031.0  2034  Kano
# 432           205970.0                0.034605   6157955.0  2033  Kano
# 433           202246.0                0.035175   5951985.0  2032  Kano
# 434           198553.0                0.035768   5749739.0  2031  Kano
# ..                 ...                     ...         ...   ...   ...
# 511            10619.0                0.078794    145389.0  1954  Kano
# 512             6142.0                0.047750    134770.0  1953  Kano
# 513             2810.0                0.022334    128628.0  1952  Kano
# 514             2745.0                0.022304    125818.0  1951  Kano
# 515                0.0                0.000000    123073.0  1950  Kano
#
#      country
# 430  Nigeria
# 431  Nigeria
# 432  Nigeria
# 433  Nigeria
# 434  Nigeria
# ..       ...
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
encoding = OneHotEncoder(sparse=False)

# %%
df['city'] = encoding.fit_transform(df[['city']])
df['country'] = encoding.fit_transform(df[['country']])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
df
# Out:
#      population_growth  population_growth_rate  population  year  city  \
# 430           211949.0                0.033289   6578980.0  2035   1.0
# 431           209076.0                0.033952   6367031.0  2034   1.0
# 432           205970.0                0.034605   6157955.0  2033   1.0
# 433           202246.0                0.035175   5951985.0  2032   1.0
# 434           198553.0                0.035768   5749739.0  2031   1.0
# ..                 ...                     ...         ...   ...   ...
# 511            10619.0                0.078794    145389.0  1954   1.0
# 512             6142.0                0.047750    134770.0  1953   1.0
# 513             2810.0                0.022334    128628.0  1952   1.0
# 514             2745.0                0.022304    125818.0  1951   1.0
# 515                0.0                0.000000    123073.0  1950   1.0
#
#      country
# 430      1.0
# 431      1.0
# 432      1.0
# 433      1.0
# 434      1.0
# ..       ...
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#     index  population_growth  population_growth_rate  population  year  city  \
# 0     430           211949.0                0.033289   6578980.0  2035   1.0
# 1     431           209076.0                0.033952   6367031.0  2034   1.0
# 2     432           205970.0                0.034605   6157955.0  2033   1.0
# 3     433           202246.0                0.035175   5951985.0  2032   1.0
# 4     434           198553.0                0.035768   5749739.0  2031   1.0
# ..    ...                ...                     ...         ...   ...   ...
# 81    511            10619.0                0.078794    145389.0  1954   1.0
# 82    512             6142.0                0.047750    134770.0  1953   1.0
# 83    513             2810.0                0.022334    128628.0  1952   1.0
# 84    514             2745.0                0.022304    125818.0  1951   1.0
# 85    515                0.0                0.000000    123073.0  1950   1.0
#
#     country
# 0       1.0
# 1       1.0
# ...

# %%
df  = df.drop(columns=['index'])

# %%
df
# Out:
#     population_growth  population_growth_rate  population  year  city  country
# 0            211949.0                0.033289   6578980.0  2035   1.0      1.0
# 1            209076.0                0.033952   6367031.0  2034   1.0      1.0
# 2            205970.0                0.034605   6157955.0  2033   1.0      1.0
# 3            202246.0                0.035175   5951985.0  2032   1.0      1.0
# 4            198553.0                0.035768   5749739.0  2031   1.0      1.0
# ..                ...                     ...         ...   ...   ...      ...
# 81            10619.0                0.078794    145389.0  1954   1.0      1.0
# 82             6142.0                0.047750    134770.0  1953   1.0      1.0
# 83             2810.0                0.022334    128628.0  1952   1.0      1.0
# 84             2745.0                0.022304    125818.0  1951   1.0      1.0
# 85                0.0                0.000000    123073.0  1950   1.0      1.0
#
# [86 rows x 6 columns]

# %%
from matplotlib import pyplot as plt
plt.plot(df['year'],df['population'])

# %%
x = df[['population_growth','population_growth_rate','year'	,'city'	,'country']]
y = df[['population']]

# %%
x_train = df[(df['year'] >= 1950) & (df['year'] < 2023)]

# %%
x_train
# Out:
#     population_growth  population_growth_rate  population  year  city  country
# 13           116194.0                0.028319   4219209.0  2022   1.0      1.0
# 14           103965.0                0.025997   4103015.0  2021   1.0      1.0
# 15            93452.0                0.023928   3999050.0  2020   1.0      1.0
# 16            85516.0                0.022386   3905598.0  2019   1.0      1.0
# 17            80602.0                0.021554   3820082.0  2018   1.0      1.0
# ..                ...                     ...         ...   ...   ...      ...
# 81            10619.0                0.078794    145389.0  1954   1.0      1.0
# 82             6142.0                0.047750    134770.0  1953   1.0      1.0
# 83             2810.0                0.022334    128628.0  1952   1.0      1.0
# 84             2745.0                0.022304    125818.0  1951   1.0      1.0
# 85                0.0                0.000000    123073.0  1950   1.0      1.0
#
# [73 rows x 6 columns]

# %%
y_train = x_train[['population']]

# %%
x_train = x_train.drop(columns=['population'])

# %%
x_train
# Out:
#     population_growth  population_growth_rate  year  city  country
# 13           116194.0                0.028319  2022   1.0      1.0
# 14           103965.0                0.025997  2021   1.0      1.0
# 15            93452.0                0.023928  2020   1.0      1.0
# 16            85516.0                0.022386  2019   1.0      1.0
# 17            80602.0                0.021554  2018   1.0      1.0
# ..                ...                     ...   ...   ...      ...
# 81            10619.0                0.078794  1954   1.0      1.0
# 82             6142.0                0.047750  1953   1.0      1.0
# 83             2810.0                0.022334  1952   1.0      1.0
# 84             2745.0                0.022304  1951   1.0      1.0
# 85                0.0                0.000000  1950   1.0      1.0
#
# [73 rows x 5 columns]

# %%
y_train
# Out:
#     population
# 13   4219209.0
# 14   4103015.0
# 15   3999050.0
# 16   3905598.0
# 17   3820082.0
# ..         ...
# 81    145389.0
# 82    134770.0
# 83    128628.0
# 84    125818.0
# 85    123073.0
#
# [73 rows x 1 columns]

# %%
x_test = df[(df['year'] >= 2023) & (df['year'] <= 2035)]
x_test
# Out:
#     population_growth  population_growth_rate  population  year  city  country
# 0            211949.0                0.033289   6578980.0  2035   1.0      1.0
# 1            209076.0                0.033952   6367031.0  2034   1.0      1.0
# 2            205970.0                0.034605   6157955.0  2033   1.0      1.0
# 3            202246.0                0.035175   5951985.0  2032   1.0      1.0
# 4            198553.0                0.035768   5749739.0  2031   1.0      1.0
# 5            194150.0                0.036242   5551186.0  2030   1.0      1.0
# 6            188948.0                0.036561   5357036.0  2029   1.0      1.0
# 7            182456.0                0.036596   5168088.0  2028   1.0      1.0
# 8            174822.0                0.036339   4985632.0  2027   1.0      1.0
# 9            165495.0                0.035626   4810810.0  2026   1.0      1.0
# 10           154581.0                0.034422   4645315.0  2025   1.0      1.0
# ...

# %%
y_test = x_test[['population']]

# %%
y_test
# Out:
#     population
# 0    6578980.0
# 1    6367031.0
# 2    6157955.0
# 3    5951985.0
# 4    5749739.0
# 5    5551186.0
# 6    5357036.0
# 7    5168088.0
# 8    4985632.0
# 9    4810810.0
# 10   4645315.0
# 11   4490734.0
# 12   4348481.0

# %%
x_test = x_test.drop(columns=['population'])

# %%
import tensorflow as tf

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (73, 5)
# (73, 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train,y_train = scaler.fit_transform(x_train),scaler.fit_transform(y_train)
x_test,y_test = scaler.fit_transform(x_test),scaler.fit_transform(y_test)

# %%
y_train.shape
# Out:
# (73, 1)

# %%
y_test.shape
# Out:
# (13, 1)

# %%
x_test.shape
# Out:
# (13, 5)

# %%
AUTO = tf.data.experimental.AUTOTUNE
train = tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(32).prefetch(AUTO)
test = tf.data.Dataset.from_tensor_slices((x_test,y_test)).batch(32).prefetch(AUTO)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SpatialDropout1D, Dense, Dropout, LSTM,Reshape

# %%
n_lstm = 128
model1 = Sequential()
model1.add(Dense(256,input_shape=[5],activation='relu'))
model1.add(Dropout(0.2))
model1.add(Reshape((1, 256))) 
model1.add(LSTM(n_lstm, return_sequences=False))
model1.add(Dropout(0.2))
model1.add(Dense(1, activation='linear'))

# %%
model1.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model1.fit(train,epochs=1000, batch_size=64,validation_data=(test),callbacks =[early_stop])
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 4s 268ms/step - loss: 1.0020 - mean_absolute_error: 0.8924 - val_loss: 0.8548 - val_mean_absolute_error: 0.7986
# Epoch 2/1000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7792 - mean_absolute_error: 0.7837 - val_loss: 0.7055 - val_mean_absolute_error: 0.7217
# Epoch 3/1000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6159 - mean_absolute_error: 0.6947 - val_loss: 0.5651 - val_mean_absolute_error: 0.6489
# Epoch 4/1000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4578 - mean_absolute_error: 0.5912 - val_loss: 0.4327 - val_mean_absolute_error: 0.5689
# Epoch 5/1000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3142 - mean_absolute_error: 0.4813 - val_loss: 0.3111 - val_mean_absolute_error: 0.4900
# Epoch 6/1000
# ...

# %%
res=model1.predict(test)
predected_res = pd.DataFrame(res)
actual_res = pd.DataFrame(y_test)
det = pd.concat([actual_res, predected_res], join = 'outer', axis = 1)
print(det)
# Out:
# 1/1 [==============================] - 0s 457ms/step
#            0         0
# 0   1.680970  1.708725
# 1   1.379505  1.370264
# 2   1.082126  1.019471
# 3   0.789165  0.654515
# 4   0.501501  0.256976
# 5   0.219090 -0.102047
# 6  -0.057058 -0.391659
# 7  -0.325808 -0.581147
# 8  -0.585324 -0.694745
# 9  -0.833981 -0.757831
# 10 -1.069373 -0.892168
# 11 -1.289240 -1.117082
# 12 -1.491573 -1.392587

# %%
res
# Out:
# array([[ 1.7087251 ],
#        [ 1.3702644 ],
#        [ 1.0194713 ],
#        [ 0.6545154 ],
#        [ 0.25697595],
#        [-0.10204714],
#        [-0.39165938],
#        [-0.581147  ],
#        [-0.69474477],
#        [-0.75783056],
#        [-0.8921684 ],
#        [-1.1170822 ],
#        [-1.3925866 ]], dtype=float32)

# %%
scaler.inverse_transform(res)
# Out:
# array([[6598494. ],
#        [6360534.5],
#        [6113904.5],
#        [5857317.5],
#        [5577822. ],
#        [5325406. ],
#        [5121790.5],
#        [4988568.5],
#        [4908702. ],
#        [4864349. ],
#        [4769901. ],
#        [4611772. ],
#        [4418075. ]], dtype=float32)

# %%
pd.DataFrame(list(zip(scaler.inverse_transform(y_test), scaler.inverse_transform(res))),columns=['Actual', 'predicted'])
# Out:
#          Actual    predicted
# 0   [6578980.0]  [6598494.0]
# 1   [6367031.0]  [6360534.5]
# 2   [6157955.0]  [6113904.5]
# 3   [5951985.0]  [5857317.5]
# 4   [5749739.0]  [5577822.0]
# 5   [5551186.0]  [5325406.0]
# 6   [5357036.0]  [5121790.5]
# 7   [5168088.0]  [4988568.5]
# 8   [4985632.0]  [4908702.0]
# 9   [4810810.0]  [4864349.0]
# 10  [4645315.0]  [4769901.0]
# 11  [4490734.0]  [4611772.0]
# 12  [4348481.0]  [4418075.0]
